# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
# libraries for EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import cufflinks as cf

#Enabling the offline mode for interactive plotting locally
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
import plotly.io as pio
pio.renderers.default = "notebook"

#To display the plots
# %matplotlib inline

# sklearn library for machine learning algorithms, data preprocessing, and evaluation
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import classification_report, confusion_matrix, log_loss, recall_score, accuracy_score, precision_score, f1_score, plot_confusion_matrix, roc_auc_score

# yellowbrick library for visualizing the model performance
from yellowbrick.classifier import ConfusionMatrix

from sklearn.pipeline import Pipeline

# to get rid of the warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)
sns.set_style("whitegrid", {'axes.grid' : False})

# To display maximum columns
pd.set_option('display.max_columns', None)

# To display maximum rows
pd.set_option('display.max_rows', 200)

pd.set_option('display.float_format', lambda x: '%.2f' % x)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %% [markdown]
# primary MOS: A United States military occupation code

# %%
df_male =pd.read_csv("ANSUR II MALE Public.csv", encoding="unicode_escape")
df_male.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# 2                      256               196                427
# 3                      262               199                401
# 4                      267               224                435
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        369               274               493
# 1                        338               257               479
# 2                        408               261               544
# 3                        359               262               518
# 4                        356               263               524
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  71               319                        291
# 1                  67               344                        320
# 2                  75               345                        330
# 3                  73               328                        309
# 4                  80               340                        310
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 142                   979           240            882
# 1                 135                   944           232            870
# 2                 135                  1054           258            901
# 3                 143                   991           242            821
# 4                 138                  1029           275           1080
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                619                     509                373
# 1                584                     468                357
# 2                623                     506                412
# 3                560                     437                395
# 4                706                     567                425
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1535           291                1074         259         1292
# 1             1471           269                1021         253         1244
# 2             1501           288                1120         267         1288
# 3             1423           296                1114         262         1205
# 4             1684           304                1048         232         1452
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           877                    607                             351
# 1           851                    615                             376
# 2           854                    636                             359
# 3           769                    590                             341
# 4          1014                    682                             382
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          36         71             19              247               802
# 1          33         62             18              232               781
# 2          40         61             23              237               810
# 3          39         66             25              272               794
# 4          32         56             19              188               814
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                    101         273                        349
# 1                     98         263                        348
# 2                    103         270                        355
# 3                    106         267                        352
# 4                    111         305                        399
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         299                    575                477
# 1                         289                    523                476
# 2                         357                    575                491
# 3                         318                    593                467
# 4                         324                    605                550
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1136           90                214         193
# 1                 1096           86                203         195
# 2                 1115           93                220         203
# 3                 1034           91                217         194
# 4                 1279           94                222         218
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          150                583         206                     326
# 1          146                568         201                     334
# 2          148                573         202                     356
# 3          158                576         199                     341
# 4          153                566         197                     374
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           70         332                366                1071
# 1           72         312                356                1046
# 2           70         349                393                1053
# 3           68         338                367                 986
# 4           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    685         422          441                   502
# 1                    620         441          447                   490
# 2                    665         462          475                   496
# 3                    640         458          461                   460
# 4                    675         481          505                   612
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                560                             500                      77
# 1                540                             488                      73
# 2                556                             482                      72
# 3                511                             452                      76
# 4                666                             585                      85
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      391                  118                400
# 1                      371                  131                380
# 2                      409                  123                403
# 3                      393                  106                407
# 4                      458                  135                398
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    436                           1447         113
# 1                    420                           1380         118
# 2                    434                           1447         121
# 3                    446                           1357         118
# 4                    430                           1572         132
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              437                   273                   1151
# 1              417                   254                   1119
# 2              431                   268                   1276
# 3              393                   249                   1155
# 4              523                   302                   1231
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  368             145            928                     883
# 1                  353             141            884                     868
# 2                  367             167            917                     910
# 3                  330             148            903                     848
# 4                  400             180            919                     995
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            600  1782     1776                 1449            1092
# 1            564  1745     1702                 1387            1076
# 2            604  1867     1735                 1438            1105
# 3            550  1708     1655                 1346            1021
# 4            641  2035     1914                 1596            1292
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 610             164            786           491
# 1                 572             169            822           476
# 2                 685             198            807           477
# 3                 604             180            803           445
# 4                 672             194            962           584
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               140                  919                           1700
# 1               120                  918                           1627
# 2               125                  918                           1678
# 3               127                  847                           1625
# 4               122                 1090                           1679
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              501           329                 933         240
# 1              432           316                 870         225
# 2              472           329                 964         255
# 3              461           315                 857         205
# 4              467           303                 868         214
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      440                  1054       815
# 1                      371                  1054       726
# 2                      411                  1041       929
# 3                      399                   968       794
# 4                      379                  1245       946
#
#    wristcircumference  wristheight Gender       Date Installation  \
# 0                 175          853   Male   4-Oct-10    Fort Hood
# 1                 167          815   Male   4-Oct-10    Fort Hood
# 2                 180          831   Male   4-Oct-10    Fort Hood
# 3                 176          793   Male  12-Oct-10    Fort Hood
# 4                 188          954   Male  12-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army             Combat Arms        19D          North Dakota
# 1  Regular Army          Combat Support        68W              New York
# 2  Regular Army          Combat Support        68W              New York
# 3  Regular Army  Combat Service Support        88M             Wisconsin
# 4  Regular Army  Combat Service Support        92G        North Carolina
#
#    SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   1       NaN        1   41        71        180
# 1                   1       NaN        1   35        68        160
# 2                   2       NaN        2   42        68        205
# 3                   1       NaN        1   31        66        175
# 4                   2       NaN        2   21        77        213
#
#   WritingPreference
# 0        Right hand
# 1         Left hand
# 2         Left hand
# 3        Right hand
# 4        Right hand

# %%
df_male.shape
# Out:
# (4082, 108)

# %%
df_female =pd.read_csv("ANSUR II FEMALE Public.csv", encoding="unicode_escape")
df_female.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# 2                      237               196                397
# 3                      240               188                384
# 4                      217               182                378
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        315               263               466
# 1                        272               250               430
# 2                        300               276               450
# 3                        364               276               484
# 4                        320               336               525
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  65               338                        301
# 1                  64               294                        270
# 2                  69               309                        270
# 3                  68               340                        294
# 4                  67               300                        295
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 141                  1011           223            836
# 1                 126                   893           186            900
# 2                 128                   987           204            861
# 3                 144                  1012           253            897
# 4                 135                  1281           284            811
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                587                     476                360
# 1                583                     483                350
# 2                583                     466                384
# 3                599                     471                372
# 4                607                     467                433
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1336           274                 922         245         1095
# 1             1440           261                 839         206         1234
# 2             1451           287                 874         223         1226
# 3             1430           269                1008         285         1170
# 4             1362           305                1089         290         1112
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           759                    557                             310
# 1           835                    549                             329
# 2           821                    643                             374
# 3           804                    640                             351
# 4           726                    686                             356
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          35         65             16              220               713
# 1          32         60             23              208               726
# 2          36         65             26              204               790
# 3          38         62             22              244               775
# 4          34         65             18              233               732
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                     91         246                        316
# 1                     91         249                        341
# 2                    100         265                        343
# 3                     97         265                        331
# 4                     88         247                        339
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         265                    517                432
# 1                         247                    468                463
# 2                         262                    488                469
# 3                         309                    529                455
# 4                         260                    596                447
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1028           75                182         184
# 1                 1117           78                187         189
# 2                 1060           84                198         195
# 3                 1069           80                192         186
# 4                 1039           78                183         187
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          141                548         191                     314
# 1          138                535         180                     307
# 2          146                588         207                     331
# 3          153                593         206                     332
# 4          140                522         181                     308
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           69         345                388                 966
# 1           60         315                335                1048
# 2           70         356                399                1043
# 3           68         337                402                1029
# 4           63         448                499                 964
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    645         363          399                   435
# 1                    595         340          375                   483
# 2                    655         345          399                   470
# 3                    655         392          435                   469
# 4                    635         428          435                   440
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                496                             447                      55
# 1                532                             492                      69
# 2                530                             469                      64
# 3                520                             478                      67
# 4                491                             441                      63
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      404                  118                335
# 1                      334                  115                302
# 2                      401                  135                325
# 3                      402                  118                357
# 4                      479                  114                340
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    368                           1268         113
# 1                    345                           1389         110
# 2                    369                           1414         122
# 3                    386                           1329         115
# 4                    358                           1350         116
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              362                   235                   1062
# 1              426                   259                   1014
# 2              398                   258                   1049
# 3              394                   250                   1121
# 4              345                   242                   1151
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  327             148            803                     809
# 1                  346             142            835                     810
# 2                  362             164            904                     855
# 3                  333             157            875                     815
# 4                  329             156            824                     810
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            513  1647     1560                 1280            1013
# 1            575  1751     1665                 1372            1107
# 2            568  1779     1711                 1383            1089
# 3            536  1708     1660                 1358            1065
# 4            559  1702     1572                 1292            1030
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 622             174            736           430
# 1                 524             152            771           475
# 2                 577             164            814           458
# 3                 679             187            736           463
# 4                 766             197            766           429
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               110                  844                           1488
# 1               125                  901                           1470
# 2               129                  882                           1542
# 3               125                  866                           1627
# 4               116                  800                           1698
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              406           295                 850         217
# 1              422           254                 708         168
# 2              419           269                 727         159
# 3              451           302                 923         235
# 4              452           405                1163         300
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      345                   942       657
# 1                      329                  1032       534
# 2                      367                  1035       663
# 3                      371                   999       782
# 4                      380                   911       886
#
#    wristcircumference  wristheight  Gender      Date Installation  \
# 0                 152          756  Female  5-Oct-10    Fort Hood
# 1                 155          815  Female  5-Oct-10    Fort Hood
# 2                 162          799  Female  5-Oct-10    Fort Hood
# 3                 173          818  Female  5-Oct-10    Fort Hood
# 4                 152          762  Female  5-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army          Combat Support        92Y               Germany
# 1  Regular Army  Combat Service Support        25U            California
# 2  Regular Army  Combat Service Support        35D                 Texas
# 3  Regular Army  Combat Service Support        25U  District of Columbia
# 4  Regular Army             Combat Arms        42A                 Texas
#
#    SubjectNumericRace           Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   2                 NaN        2   26        61        142
# 1                   3             Mexican        3   21        64        120
# 2                   1                 NaN        1   23        68        147
# 3                   8  Caribbean Islander        2   22        66        175
# 4                   1                 NaN        1   45        63        195
#
#   WritingPreference
# 0        Right hand
# 1        Right hand
# 2        Right hand
# 3        Right hand
# 4        Right hand

# %%
df_female.shape
# Out:
# (1986, 108)

# %%
df_female.rename({"SubjectId":"subjectid"}, axis=1, inplace=True)

# %%
df_female.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# 2                      237               196                397
# 3                      240               188                384
# 4                      217               182                378
#
#    bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# 0                        315               263               466
# 1                        272               250               430
# 2                        300               276               450
# 3                        364               276               484
# 4                        320               336               525
#
#    bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# 0                  65               338                        301
# 1                  64               294                        270
# 2                  69               309                        270
# 3                  68               340                        294
# 4                  67               300                        295
#
#    bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# 0                 141                  1011           223            836
# 1                 126                   893           186            900
# 2                 128                   987           204            861
# 3                 144                  1012           253            897
# 4                 135                  1281           284            811
#
#    buttockkneelength  buttockpopliteallength  calfcircumference  \
# 0                587                     476                360
# 1                583                     483                350
# 2                583                     466                384
# 3                599                     471                372
# 4                607                     467                433
#
#    cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  \
# 0             1336           274                 922         245         1095
# 1             1440           261                 839         206         1234
# 2             1451           287                 874         223         1226
# 3             1430           269                1008         285         1170
# 4             1362           305                1089         290         1112
#
#    crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  \
# 0           759                    557                             310
# 1           835                    549                             329
# 2           821                    643                             374
# 3           804                    640                             351
# 4           726                    686                             356
#
#    earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  \
# 0          35         65             16              220               713
# 1          32         60             23              208               726
# 2          36         65             26              204               790
# 3          38         62             22              244               775
# 4          34         65             18              233               732
#
#    footbreadthhorizontal  footlength  forearmcenterofgriplength  \
# 0                     91         246                        316
# 1                     91         249                        341
# 2                    100         265                        343
# 3                     97         265                        331
# 4                     88         247                        339
#
#    forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  \
# 0                         265                    517                432
# 1                         247                    468                463
# 2                         262                    488                469
# 3                         309                    529                455
# 4                         260                    596                447
#
#    functionalleglength  handbreadth  handcircumference  handlength  \
# 0                 1028           75                182         184
# 1                 1117           78                187         189
# 2                 1060           84                198         195
# 3                 1069           80                192         186
# 4                 1039           78                183         187
#
#    headbreadth  headcircumference  headlength  heelanklecircumference  \
# 0          141                548         191                     314
# 1          138                535         180                     307
# 2          146                588         207                     331
# 3          153                593         206                     332
# 4          140                522         181                     308
#
#    heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0           69         345                388                 966
# 1           60         315                335                1048
# 2           70         356                399                1043
# 3           68         337                402                1029
# 4           63         448                499                 964
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# 0                    645         363          399                   435
# 1                    595         340          375                   483
# 2                    655         345          399                   470
# 3                    655         392          435                   469
# 4                    635         428          435                   440
#
#    kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  \
# 0                496                             447                      55
# 1                532                             492                      69
# 2                530                             469                      64
# 3                520                             478                      67
# 4                491                             441                      63
#
#    lowerthighcircumference  mentonsellionlength  neckcircumference  \
# 0                      404                  118                335
# 1                      334                  115                302
# 2                      401                  135                325
# 3                      402                  118                357
# 4                      479                  114                340
#
#    neckcircumferencebase  overheadfingertipreachsitting  palmlength  \
# 0                    368                           1268         113
# 1                    345                           1389         110
# 2                    369                           1414         122
# 3                    386                           1329         115
# 4                    358                           1350         116
#
#    poplitealheight  radialestylionlength  shouldercircumference  \
# 0              362                   235                   1062
# 1              426                   259                   1014
# 2              398                   258                   1049
# 3              394                   250                   1121
# 4              345                   242                   1151
#
#    shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  \
# 0                  327             148            803                     809
# 1                  346             142            835                     810
# 2                  362             164            904                     855
# 3                  333             157            875                     815
# 4                  329             156            824                     810
#
#    sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  \
# 0            513  1647     1560                 1280            1013
# 1            575  1751     1665                 1372            1107
# 2            568  1779     1711                 1383            1089
# 3            536  1708     1660                 1358            1065
# 4            559  1702     1572                 1292            1030
#
#    thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# 0                 622             174            736           430
# 1                 524             152            771           475
# 2                 577             164            814           458
# 3                 679             187            736           463
# 4                 766             197            766           429
#
#    tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# 0               110                  844                           1488
# 1               125                  901                           1470
# 2               129                  882                           1542
# 3               125                  866                           1627
# 4               116                  800                           1698
#
#    waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# 0              406           295                 850         217
# 1              422           254                 708         168
# 2              419           269                 727         159
# 3              451           302                 923         235
# 4              452           405                1163         300
#
#    waistfrontlengthsitting  waistheightomphalion  weightkg  \
# 0                      345                   942       657
# 1                      329                  1032       534
# 2                      367                  1035       663
# 3                      371                   999       782
# 4                      380                   911       886
#
#    wristcircumference  wristheight  Gender      Date Installation  \
# 0                 152          756  Female  5-Oct-10    Fort Hood
# 1                 155          815  Female  5-Oct-10    Fort Hood
# 2                 162          799  Female  5-Oct-10    Fort Hood
# 3                 173          818  Female  5-Oct-10    Fort Hood
# 4                 152          762  Female  5-Oct-10    Fort Hood
#
#       Component                  Branch PrimaryMOS SubjectsBirthLocation  \
# 0  Regular Army          Combat Support        92Y               Germany
# 1  Regular Army  Combat Service Support        25U            California
# 2  Regular Army  Combat Service Support        35D                 Texas
# 3  Regular Army  Combat Service Support        25U  District of Columbia
# 4  Regular Army             Combat Arms        42A                 Texas
#
#    SubjectNumericRace           Ethnicity  DODRace  Age  Heightin  Weightlbs  \
# 0                   2                 NaN        2   26        61        142
# 1                   3             Mexican        3   21        64        120
# 2                   1                 NaN        1   23        68        147
# 3                   8  Caribbean Islander        2   22        66        175
# 4                   1                 NaN        1   45        63        195
#
#   WritingPreference
# 0        Right hand
# 1        Right hand
# 2        Right hand
# 3        Right hand
# 4        Right hand

# %%
df = pd.concat([df_male, df_female], ignore_index=True)

# %%
df.shape
# Out:
# (6068, 108)

# %% [markdown]
# ## Explore Data

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Data columns (total 108 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    subjectid                       int64
#  1    abdominalextensiondepthsitting  int64
#  2    acromialheight                  int64
#  3    acromionradialelength           int64
#  4    anklecircumference              int64
#  5    axillaheight                    int64
#  6    balloffootcircumference         int64
#  7    balloffootlength                int64
#  8    biacromialbreadth               int64
#  9    bicepscircumferenceflexed       int64
#  10   bicristalbreadth                int64
#  11   bideltoidbreadth                int64
#  12   bimalleolarbreadth              int64
#  13   bitragionchinarc                int64
#  14   bitragionsubmandibulararc       int64
#  15   bizygomaticbreadth              int64
#  16   buttockcircumference            int64
#  17   buttockdepth                    int64
#  18   buttockheight                   int64
#  19   buttockkneelength               int64
#  20   buttockpopliteallength          int64
#  21   calfcircumference               int64
#  22   cervicaleheight                 int64
#  23   chestbreadth                    int64
#  24   chestcircumference              int64
#  25   chestdepth                      int64
#  26   chestheight                     int64
#  27   crotchheight                    int64
#  28   crotchlengthomphalion           int64
#  29   crotchlengthposterioromphalion  int64
#  30   earbreadth                      int64
#  31   earlength                       int64
#  32   earprotrusion                   int64
#  33   elbowrestheight                 int64
#  34   eyeheightsitting                int64
#  35   footbreadthhorizontal           int64
#  36   footlength                      int64
#  37   forearmcenterofgriplength       int64
#  38   forearmcircumferenceflexed      int64
#  39   forearmforearmbreadth           int64
#  40   forearmhandlength               int64
#  41   functionalleglength             int64
#  42   handbreadth                     int64
#  43   handcircumference               int64
#  44   handlength                      int64
#  45   headbreadth                     int64
#  46   headcircumference               int64
#  47   headlength                      int64
#  48   heelanklecircumference          int64
#  49   heelbreadth                     int64
#  50   hipbreadth                      int64
#  51   hipbreadthsitting               int64
#  52   iliocristaleheight              int64
#  53   interpupillarybreadth           int64
#  54   interscyei                      int64
#  55   interscyeii                     int64
#  56   kneeheightmidpatella            int64
#  57   kneeheightsitting               int64
#  58   lateralfemoralepicondyleheight  int64
#  59   lateralmalleolusheight          int64
#  60   lowerthighcircumference         int64
#  61   mentonsellionlength             int64
#  62   neckcircumference               int64
#  63   neckcircumferencebase           int64
#  64   overheadfingertipreachsitting   int64
#  65   palmlength                      int64
#  66   poplitealheight                 int64
#  67   radialestylionlength            int64
#  68   shouldercircumference           int64
#  69   shoulderelbowlength             int64
#  70   shoulderlength                  int64
#  71   sittingheight                   int64
#  72   sleevelengthspinewrist          int64
#  73   sleeveoutseam                   int64
#  74   span                            int64
#  75   stature                         int64
#  76   suprasternaleheight             int64
#  77   tenthribheight                  int64
#  78   thighcircumference              int64
#  79   thighclearance                  int64
#  80   thumbtipreach                   int64
#  81   tibialheight                    int64
#  82   tragiontopofhead                int64
#  83   trochanterionheight             int64
#  84   verticaltrunkcircumferenceusa   int64
#  85   waistbacklength                 int64
#  86   waistbreadth                    int64
#  87   waistcircumference              int64
#  88   waistdepth                      int64
#  89   waistfrontlengthsitting         int64
#  90   waistheightomphalion            int64
#  91   weightkg                        int64
#  92   wristcircumference              int64
#  93   wristheight                     int64
#  94   Gender                          object
#  95   Date                            object
#  96   Installation                    object
#  97   Component                       object
#  98   Branch                          object
#  99   PrimaryMOS                      object
#  100  SubjectsBirthLocation           object
#  101  SubjectNumericRace              int64
#  102  Ethnicity                       object
#  103  DODRace                         int64
#  104  Age                             int64
#  105  Heightin                        int64
#  106  Weightlbs                       int64
#  107  WritingPreference               object
# dtypes: int64(99), object(9)
# memory usage: 5.0+ MB

# %%
df.isnull().sum()
# Out:
# subjectid                            0
# abdominalextensiondepthsitting       0
# acromialheight                       0
# acromionradialelength                0
# anklecircumference                   0
# axillaheight                         0
# balloffootcircumference              0
# balloffootlength                     0
# biacromialbreadth                    0
# bicepscircumferenceflexed            0
# bicristalbreadth                     0
# bideltoidbreadth                     0
# bimalleolarbreadth                   0
# bitragionchinarc                     0
# bitragionsubmandibulararc            0
# bizygomaticbreadth                   0
# buttockcircumference                 0
# buttockdepth                         0
# buttockheight                        0
# buttockkneelength                    0
# buttockpopliteallength               0
# calfcircumference                    0
# cervicaleheight                      0
# chestbreadth                         0
# chestcircumference                   0
# chestdepth                           0
# chestheight                          0
# crotchheight                         0
# crotchlengthomphalion                0
# crotchlengthposterioromphalion       0
# earbreadth                           0
# earlength                            0
# earprotrusion                        0
# elbowrestheight                      0
# eyeheightsitting                     0
# footbreadthhorizontal                0
# footlength                           0
# forearmcenterofgriplength            0
# forearmcircumferenceflexed           0
# forearmforearmbreadth                0
# forearmhandlength                    0
# functionalleglength                  0
# handbreadth                          0
# handcircumference                    0
# handlength                           0
# headbreadth                          0
# headcircumference                    0
# headlength                           0
# heelanklecircumference               0
# heelbreadth                          0
# hipbreadth                           0
# hipbreadthsitting                    0
# iliocristaleheight                   0
# interpupillarybreadth                0
# interscyei                           0
# interscyeii                          0
# kneeheightmidpatella                 0
# kneeheightsitting                    0
# lateralfemoralepicondyleheight       0
# lateralmalleolusheight               0
# lowerthighcircumference              0
# mentonsellionlength                  0
# neckcircumference                    0
# neckcircumferencebase                0
# overheadfingertipreachsitting        0
# palmlength                           0
# poplitealheight                      0
# radialestylionlength                 0
# shouldercircumference                0
# shoulderelbowlength                  0
# shoulderlength                       0
# sittingheight                        0
# sleevelengthspinewrist               0
# sleeveoutseam                        0
# span                                 0
# stature                              0
# suprasternaleheight                  0
# tenthribheight                       0
# thighcircumference                   0
# thighclearance                       0
# thumbtipreach                        0
# tibialheight                         0
# tragiontopofhead                     0
# trochanterionheight                  0
# verticaltrunkcircumferenceusa        0
# waistbacklength                      0
# waistbreadth                         0
# waistcircumference                   0
# waistdepth                           0
# waistfrontlengthsitting              0
# waistheightomphalion                 0
# weightkg                             0
# wristcircumference                   0
# wristheight                          0
# Gender                               0
# Date                                 0
# Installation                         0
# Component                            0
# Branch                               0
# PrimaryMOS                           0
# SubjectsBirthLocation                0
# SubjectNumericRace                   0
# Ethnicity                         4647
# DODRace                              0
# Age                                  0
# Heightin                             0
# Weightlbs                            0
# WritingPreference                    0
# dtype: int64

# %%
# Drop Ethnicity feature

df.drop(columns="Ethnicity", inplace=True)

# %%
df.shape
# Out:
# (6068, 107)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        subjectid  abdominalextensiondepthsitting  acromialheight  \
# count    6068.00                         6068.00         6068.00
# mean    20757.20                          246.47         1406.16
# std     13159.39                           37.40           79.09
# min     10027.00                          155.00         1115.00
# 25%     14841.75                          219.00         1350.00
# 50%     20063.50                          242.00         1410.00
# 75%     27234.50                          271.00         1462.00
# max    920103.00                          451.00         1683.00
#
#        acromionradialelength  anklecircumference  axillaheight  \
# count                6068.00             6068.00       6068.00
# mean                  327.37              224.89       1299.61
# std                    20.72               16.05         72.02
# min                   249.00              156.00       1038.00
# 25%                   313.00              214.00       1249.00
# 50%                   328.00              225.00       1302.00
# 75%                   341.25              235.00       1349.00
# max                   393.00              293.00       1553.00
#
#        balloffootcircumference  balloffootlength  biacromialbreadth  \
# count                  6068.00           6068.00            6068.00
# mean                    244.19            194.75             399.20
# std                      16.85             13.52              30.24
# min                     186.00            151.00             283.00
# 25%                     232.00            185.00             376.00
# 50%                     245.00            195.00             404.00
# 75%                     256.00            204.00             421.00
# max                     306.00            245.00             489.00
#
#        bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  \
# count                    6068.00           6068.00           6068.00
# mean                      340.93            274.74            490.75
# std                        41.52             19.22             42.14
# min                       216.00            197.00            357.00
# 25%                       311.00            262.00            460.00
# 50%                       341.00            274.00            492.00
# 75%                       370.00            288.00            520.00
# max                       490.00            362.00            637.00
#
#        bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  \
# count             6068.00           6068.00                    6068.00
# mean                72.25            324.90                     306.64
# std                  5.34             17.09                      20.79
# min                 55.00            267.00                     245.00
# 25%                 68.00            314.00                     292.00
# 50%                 72.00            326.00                     307.00
# 75%                 76.00            336.00                     321.00
# max                 91.00            385.00                     390.00
#
#        bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  \
# count             6068.00               6068.00       6068.00        6068.00
# mean               139.72               1020.08        241.62         870.15
# std                  7.31                 76.42         26.48          54.82
# min                116.00                737.00        168.00         656.00
# 25%                135.00                968.00        222.00         832.00
# 50%                140.00               1017.00        241.00         868.00
# 75%                145.00               1068.00        259.00         906.25
# max                174.00               1341.00        349.00        1080.00
#
#        buttockkneelength  buttockpopliteallength  calfcircumference  \
# count            6068.00                 6068.00            6068.00
# mean              609.00                  497.10             386.04
# std                33.79                   29.08              30.65
# min               466.00                  367.00             266.00
# 25%               586.00                  477.00             364.75
# 50%               609.00                  497.00             385.00
# 75%               632.00                  517.00             406.00
# max               736.00                  605.00             523.00
#
#        cervicaleheight  chestbreadth  chestcircumference  chestdepth  \
# count          6068.00       6068.00             6068.00     6068.00
# mean           1477.49        282.86             1022.10      251.74
# std              84.32         20.66              100.67       26.78
# min            1184.00        213.00              695.00      170.00
# 25%            1418.00        268.00              949.00      233.00
# 50%            1484.00        283.00             1020.50      251.00
# 75%            1537.00        297.00             1092.00      270.00
# max            1738.00        363.00             1469.00      383.00
#
#        chestheight  crotchheight  crotchlengthomphalion  \
# count      6068.00       6068.00                6068.00
# mean       1252.01        825.11                 621.85
# std          79.58         54.75                  45.33
# min         984.00        610.00                 473.00
# 25%        1196.00        787.00                 590.00
# 50%        1259.00        825.00                 620.00
# 75%        1309.00        863.00                 651.00
# max        1506.00       1031.00                 799.00
#
#        crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  \
# count                         6068.00     6068.00    6068.00        6068.00
# mean                           351.32       35.13      62.63          22.26
# std                             29.94        3.23       4.88           3.17
# min                            243.00       25.00      46.00          13.00
# 25%                            330.00       33.00      59.00          20.00
# 50%                            350.00       35.00      62.00          22.00
# 75%                            372.00       37.00      66.00          24.00
# max                            468.00       46.00      81.00          34.00
#
#        elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  \
# count          6068.00           6068.00                6068.00     6068.00
# mean            240.91            785.91                  98.87      263.03
# std              28.51             41.87                   6.66       17.39
# min             138.00            654.00                  77.00      198.00
# 25%             222.00            757.00                  94.00      251.00
# 50%             241.00            787.00                  99.00      264.00
# 75%             261.00            815.00                 104.00      276.00
# max             345.00            912.00                 126.00      323.00
#
#        forearmcenterofgriplength  forearmcircumferenceflexed  \
# count                    6068.00                     6068.00
# mean                      338.77                      295.01
# std                        23.24                       30.05
# min                       258.00                      200.00
# 25%                       322.00                      272.00
# 50%                       340.00                      297.00
# 75%                       355.00                      317.00
# max                       416.00                      402.00
#
#        forearmforearmbreadth  forearmhandlength  functionalleglength  \
# count                6068.00            6068.00              6068.00
# mean                  552.08             467.01              1102.05
# std                    62.37              30.03                68.55
# min                   376.00             342.00               835.00
# 25%                   505.00             446.00              1055.00
# 50%                   553.00             469.00              1104.00
# 75%                   597.00             488.00              1149.00
# max                   778.00             574.00              1316.00
#
#        handbreadth  handcircumference  handlength  headbreadth  \
# count      6068.00            6068.00     6068.00      6068.00
# mean         84.95             203.86      189.29       152.18
# std           6.35              15.55       11.51         6.24
# min          67.00             152.00      145.00       131.00
# 25%          80.00             192.00      181.00       148.00
# 50%          86.00             206.00      189.50       152.00
# 75%          90.00             215.00      197.00       156.00
# max         105.00             248.00      239.00       180.00
#
#        headcircumference  headlength  heelanklecircumference  heelbreadth  \
# count            6068.00     6068.00                 6068.00      6068.00
# mean              570.04      196.33                  332.62        70.76
# std                18.29        8.49                   22.46         5.93
# min               500.00      168.00                  258.00        48.00
# 25%               557.00      191.00                  316.00        67.00
# 50%               570.00      197.00                  334.00        70.00
# 75%               582.00      202.00                  348.00        75.00
# max               635.00      225.00                  403.00        93.00
#
#        hipbreadth  hipbreadthsitting  iliocristaleheight  \
# count     6068.00            6068.00             6068.00
# mean       348.39             385.73             1040.06
# std         25.30              32.40               59.87
# min        264.00             280.00              816.00
# 25%        332.00             364.00              998.00
# 50%        347.00             384.00             1040.00
# 75%        364.00             406.00             1081.00
# max        473.00             541.00             1253.00
#
#        interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  \
# count                6068.00     6068.00      6068.00               6068.00
# mean                  632.60      412.04       432.34                475.51
# std                    36.51       43.07        38.66                 33.07
# min                   510.00      270.00       306.00                346.00
# 25%                   610.00      381.00       405.00                452.00
# 50%                   635.00      411.00       434.00                476.00
# 75%                   655.00      442.00       460.00                497.00
# max                   770.00      562.00       577.00                612.00
#
#        kneeheightsitting  lateralfemoralepicondyleheight  \
# count            6068.00                         6068.00
# mean              540.12                          483.24
# std                34.20                           29.36
# min               407.00                          352.00
# 25%               516.00                          463.00
# 50%               541.00                          483.00
# 75%               564.00                          503.00
# max               666.00                          594.00
#
#        lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  \
# count                 6068.00                  6068.00              6068.00
# mean                    69.58                   406.48               119.52
# std                      7.27                    33.23                 7.88
# min                     43.00                   290.00                91.00
# 25%                     65.00                   384.00               114.00
# 50%                     70.00                   405.00               120.00
# 75%                     75.00                   427.00               125.00
# max                     93.00                   600.00               156.00
#
#        neckcircumference  neckcircumferencebase  \
# count            6068.00                6068.00
# mean              375.44                 413.83
# std                39.77                  38.16
# min               275.00                 302.00
# 25%               342.00                 382.00
# 50%               380.00                 418.00
# 75%               404.00                 442.00
# max               514.00                 545.00
#
#        overheadfingertipreachsitting  palmlength  poplitealheight  \
# count                        6068.00     6068.00          6068.00
# mean                         1388.40      113.92           416.19
# std                            85.85        7.14            31.27
# min                          1111.00       88.00           305.00
# 25%                          1327.00      109.00           394.00
# 50%                          1393.00      114.00           417.00
# 75%                          1449.00      118.00           438.00
# max                          1651.00      140.00           525.00
#
#        radialestylionlength  shouldercircumference  shoulderelbowlength  \
# count               6068.00                6068.00              6068.00
# mean                 259.19                1129.36               354.08
# std                   19.78                  92.83                22.60
# min                  169.00                 852.00               271.00
# 25%                  245.00                1057.00               338.00
# 50%                  260.00                1139.00               355.00
# 75%                  273.00                1197.00               370.00
# max                  328.00                1413.00               423.00
#
#        shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  \
# count         6068.00        6068.00                 6068.00        6068.00
# mean           145.07         898.11                  866.67         576.90
# std             12.42          45.30                   57.52          38.26
# min            107.00         750.00                  636.00         410.00
# 25%            137.00         866.00                  824.00         550.00
# 50%            145.00         900.00                  872.00         578.00
# 75%            154.00         930.00                  910.00         603.00
# max            185.00        1039.00                 1058.00         709.00
#
#          span  stature  suprasternaleheight  tenthribheight  \
# count 6068.00  6068.00              6068.00         6068.00
# mean  1763.79  1714.41              1402.95         1099.59
# std    110.83    90.02                78.77           60.54
# min   1323.00  1409.00              1131.00          868.00
# 25%   1686.75  1651.75              1348.00         1057.00
# 50%   1771.00  1719.00              1407.00         1099.00
# 75%   1842.00  1779.00              1459.00         1141.00
# max   2121.00  1993.00              1650.00         1305.00
#
#        thighcircumference  thighclearance  thumbtipreach  tibialheight  \
# count             6068.00         6068.00        6068.00       6068.00
# mean               622.20          176.34         789.70        458.24
# std                 57.75           16.22          53.82         29.76
# min                412.00          121.00         602.00        344.00
# 25%                583.00          165.00         753.00        437.00
# 50%                621.00          175.00         792.00        458.00
# 75%                659.00          187.00         826.00        478.00
# max                870.00          259.00         998.00        584.00
#
#        tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  \
# count           6068.00              6068.00                        6068.00
# mean             129.62               882.74                        1630.31
# std                6.66                54.40                          98.62
# min              105.00               660.00                        1342.00
# 25%              125.00               845.00                        1558.00
# 50%              130.00               882.00                        1628.00
# 75%              134.00               918.00                        1695.00
# max              150.00              1095.00                        1991.00
#
#        waistbacklength  waistbreadth  waistcircumference  waistdepth  \
# count          6068.00       6068.00             6068.00     6068.00
# mean            460.52        317.75              914.50      229.67
# std              36.68         36.36              114.27       35.61
# min             345.00        211.00              611.00      138.00
# 25%             435.00        292.00              829.00      203.00
# 50%             463.00        316.00              907.00      226.00
# 75%             486.00        343.00              992.00      252.25
# max             598.00        461.00             1379.00      406.00
#
#        waistfrontlengthsitting  waistheightomphalion  weightkg  \
# count                  6068.00               6068.00   6068.00
# mean                    377.00               1031.50    797.09
# std                      31.62                 62.70    156.53
# min                     289.00                805.00    358.00
# 25%                     355.00                988.00    682.00
# 50%                     375.00               1033.00    785.00
# 75%                     398.00               1076.00    896.00
# max                     494.00               1245.00   1442.00
#
#        wristcircumference  wristheight  SubjectNumericRace  DODRace     Age  \
# count             6068.00      6068.00             6068.00  6068.00 6068.00
# mean               169.00       830.06               17.52     1.62   29.76
# std                 13.12        47.65              550.95     0.98    8.67
# min                124.00       672.00                1.00     1.00   17.00
# 25%                159.00       797.00                1.00     1.00   23.00
# 50%                170.00       830.00                1.00     1.00   28.00
# 75%                179.00       863.00                2.00     2.00   36.00
# max                216.00      1009.00            42351.00     8.00   58.00
#
#        Heightin  Weightlbs
# count   6068.00    6068.00
# mean      68.26     174.75
# std        3.86      33.69
# min       56.00       0.00
# 25%       66.00     150.00
# 50%       68.00     173.00
# 75%       71.00     196.00
# max       94.00     321.00

# %%
df.describe(include="O")
# Out:
#        Gender       Date Installation     Component                  Branch  \
# count    6068       6068         6068          6068                    6068
# unique      2        253           12             3                       3
# top      Male  27-Feb-12  Camp Shelby  Regular Army  Combat Service Support
# freq     4082         45         1160          3140                    3174
#
#        PrimaryMOS SubjectsBirthLocation WritingPreference
# count        6068                  6068              6068
# unique        285                   152                 3
# top           11B            California        Right hand
# freq          671                   446              5350

# %%
# features will be dropped

# Date
# Installation
# subjectid
# Weightlbs = weightkg
# Heightin = stature

# %%
df[["SubjectNumericRace","DODRace"]].value_counts()
# Out:
# SubjectNumericRace  DODRace
# 1                   1          3554
# 2                   2          1025
# 3                   3           522
# 31                  3           112
# 4                   4           108
# 51                  1            99
# 8                   2            94
# 21                  2            51
# 31                  1            47
# 6                   6            37
# 23                  2            26
# 41                  4            26
# 28                  2            25
# 51                  5            24
# 6                   4            21
# 41                  1            19
# 251                 2            18
# 5                   5            16
# 61                  1            15
# 3                   1            13
# 25                  2            13
# 18                  1            12
# 61                  6            12
# 8                   1            11
#                     4            10
# 21                  1             9
# 61                  4             8
# 23                  3             8
# 62                  2             6
# 42                  2             6
# 64                  4             6
# 3                   2             6
# 35                  3             5
# 351                 3             5
#                     1             4
# 38                  2             4
#                     3             4
# 235                 2             3
# 63                  3             3
# 51                  3             3
# 1                   3             3
# 43                  3             3
# 18                  2             3
# 218                 2             3
# 231                 3             3
# 63                  6             3
# 35                  5             3
# 231                 2             3
# 251                 1             2
# 423                 2             2
# 2518                2             2
# 64                  6             2
# 43                  4             2
# 5                   6             2
# 1                   5             2
#                     2             2
# 4251                2             1
# 2351                2             1
# 351                 5             1
# 358                 3             1
# 2                   5             1
# 425                 2             1
# 428                 2             1
# 431                 1             1
#                     3             1
# 451                 1             1
#                     4             1
# 4                   1             1
# 641                 4             1
#                     6             1
# 651                 1             1
#                     6             1
# 2351                1             1
# 631                 3             1
# 48                  4             1
# 318                 8             1
# 28                  3             1
# 42                  4             1
# 62                  4             1
#                     6             1
# 41                  5             1
# 63                  4             1
# 38                  1             1
# 31                  8             1
# 25                  5             1
# 318                 1             1
# 18                  8             1
#                     4             1
#                     3             1
# 235                 3             1
# 238                 2             1
# 8                   3             1
# 6                   3             1
# 42351               2             1
# dtype: int64

# %%
df[df.SubjectNumericRace != df.DODRace].shape
# Out:
# (806, 107)

# %%
(df.SubjectNumericRace > 8).sum()/df.shape[0]
# Out:
# 0.1051417270929466

# %%
df.SubjectNumericRace.value_counts().sort_index()
# Out:
# 1        3561
# 2        1026
# 3         541
# 4         109
# 5          18
# 6          59
# 8         116
# 18         18
# 21         60
# 23         34
# 25         14
# 28         26
# 31        160
# 35          8
# 38          9
# 41         46
# 42          7
# 43          5
# 48          1
# 51        126
# 61         35
# 62          8
# 63          7
# 64          8
# 218         3
# 231         6
# 235         4
# 238         1
# 251        20
# 318         2
# 351        10
# 358         1
# 423         2
# 425         1
# 428         1
# 431         2
# 451         2
# 631         1
# 641         2
# 651         2
# 2351        2
# 2518        2
# 4251        1
# 42351       1
# Name: SubjectNumericRace, dtype: int64

# %%
df.DODRace.value_counts()
# Out:
# 1    3792
# 2    1298
# 3     679
# 4     188
# 6      59
# 5      49
# 8       3
# Name: DODRace, dtype: int64

# %%
df[df.SubjectNumericRace == df.DODRace][["SubjectNumericRace","DODRace"]].value_counts()
# Out:
# SubjectNumericRace  DODRace
# 1                   1          3554
# 2                   2          1025
# 3                   3           522
# 4                   4           108
# 6                   6            37
# 5                   5            16
# dtype: int64

# %%
# features will be dropped

# Date
# Installation
# subjectid
# Weightlbs = weightkg
# Heightin = stature
# SubjectNumericRace
# PrimaryMOS
# SubjectsBirthLocation

df.drop(columns=["Date","Installation", "subjectid","Weightlbs","Heightin","SubjectNumericRace", "PrimaryMOS", "SubjectsBirthLocation"], inplace=True)

# %%
df.shape
# Out:
# (6068, 99)

# %%
# dropping DODRace whose value counts are less than 500

(df.DODRace.value_counts() < 500)
# Out:
# 1    False
# 2    False
# 3    False
# 4     True
# 6     True
# 5     True
# 8     True
# Name: DODRace, dtype: bool

# %%
df.loc[df.DODRace.isin([4,5,6,8])].index
# Out:
# Int64Index([  45,   58,   60,  111,  120,  135,  163,  176,  198,  204,
#             ...
#             5886, 5888, 5920, 5936, 5949, 5957, 5964, 5971, 5977, 6024],
#            dtype='int64', length=299)

# %%
df.drop(index=df.loc[df.DODRace.isin([4,5,6,8])].index, inplace=True)

# %%
df.shape
# Out:
# (5769, 99)

# %%
sns.scatterplot(data=df.DODRace)
# Out:
# <AxesSubplot:ylabel='DODRace'>

# %%
df.corr()
# Out:
#                                 abdominalextensiondepthsitting  \
# abdominalextensiondepthsitting                            1.00
# acromialheight                                            0.35
# acromionradialelength                                     0.31
# anklecircumference                                        0.52
# axillaheight                                              0.28
# balloffootcircumference                                   0.46
# balloffootlength                                          0.33
# biacromialbreadth                                         0.42
# bicepscircumferenceflexed                                 0.69
# bicristalbreadth                                          0.51
# bideltoidbreadth                                          0.72
# bimalleolarbreadth                                        0.37
# bitragionchinarc                                          0.53
# bitragionsubmandibulararc                                 0.63
# bizygomaticbreadth                                        0.52
# buttockcircumference                                      0.74
# buttockdepth                                              0.84
# buttockheight                                             0.25
# buttockkneelength                                         0.48
# buttockpopliteallength                                    0.32
# calfcircumference                                         0.66
# cervicaleheight                                           0.34
# chestbreadth                                              0.63
# chestcircumference                                        0.83
# chestdepth                                                0.78
# chestheight                                               0.30
# crotchheight                                              0.19
# crotchlengthomphalion                                     0.46
# crotchlengthposterioromphalion                            0.20
# earbreadth                                                0.24
# earlength                                                 0.40
# earprotrusion                                             0.14
# elbowrestheight                                           0.26
# eyeheightsitting                                          0.28
# footbreadthhorizontal                                     0.44
# footlength                                                0.35
# forearmcenterofgriplength                                 0.35
# forearmcircumferenceflexed                                0.63
# forearmforearmbreadth                                     0.73
# forearmhandlength                                         0.31
# functionalleglength                                       0.42
# handbreadth                                               0.42
# handcircumference                                         0.46
# handlength                                                0.30
# headbreadth                                               0.36
# headcircumference                                         0.36
# headlength                                                0.33
# heelanklecircumference                                    0.50
# heelbreadth                                               0.44
# hipbreadth                                                0.60
# hipbreadthsitting                                         0.55
# iliocristaleheight                                        0.26
# interpupillarybreadth                                     0.26
# interscyei                                                0.60
# interscyeii                                               0.54
# kneeheightmidpatella                                      0.28
# kneeheightsitting                                         0.35
# lateralfemoralepicondyleheight                            0.22
# lateralmalleolusheight                                    0.35
# lowerthighcircumference                                   0.67
# mentonsellionlength                                       0.29
# neckcircumference                                         0.66
# neckcircumferencebase                                     0.63
# overheadfingertipreachsitting                             0.32
# palmlength                                                0.31
# poplitealheight                                           0.15
# radialestylionlength                                      0.28
# shouldercircumference                                     0.64
# shoulderelbowlength                                       0.29
# shoulderlength                                            0.19
# sittingheight                                             0.27
# sleevelengthspinewrist                                    0.42
# sleeveoutseam                                             0.28
# span                                                      0.32
# stature                                                   0.31
# suprasternaleheight                                       0.35
# tenthribheight                                            0.29
# thighcircumference                                        0.73
# thighclearance                                            0.72
# thumbtipreach                                             0.39
# tibialheight                                              0.26
# tragiontopofhead                                          0.19
# trochanterionheight                                       0.23
# verticaltrunkcircumferenceusa                             0.73
# waistbacklength                                           0.57
# waistbreadth                                              0.86
# waistcircumference                                        0.94
# waistdepth                                                0.96
# waistfrontlengthsitting                                   0.58
# waistheightomphalion                                      0.15
# weightkg                                                  0.83
# wristcircumference                                        0.55
# wristheight                                               0.38
# DODRace                                                  -0.03
# Age                                                       0.39
#
#                                 acromialheight  acromionradialelength  \
# abdominalextensiondepthsitting            0.35                   0.31
# acromialheight                            1.00                   0.87
# acromionradialelength                     0.87                   1.00
# anklecircumference                        0.50                   0.42
# axillaheight                              0.99                   0.86
# balloffootcircumference                   0.69                   0.60
# balloffootlength                          0.80                   0.73
# biacromialbreadth                         0.73                   0.67
# bicepscircumferenceflexed                 0.52                   0.45
# bicristalbreadth                          0.40                   0.34
# bideltoidbreadth                          0.63                   0.56
# bimalleolarbreadth                        0.71                   0.61
# bitragionchinarc                          0.57                   0.52
# bitragionsubmandibulararc                 0.58                   0.51
# bizygomaticbreadth                        0.51                   0.46
# buttockcircumference                      0.28                   0.25
# buttockdepth                              0.34                   0.29
# buttockheight                             0.87                   0.81
# buttockkneelength                         0.81                   0.78
# buttockpopliteallength                    0.75                   0.74
# calfcircumference                         0.41                   0.35
# cervicaleheight                           0.98                   0.87
# chestbreadth                              0.54                   0.47
# chestcircumference                        0.53                   0.47
# chestdepth                                0.28                   0.27
# chestheight                               0.96                   0.84
# crotchheight                              0.90                   0.85
# crotchlengthomphalion                     0.34                   0.25
# crotchlengthposterioromphalion            0.41                   0.31
# earbreadth                                0.36                   0.31
# earlength                                 0.44                   0.37
# earprotrusion                             0.28                   0.23
# elbowrestheight                           0.29                  -0.00
# eyeheightsitting                          0.81                   0.64
# footbreadthhorizontal                     0.67                   0.59
# footlength                                0.83                   0.75
# forearmcenterofgriplength                 0.85                   0.82
# forearmcircumferenceflexed                0.64                   0.56
# forearmforearmbreadth                     0.57                   0.50
# forearmhandlength                         0.86                   0.84
# functionalleglength                       0.89                   0.82
# handbreadth                               0.71                   0.62
# handcircumference                         0.72                   0.63
# handlength                                0.75                   0.72
# headbreadth                               0.41                   0.35
# headcircumference                         0.43                   0.39
# headlength                                0.55                   0.48
# heelanklecircumference                    0.80                   0.71
# heelbreadth                               0.45                   0.44
# hipbreadth                                0.21                   0.18
# hipbreadthsitting                         0.10                   0.08
# iliocristaleheight                        0.93                   0.86
# interpupillarybreadth                     0.34                   0.34
# interscyei                                0.53                   0.47
# interscyeii                               0.59                   0.54
# kneeheightmidpatella                      0.90                   0.83
# kneeheightsitting                         0.93                   0.86
# lateralfemoralepicondyleheight            0.86                   0.81
# lateralmalleolusheight                    0.68                   0.55
# lowerthighcircumference                   0.33                   0.28
# mentonsellionlength                       0.54                   0.47
# neckcircumference                         0.63                   0.55
# neckcircumferencebase                     0.65                   0.57
# overheadfingertipreachsitting             0.87                   0.79
# palmlength                                0.71                   0.67
# poplitealheight                           0.89                   0.83
# radialestylionlength                      0.82                   0.80
# shouldercircumference                     0.69                   0.62
# shoulderelbowlength                       0.89                   0.97
# shoulderlength                            0.54                   0.51
# sittingheight                             0.82                   0.65
# sleevelengthspinewrist                    0.87                   0.87
# sleeveoutseam                             0.88                   0.94
# span                                      0.88                   0.89
# stature                                   0.98                   0.86
# suprasternaleheight                       0.98                   0.86
# tenthribheight                            0.95                   0.85
# thighcircumference                        0.28                   0.24
# thighclearance                            0.45                   0.38
# thumbtipreach                             0.80                   0.80
# tibialheight                              0.89                   0.83
# tragiontopofhead                          0.33                   0.29
# trochanterionheight                       0.88                   0.83
# verticaltrunkcircumferenceusa             0.73                   0.58
# waistbacklength                           0.73                   0.61
# waistbreadth                              0.44                   0.37
# waistcircumference                        0.41                   0.35
# waistdepth                                0.36                   0.33
# waistfrontlengthsitting                   0.61                   0.48
# waistheightomphalion                      0.93                   0.85
# weightkg                                  0.68                   0.60
# wristcircumference                        0.73                   0.64
# wristheight                               0.92                   0.68
# DODRace                                  -0.22                  -0.16
# Age                                       0.08                   0.08
#
#                                 anklecircumference  axillaheight  \
# abdominalextensiondepthsitting                0.52          0.28
# acromialheight                                0.50          0.99
# acromionradialelength                         0.42          0.86
# anklecircumference                            1.00          0.46
# axillaheight                                  0.46          1.00
# balloffootcircumference                       0.71          0.66
# balloffootlength                              0.56          0.79
# biacromialbreadth                             0.54          0.71
# bicepscircumferenceflexed                     0.64          0.46
# bicristalbreadth                              0.45          0.36
# bideltoidbreadth                              0.64          0.56
# bimalleolarbreadth                            0.69          0.68
# bitragionchinarc                              0.52          0.53
# bitragionsubmandibulararc                     0.53          0.52
# bizygomaticbreadth                            0.50          0.45
# buttockcircumference                          0.57          0.23
# buttockdepth                                  0.58          0.28
# buttockheight                                 0.36          0.88
# buttockkneelength                             0.50          0.81
# buttockpopliteallength                        0.33          0.76
# calfcircumference                             0.82          0.36
# cervicaleheight                               0.51          0.98
# chestbreadth                                  0.56          0.47
# chestcircumference                            0.61          0.45
# chestdepth                                    0.49          0.22
# chestheight                                   0.48          0.96
# crotchheight                                  0.38          0.92
# crotchlengthomphalion                         0.46          0.31
# crotchlengthposterioromphalion                0.38          0.40
# earbreadth                                    0.22          0.34
# earlength                                     0.37          0.40
# earprotrusion                                 0.24          0.26
# elbowrestheight                               0.31          0.24
# eyeheightsitting                              0.51          0.79
# footbreadthhorizontal                         0.65          0.64
# footlength                                    0.58          0.82
# forearmcenterofgriplength                     0.45          0.85
# forearmcircumferenceflexed                    0.66          0.58
# forearmforearmbreadth                         0.61          0.50
# forearmhandlength                             0.45          0.87
# functionalleglength                           0.51          0.89
# handbreadth                                   0.57          0.67
# handcircumference                             0.61          0.67
# handlength                                    0.45          0.76
# headbreadth                                   0.40          0.37
# headcircumference                             0.43          0.41
# headlength                                    0.43          0.53
# heelanklecircumference                        0.73          0.77
# heelbreadth                                   0.53          0.42
# hipbreadth                                    0.46          0.17
# hipbreadthsitting                             0.41          0.07
# iliocristaleheight                            0.42          0.95
# interpupillarybreadth                         0.24          0.33
# interscyei                                    0.51          0.47
# interscyeii                                   0.52          0.55
# kneeheightmidpatella                          0.41          0.90
# kneeheightsitting                             0.51          0.93
# lateralfemoralepicondyleheight                0.38          0.87
# lateralmalleolusheight                        0.49          0.65
# lowerthighcircumference                       0.70          0.28
# mentonsellionlength                           0.40          0.51
# neckcircumference                             0.57          0.56
# neckcircumferencebase                         0.58          0.59
# overheadfingertipreachsitting                 0.50          0.86
# palmlength                                    0.45          0.70
# poplitealheight                               0.35          0.91
# radialestylionlength                          0.39          0.83
# shouldercircumference                         0.63          0.64
# shoulderelbowlength                           0.42          0.88
# shoulderlength                                0.35          0.55
# sittingheight                                 0.52          0.80
# sleevelengthspinewrist                        0.54          0.85
# sleeveoutseam                                 0.41          0.88
# span                                          0.46          0.88
# stature                                       0.51          0.98
# suprasternaleheight                           0.52          0.98
# tenthribheight                                0.44          0.95
# thighcircumference                            0.59          0.23
# thighclearance                                0.65          0.39
# thumbtipreach                                 0.46          0.80
# tibialheight                                  0.40          0.90
# tragiontopofhead                              0.30          0.31
# trochanterionheight                           0.37          0.90
# verticaltrunkcircumferenceusa                 0.67          0.68
# waistbacklength                               0.51          0.68
# waistbreadth                                  0.59          0.36
# waistcircumference                            0.56          0.33
# waistdepth                                    0.51          0.29
# waistfrontlengthsitting                       0.48          0.57
# waistheightomphalion                          0.41          0.95
# weightkg                                      0.74          0.61
# wristcircumference                            0.70          0.69
# wristheight                                   0.51          0.90
# DODRace                                      -0.16         -0.21
# Age                                          -0.03          0.04
#
#                                 balloffootcircumference  balloffootlength  \
# abdominalextensiondepthsitting                     0.46              0.33
# acromialheight                                     0.69              0.80
# acromionradialelength                              0.60              0.73
# anklecircumference                                 0.71              0.56
# axillaheight                                       0.66              0.79
# balloffootcircumference                            1.00              0.74
# balloffootlength                                   0.74              1.00
# biacromialbreadth                                  0.74              0.74
# bicepscircumferenceflexed                          0.66              0.57
# bicristalbreadth                                   0.34              0.29
# bideltoidbreadth                                   0.72              0.63
# bimalleolarbreadth                                 0.80              0.77
# bitragionchinarc                                   0.66              0.62
# bitragionsubmandibulararc                          0.65              0.59
# bizygomaticbreadth                                 0.62              0.54
# buttockcircumference                               0.36              0.25
# buttockdepth                                       0.46              0.34
# buttockheight                                      0.55              0.73
# buttockkneelength                                  0.58              0.71
# buttockpopliteallength                             0.44              0.65
# calfcircumference                                  0.62              0.46
# cervicaleheight                                    0.71              0.82
# chestbreadth                                       0.58              0.50
# chestcircumference                                 0.63              0.52
# chestdepth                                         0.37              0.27
# chestheight                                        0.70              0.81
# crotchheight                                       0.59              0.78
# crotchlengthomphalion                              0.33              0.23
# crotchlengthposterioromphalion                     0.35              0.28
# earbreadth                                         0.37              0.39
# earlength                                          0.47              0.39
# earprotrusion                                      0.31              0.26
# elbowrestheight                                    0.25              0.12
# eyeheightsitting                                   0.65              0.63
# footbreadthhorizontal                              0.92              0.73
# footlength                                         0.78              0.96
# forearmcenterofgriplength                          0.67              0.81
# forearmcircumferenceflexed                         0.76              0.68
# forearmforearmbreadth                              0.67              0.57
# forearmhandlength                                  0.69              0.85
# functionalleglength                                0.67              0.77
# handbreadth                                        0.82              0.74
# handcircumference                                  0.84              0.75
# handlength                                         0.66              0.79
# headbreadth                                        0.51              0.45
# headcircumference                                  0.50              0.47
# headlength                                         0.58              0.57
# heelanklecircumference                             0.86              0.87
# heelbreadth                                        0.63              0.62
# hipbreadth                                         0.23              0.14
# hipbreadthsitting                                  0.14              0.05
# iliocristaleheight                                 0.61              0.77
# interpupillarybreadth                              0.37              0.41
# interscyei                                         0.60              0.54
# interscyeii                                        0.64              0.60
# kneeheightmidpatella                               0.62              0.78
# kneeheightsitting                                  0.70              0.82
# lateralfemoralepicondyleheight                     0.55              0.73
# lateralmalleolusheight                             0.64              0.57
# lowerthighcircumference                            0.49              0.36
# mentonsellionlength                                0.57              0.57
# neckcircumference                                  0.73              0.65
# neckcircumferencebase                              0.73              0.66
# overheadfingertipreachsitting                      0.68              0.72
# palmlength                                         0.62              0.75
# poplitealheight                                    0.62              0.78
# radialestylionlength                               0.63              0.79
# shouldercircumference                              0.76              0.71
# shoulderelbowlength                                0.64              0.75
# shoulderlength                                     0.53              0.56
# sittingheight                                      0.66              0.65
# sleevelengthspinewrist                             0.75              0.82
# sleeveoutseam                                      0.63              0.78
# span                                               0.69              0.82
# stature                                            0.71              0.81
# suprasternaleheight                                0.71              0.81
# tenthribheight                                     0.62              0.78
# thighcircumference                                 0.40              0.29
# thighclearance                                     0.57              0.45
# thumbtipreach                                      0.64              0.75
# tibialheight                                       0.59              0.74
# tragiontopofhead                                   0.34              0.33
# trochanterionheight                                0.57              0.74
# verticaltrunkcircumferenceusa                      0.68              0.59
# waistbacklength                                    0.64              0.63
# waistbreadth                                       0.51              0.38
# waistcircumference                                 0.49              0.37
# waistdepth                                         0.46              0.35
# waistfrontlengthsitting                            0.55              0.46
# waistheightomphalion                               0.62              0.78
# weightkg                                           0.73              0.65
# wristcircumference                                 0.83              0.74
# wristheight                                        0.63              0.68
# DODRace                                           -0.11             -0.06
# Age                                                0.08              0.03
#
#                                 biacromialbreadth  bicepscircumferenceflexed  \
# abdominalextensiondepthsitting               0.42                       0.69
# acromialheight                               0.73                       0.52
# acromionradialelength                        0.67                       0.45
# anklecircumference                           0.54                       0.64
# axillaheight                                 0.71                       0.46
# balloffootcircumference                      0.74                       0.66
# balloffootlength                             0.74                       0.57
# biacromialbreadth                            1.00                       0.66
# bicepscircumferenceflexed                    0.66                       1.00
# bicristalbreadth                             0.28                       0.39
# bideltoidbreadth                             0.83                       0.87
# bimalleolarbreadth                           0.72                       0.60
# bitragionchinarc                             0.67                       0.68
# bitragionsubmandibulararc                    0.67                       0.71
# bizygomaticbreadth                           0.63                       0.64
# buttockcircumference                         0.26                       0.60
# buttockdepth                                 0.39                       0.70
# buttockheight                                0.61                       0.40
# buttockkneelength                            0.59                       0.55
# buttockpopliteallength                       0.48                       0.39
# calfcircumference                            0.47                       0.72
# cervicaleheight                              0.78                       0.53
# chestbreadth                                 0.65                       0.66
# chestcircumference                           0.64                       0.84
# chestdepth                                   0.29                       0.66
# chestheight                                  0.77                       0.51
# crotchheight                                 0.65                       0.40
# crotchlengthomphalion                        0.26                       0.40
# crotchlengthposterioromphalion               0.34                       0.30
# earbreadth                                   0.39                       0.32
# earlength                                    0.47                       0.41
# earprotrusion                                0.34                       0.23
# elbowrestheight                              0.18                       0.28
# eyeheightsitting                             0.70                       0.47
# footbreadthhorizontal                        0.71                       0.64
# footlength                                   0.76                       0.58
# forearmcenterofgriplength                    0.74                       0.56
# forearmcircumferenceflexed                   0.76                       0.91
# forearmforearmbreadth                        0.70                       0.86
# forearmhandlength                            0.75                       0.54
# functionalleglength                          0.71                       0.55
# handbreadth                                  0.77                       0.67
# handcircumference                            0.79                       0.71
# handlength                                   0.65                       0.49
# headbreadth                                  0.52                       0.49
# headcircumference                            0.47                       0.45
# headlength                                   0.58                       0.49
# heelanklecircumference                       0.78                       0.70
# heelbreadth                                  0.52                       0.58
# hipbreadth                                   0.13                       0.42
# hipbreadthsitting                            0.01                       0.36
# iliocristaleheight                           0.66                       0.43
# interpupillarybreadth                        0.38                       0.36
# interscyei                                   0.71                       0.70
# interscyeii                                  0.80                       0.68
# kneeheightmidpatella                         0.67                       0.45
# kneeheightsitting                            0.73                       0.53
# lateralfemoralepicondyleheight               0.58                       0.37
# lateralmalleolusheight                       0.63                       0.50
# lowerthighcircumference                      0.33                       0.66
# mentonsellionlength                          0.58                       0.47
# neckcircumference                            0.79                       0.82
# neckcircumferencebase                        0.80                       0.80
# overheadfingertipreachsitting                0.77                       0.51
# palmlength                                   0.64                       0.49
# poplitealheight                              0.69                       0.38
# radialestylionlength                         0.71                       0.49
# shouldercircumference                        0.90                       0.86
# shoulderelbowlength                          0.71                       0.46
# shoulderlength                               0.78                       0.39
# sittingheight                                0.70                       0.47
# sleevelengthspinewrist                       0.86                       0.64
# sleeveoutseam                                0.71                       0.46
# span                                         0.80                       0.53
# stature                                      0.77                       0.51
# suprasternaleheight                          0.76                       0.54
# tenthribheight                               0.67                       0.45
# thighcircumference                           0.30                       0.68
# thighclearance                               0.51                       0.78
# thumbtipreach                                0.71                       0.54
# tibialheight                                 0.63                       0.41
# tragiontopofhead                             0.35                       0.28
# trochanterionheight                          0.62                       0.39
# verticaltrunkcircumferenceusa                0.66                       0.73
# waistbacklength                              0.69                       0.61
# waistbreadth                                 0.47                       0.71
# waistcircumference                           0.46                       0.73
# waistdepth                                   0.43                       0.70
# waistfrontlengthsitting                      0.55                       0.56
# waistheightomphalion                         0.69                       0.41
# weightkg                                     0.70                       0.88
# wristcircumference                           0.80                       0.76
# wristheight                                  0.62                       0.50
# DODRace                                     -0.11                      -0.03
# Age                                          0.07                       0.22
#
#                                 bicristalbreadth  bideltoidbreadth  \
# abdominalextensiondepthsitting              0.51              0.72
# acromialheight                              0.40              0.63
# acromionradialelength                       0.34              0.56
# anklecircumference                          0.45              0.64
# axillaheight                                0.36              0.56
# balloffootcircumference                     0.34              0.72
# balloffootlength                            0.29              0.63
# biacromialbreadth                           0.28              0.83
# bicepscircumferenceflexed                   0.39              0.87
# bicristalbreadth                            1.00              0.46
# bideltoidbreadth                            0.46              1.00
# bimalleolarbreadth                          0.30              0.66
# bitragionchinarc                            0.26              0.72
# bitragionsubmandibulararc                   0.33              0.77
# bizygomaticbreadth                          0.31              0.70
# buttockcircumference                        0.65              0.58
# buttockdepth                                0.52              0.70
# buttockheight                               0.30              0.47
# buttockkneelength                           0.44              0.60
# buttockpopliteallength                      0.36              0.44
# calfcircumference                           0.49              0.69
# cervicaleheight                             0.37              0.64
# chestbreadth                                0.56              0.81
# chestcircumference                          0.54              0.90
# chestdepth                                  0.57              0.63
# chestheight                                 0.30              0.61
# crotchheight                                0.25              0.48
# crotchlengthomphalion                       0.43              0.44
# crotchlengthposterioromphalion              0.23              0.34
# earbreadth                                  0.16              0.36
# earlength                                   0.27              0.49
# earprotrusion                               0.09              0.29
# elbowrestheight                             0.34              0.32
# eyeheightsitting                            0.37              0.58
# footbreadthhorizontal                       0.31              0.69
# footlength                                  0.29              0.65
# forearmcenterofgriplength                   0.25              0.62
# forearmcircumferenceflexed                  0.34              0.87
# forearmforearmbreadth                       0.45              0.93
# forearmhandlength                           0.25              0.60
# functionalleglength                         0.36              0.64
# handbreadth                                 0.26              0.72
# handcircumference                           0.27              0.75
# handlength                                  0.25              0.54
# headbreadth                                 0.23              0.54
# headcircumference                           0.23              0.49
# headlength                                  0.19              0.54
# heelanklecircumference                      0.36              0.76
# heelbreadth                                 0.18              0.57
# hipbreadth                                  0.69              0.42
# hipbreadthsitting                           0.60              0.32
# iliocristaleheight                          0.32              0.51
# interpupillarybreadth                       0.08              0.37
# interscyei                                  0.36              0.82
# interscyeii                                 0.34              0.82
# kneeheightmidpatella                        0.30              0.53
# kneeheightsitting                           0.34              0.61
# lateralfemoralepicondyleheight              0.32              0.45
# lateralmalleolusheight                      0.27              0.57
# lowerthighcircumference                     0.52              0.60
# mentonsellionlength                         0.20              0.52
# neckcircumference                           0.32              0.87
# neckcircumferencebase                       0.33              0.86
# overheadfingertipreachsitting               0.31              0.63
# palmlength                                  0.23              0.54
# poplitealheight                             0.21              0.49
# radialestylionlength                        0.21              0.56
# shouldercircumference                       0.38              0.95
# shoulderelbowlength                         0.31              0.57
# shoulderlength                              0.17              0.54
# sittingheight                               0.39              0.58
# sleevelengthspinewrist                      0.34              0.76
# sleeveoutseam                               0.28              0.57
# span                                        0.27              0.64
# stature                                     0.37              0.62
# suprasternaleheight                         0.38              0.64
# tenthribheight                              0.38              0.54
# thighcircumference                          0.54              0.63
# thighclearance                              0.44              0.75
# thumbtipreach                               0.30              0.62
# tibialheight                                0.31              0.50
# tragiontopofhead                            0.21              0.33
# trochanterionheight                         0.28              0.47
# verticaltrunkcircumferenceusa               0.60              0.80
# waistbacklength                             0.46              0.70
# waistbreadth                                0.70              0.77
# waistcircumference                          0.63              0.78
# waistdepth                                  0.53              0.73
# waistfrontlengthsitting                     0.41              0.63
# waistheightomphalion                        0.25              0.50
# weightkg                                    0.58              0.91
# wristcircumference                          0.35              0.81
# wristheight                                 0.46              0.59
# DODRace                                    -0.20             -0.07
# Age                                         0.14              0.21
#
#                                 bimalleolarbreadth  bitragionchinarc  \
# abdominalextensiondepthsitting                0.37              0.53
# acromialheight                                0.71              0.57
# acromionradialelength                         0.61              0.52
# anklecircumference                            0.69              0.52
# axillaheight                                  0.68              0.53
# balloffootcircumference                       0.80              0.66
# balloffootlength                              0.77              0.62
# biacromialbreadth                             0.72              0.67
# bicepscircumferenceflexed                     0.60              0.68
# bicristalbreadth                              0.30              0.26
# bideltoidbreadth                              0.66              0.72
# bimalleolarbreadth                            1.00              0.59
# bitragionchinarc                              0.59              1.00
# bitragionsubmandibulararc                     0.60              0.85
# bizygomaticbreadth                            0.58              0.72
# buttockcircumference                          0.27              0.39
# buttockdepth                                  0.36              0.52
# buttockheight                                 0.56              0.48
# buttockkneelength                             0.57              0.55
# buttockpopliteallength                        0.45              0.42
# calfcircumference                             0.56              0.53
# cervicaleheight                               0.73              0.58
# chestbreadth                                  0.53              0.56
# chestcircumference                            0.55              0.66
# chestdepth                                    0.28              0.45
# chestheight                                   0.72              0.57
# crotchheight                                  0.62              0.49
# crotchlengthomphalion                         0.26              0.30
# crotchlengthposterioromphalion                0.32              0.28
# earbreadth                                    0.31              0.36
# earlength                                     0.42              0.46
# earprotrusion                                 0.31              0.20
# elbowrestheight                               0.24              0.16
# eyeheightsitting                              0.66              0.47
# footbreadthhorizontal                         0.76              0.64
# footlength                                    0.78              0.64
# forearmcenterofgriplength                     0.68              0.64
# forearmcircumferenceflexed                    0.71              0.72
# forearmforearmbreadth                         0.61              0.67
# forearmhandlength                             0.69              0.63
# functionalleglength                           0.67              0.58
# handbreadth                                   0.76              0.65
# handcircumference                             0.78              0.68
# handlength                                    0.63              0.58
# headbreadth                                   0.49              0.51
# headcircumference                             0.46              0.58
# headlength                                    0.54              0.59
# heelanklecircumference                        0.83              0.71
# heelbreadth                                   0.61              0.59
# hipbreadth                                    0.16              0.23
# hipbreadthsitting                             0.05              0.17
# iliocristaleheight                            0.62              0.51
# interpupillarybreadth                         0.33              0.50
# interscyei                                    0.57              0.59
# interscyeii                                   0.62              0.61
# kneeheightmidpatella                          0.63              0.53
# kneeheightsitting                             0.70              0.59
# lateralfemoralepicondyleheight                0.57              0.46
# lateralmalleolusheight                        0.59              0.49
# lowerthighcircumference                       0.43              0.48
# mentonsellionlength                           0.55              0.56
# neckcircumference                             0.67              0.74
# neckcircumferencebase                         0.68              0.72
# overheadfingertipreachsitting                 0.68              0.57
# palmlength                                    0.62              0.57
# poplitealheight                               0.65              0.49
# radialestylionlength                          0.64              0.58
# shouldercircumference                         0.72              0.74
# shoulderelbowlength                           0.65              0.54
# shoulderlength                                0.54              0.45
# sittingheight                                 0.67              0.48
# sleevelengthspinewrist                        0.74              0.67
# sleeveoutseam                                 0.65              0.55
# span                                          0.70              0.62
# stature                                       0.73              0.56
# suprasternaleheight                           0.72              0.58
# tenthribheight                                0.63              0.51
# thighcircumference                            0.31              0.44
# thighclearance                                0.50              0.58
# thumbtipreach                                 0.64              0.59
# tibialheight                                  0.59              0.50
# tragiontopofhead                              0.35              0.26
# trochanterionheight                           0.58              0.49
# verticaltrunkcircumferenceusa                 0.62              0.62
# waistbacklength                               0.63              0.56
# waistbreadth                                  0.43              0.51
# ...
# headlength                                         0.42                  0.50
# heelanklecircumference                             0.58                  0.73
# heelbreadth                                        0.37                  0.40
# hipbreadth                                         0.34                  0.08
# hipbreadthsitting                                  0.28                 -0.01
# iliocristaleheight                                 0.47                  0.94
# interpupillarybreadth                              0.23                  0.32
# interscyei                                         0.51                  0.43
# interscyeii                                        0.53                  0.52
# kneeheightmidpatella                               0.43                  0.91
# kneeheightsitting                                  0.51                  0.93
# lateralfemoralepicondyleheight                     0.37                  0.89
# lateralmalleolusheight                             0.50                  0.61
# lowerthighcircumference                            0.41                  0.21
# mentonsellionlength                                0.39                  0.49
# neckcircumference                                  0.60                  0.50
# neckcircumferencebase                              0.61                  0.53
# overheadfingertipreachsitting                      0.66                  0.81
# palmlength                                         0.42                  0.69
# poplitealheight                                    0.40                  0.93
# radialestylionlength                               0.43                  0.83
# shouldercircumference                              0.63                  0.60
# shoulderelbowlength                                0.50                  0.87
# shoulderlength                                     0.41                  0.58
# sittingheight                                      0.70                  0.71
# sleevelengthspinewrist                             0.56                  0.84
# sleeveoutseam                                      0.46                  0.88
# span                                               0.52                  0.88
# stature                                            0.61                  0.94
# suprasternaleheight                                0.64                  0.94
# tenthribheight                                     0.48                  0.94
# thighcircumference                                 0.39                  0.15
# thighclearance                                     0.48                  0.32
# thumbtipreach                                      0.50                  0.78
# tibialheight                                       0.45                  0.91
# tragiontopofhead                                   0.25                  0.29
# trochanterionheight                                0.41                  0.91
# verticaltrunkcircumferenceusa                      0.75                  0.54
# waistbacklength                                    0.72                  0.52
# waistbreadth                                       0.61                  0.23
# waistcircumference                                 0.62                  0.19
# waistdepth                                         0.59                  0.15
# waistfrontlengthsitting                            1.00                  0.39
# waistheightomphalion                               0.39                  1.00
# weightkg                                           0.68                  0.52
# wristcircumference                                 0.62                  0.63
# wristheight                                        0.62                  0.81
# DODRace                                           -0.16                 -0.17
# Age                                                0.26                 -0.03
#
#                                 weightkg  wristcircumference  wristheight  \
# abdominalextensiondepthsitting      0.83                0.55         0.38
# acromialheight                      0.68                0.73         0.92
# acromionradialelength               0.60                0.64         0.68
# anklecircumference                  0.74                0.70         0.51
# axillaheight                        0.61                0.69         0.90
# balloffootcircumference             0.73                0.83         0.63
# balloffootlength                    0.65                0.74         0.68
# biacromialbreadth                   0.70                0.80         0.62
# bicepscircumferenceflexed           0.88                0.76         0.50
# bicristalbreadth                    0.58                0.35         0.46
# bideltoidbreadth                    0.91                0.81         0.59
# bimalleolarbreadth                  0.66                0.80         0.63
# bitragionchinarc                    0.71                0.70         0.50
# bitragionsubmandibulararc           0.77                0.73         0.55
# bizygomaticbreadth                  0.68                0.67         0.46
# buttockcircumference                0.77                0.37         0.34
# buttockdepth                        0.84                0.51         0.38
# buttockheight                       0.53                0.57         0.74
# buttockkneelength                   0.71                0.60         0.71
# buttockpopliteallength              0.54                0.44         0.64
# calfcircumference                   0.82                0.61         0.43
# cervicaleheight                     0.67                0.76         0.89
# chestbreadth                        0.77                0.64         0.55
# chestcircumference                  0.92                0.72         0.53
# chestdepth                          0.76                0.43         0.32
# chestheight                         0.63                0.74         0.86
# crotchheight                        0.51                0.60         0.75
# crotchlengthomphalion               0.58                0.34         0.42
# crotchlengthposterioromphalion      0.40                0.36         0.41
# earbreadth                          0.34                0.39         0.33
# earlength                           0.48                0.52         0.42
# earprotrusion                       0.24                0.35         0.25
# elbowrestheight                     0.36                0.30         0.50
# eyeheightsitting                    0.59                0.71         0.80
# footbreadthhorizontal               0.70                0.79         0.60
# footlength                          0.66                0.78         0.71
# forearmcenterofgriplength           0.63                0.73         0.66
# forearmcircumferenceflexed          0.86                0.87         0.59
# forearmforearmbreadth               0.87                0.77         0.55
# forearmhandlength                   0.62                0.73         0.68
# functionalleglength                 0.68                0.70         0.78
# handbreadth                         0.69                0.87         0.63
# handcircumference                   0.72                0.90         0.63
# handlength                          0.58                0.68         0.62
# headbreadth                         0.52                0.53         0.37
# headcircumference                   0.53                0.48         0.38
# headlength                          0.54                0.58         0.49
# heelanklecircumference              0.79                0.86         0.71
# heelbreadth                         0.61                0.57         0.36
# hipbreadth                          0.61                0.23         0.28
# hipbreadthsitting                   0.54                0.11         0.18
# iliocristaleheight                  0.57                0.63         0.82
# interpupillarybreadth               0.38                0.37         0.25
# interscyei                          0.74                0.69         0.50
# interscyeii                         0.73                0.72         0.53
# kneeheightmidpatella                0.57                0.64         0.77
# kneeheightsitting                   0.66                0.72         0.81
# lateralfemoralepicondyleheight      0.52                0.55         0.74
# lateralmalleolusheight              0.56                0.68         0.63
# lowerthighcircumference             0.78                0.50         0.37
# mentonsellionlength                 0.50                0.57         0.47
# neckcircumference                   0.82                0.84         0.58
# neckcircumferencebase               0.82                0.84         0.60
# overheadfingertipreachsitting       0.63                0.74         0.74
# palmlength                          0.57                0.65         0.58
# poplitealheight                     0.48                0.63         0.75
# radialestylionlength                0.57                0.67         0.61
# shouldercircumference               0.87                0.85         0.62
# shoulderelbowlength                 0.59                0.68         0.70
# shoulderlength                      0.43                0.55         0.42
# sittingheight                       0.60                0.71         0.81
# sleevelengthspinewrist              0.73                0.80         0.70
# sleeveoutseam                       0.58                0.66         0.66
# span                                0.63                0.74         0.69
# stature                             0.65                0.75         0.89
# suprasternaleheight                 0.68                0.75         0.90
# tenthribheight                      0.61                0.63         0.85
# thighcircumference                  0.79                0.41         0.32
# thighclearance                      0.84                0.61         0.45
# thumbtipreach                       0.64                0.70         0.63
# tibialheight                        0.55                0.60         0.76
# tragiontopofhead                    0.33                0.35         0.30
# trochanterionheight                 0.53                0.58         0.75
# verticaltrunkcircumferenceusa       0.90                0.75         0.77
# waistbacklength                     0.72                0.72         0.70
# waistbreadth                        0.86                0.58         0.48
# waistcircumference                  0.87                0.58         0.44
# waistdepth                          0.83                0.55         0.39
# waistfrontlengthsitting             0.68                0.62         0.62
# waistheightomphalion                0.52                0.63         0.81
# weightkg                            1.00                0.80         0.67
# wristcircumference                  0.80                1.00         0.66
# wristheight                         0.67                0.66         1.00
# DODRace                            -0.10               -0.17        -0.27
# Age                                 0.23                0.15         0.11
#
#                                 DODRace   Age
# abdominalextensiondepthsitting    -0.03  0.39
# acromialheight                    -0.22  0.08
# acromionradialelength             -0.16  0.08
# anklecircumference                -0.16 -0.03
# axillaheight                      -0.21  0.04
# balloffootcircumference           -0.11  0.08
# balloffootlength                  -0.06  0.03
# biacromialbreadth                 -0.11  0.07
# bicepscircumferenceflexed         -0.03  0.22
# bicristalbreadth                  -0.20  0.14
# bideltoidbreadth                  -0.07  0.21
# bimalleolarbreadth                -0.11  0.01
# bitragionchinarc                   0.08  0.20
# bitragionsubmandibulararc         -0.02  0.25
# bizygomaticbreadth                 0.03  0.13
# buttockcircumference              -0.03  0.20
# buttockdepth                      -0.00  0.27
# buttockheight                     -0.10  0.06
# buttockkneelength                 -0.07  0.10
# buttockpopliteallength            -0.04  0.06
# calfcircumference                 -0.09  0.13
# cervicaleheight                   -0.22  0.07
# chestbreadth                      -0.16  0.23
# chestcircumference                -0.08  0.33
# chestdepth                        -0.03  0.34
# chestheight                       -0.19  0.02
# crotchheight                      -0.11 -0.00
# crotchlengthomphalion             -0.12  0.07
# crotchlengthposterioromphalion    -0.14 -0.06
# earbreadth                        -0.06  0.19
# earlength                         -0.09  0.30
# earprotrusion                     -0.10 -0.01
# elbowrestheight                   -0.23  0.07
# eyeheightsitting                  -0.32  0.04
# footbreadthhorizontal             -0.05  0.07
# footlength                        -0.07  0.06
# forearmcenterofgriplength         -0.03  0.08
# forearmcircumferenceflexed        -0.09  0.19
# forearmforearmbreadth             -0.09  0.24
# forearmhandlength                 -0.04  0.07
# functionalleglength               -0.12  0.05
# handbreadth                       -0.16  0.14
# handcircumference                 -0.15  0.16
# handlength                        -0.03  0.12
# headbreadth                       -0.01  0.05
# headcircumference                  0.01  0.02
# headlength                        -0.11  0.05
# heelanklecircumference            -0.07  0.11
# heelbreadth                        0.17  0.11
# hipbreadth                        -0.07  0.18
# hipbreadthsitting                 -0.01  0.18
# iliocristaleheight                -0.15  0.06
# interpupillarybreadth              0.19  0.16
# interscyei                        -0.12  0.20
# interscyeii                       -0.12  0.16
# kneeheightmidpatella              -0.11  0.05
# kneeheightsitting                 -0.12  0.08
# lateralfemoralepicondyleheight    -0.09  0.03
# lateralmalleolusheight            -0.22  0.08
# lowerthighcircumference           -0.00  0.16
# mentonsellionlength               -0.02  0.10
# neckcircumference                 -0.10  0.23
# neckcircumferencebase             -0.11  0.20
# overheadfingertipreachsitting     -0.17  0.05
# palmlength                         0.00  0.13
# poplitealheight                   -0.13 -0.01
# radialestylionlength              -0.02  0.04
# shouldercircumference             -0.08  0.15
# shoulderelbowlength               -0.18  0.08
# shoulderlength                    -0.08  0.00
# sittingheight                     -0.32  0.00
# sleevelengthspinewrist            -0.12  0.08
# sleeveoutseam                     -0.10  0.04
# span                              -0.08  0.07
# stature                           -0.23  0.04
# suprasternaleheight               -0.20  0.07
# tenthribheight                    -0.16  0.04
# thighcircumference                 0.03  0.15
# thighclearance                    -0.00  0.09
# thumbtipreach                     -0.07  0.11
# tibialheight                      -0.11  0.05
# tragiontopofhead                  -0.05 -0.05
# trochanterionheight               -0.10  0.06
# verticaltrunkcircumferenceusa     -0.20  0.23
# waistbacklength                   -0.21  0.22
# waistbreadth                      -0.13  0.29
# waistcircumference                -0.07  0.37
# waistdepth                        -0.03  0.39
# waistfrontlengthsitting           -0.16  0.26
# waistheightomphalion              -0.17 -0.03
# weightkg                          -0.10  0.23
# wristcircumference                -0.17  0.15
# wristheight                       -0.27  0.11
# DODRace                            1.00  0.01
# Age                                0.01  1.00

# %%
def check_multicolinarity(data):
    ''' data = numeric list like object or pd.Dataframe'''
    def color_red(val):
        color = ('red' if abs(val) >= 0.9 and val < 1 else 'black')
        return f'color: {color}'

    df = pd.DataFrame(data)
    df_corr = df.corr().applymap(lambda x: x if abs(x)>=0.9 and x<1 else np.NaN).dropna(how='all').dropna(how='all', axis=1)
    
    print(f'Multicolinarity Data', df_corr.shape)
    return df_corr.style.applymap(color_red)

check_multicolinarity(df)
# Out:
# Multicolinarity Data (59, 59)
# <style type="text/css">
# #T_3a80a_row0_col0, #T_3a80a_row0_col1, #T_3a80a_row0_col2, #T_3a80a_row0_col3, #T_3a80a_row0_col4, #T_3a80a_row0_col5, #T_3a80a_row0_col6, #T_3a80a_row0_col7, #T_3a80a_row0_col8, #T_3a80a_row0_col9, #T_3a80a_row0_col10, #T_3a80a_row0_col11, #T_3a80a_row0_col12, #T_3a80a_row0_col13, #T_3a80a_row0_col14, #T_3a80a_row0_col15, #T_3a80a_row0_col16, #T_3a80a_row0_col17, #T_3a80a_row0_col18, #T_3a80a_row0_col19, #T_3a80a_row0_col20, #T_3a80a_row0_col21, #T_3a80a_row0_col22, #T_3a80a_row0_col23, #T_3a80a_row0_col24, #T_3a80a_row0_col25, #T_3a80a_row0_col26, #T_3a80a_row0_col27, #T_3a80a_row0_col28, #T_3a80a_row0_col29, #T_3a80a_row0_col30, #T_3a80a_row0_col31, #T_3a80a_row0_col32, #T_3a80a_row0_col33, #T_3a80a_row0_col34, #T_3a80a_row0_col35, #T_3a80a_row0_col36, #T_3a80a_row0_col37, #T_3a80a_row0_col38, #T_3a80a_row0_col39, #T_3a80a_row0_col40, #T_3a80a_row0_col41, #T_3a80a_row0_col42, #T_3a80a_row0_col43, #T_3a80a_row0_col44, #T_3a80a_row0_col45, #T_3a80a_row0_col46, #T_3a80a_row0_col47, #T_3a80a_row0_col48, #T_3a80a_row0_col49, #T_3a80a_row0_col50, #T_3a80a_row0_col51, #T_3a80a_row0_col52, #T_3a80a_row0_col55, #T_3a80a_row0_col56, #T_3a80a_row0_col57, #T_3a80a_row0_col58, #T_3a80a_row1_col0, #T_3a80a_row1_col1, #T_3a80a_row1_col2, #T_3a80a_row1_col4, #T_3a80a_row1_col5, #T_3a80a_row1_col6, #T_3a80a_row1_col7, #T_3a80a_row1_col8, #T_3a80a_row1_col9, #T_3a80a_row1_col10, #T_3a80a_row1_col11, #T_3a80a_row1_col12, #T_3a80a_row1_col14, #T_3a80a_row1_col16, #T_3a80a_row1_col17, #T_3a80a_row1_col18, #T_3a80a_row1_col19, #T_3a80a_row1_col20, #T_3a80a_row1_col21, #T_3a80a_row1_col22, #T_3a80a_row1_col23, #T_3a80a_row1_col24, #T_3a80a_row1_col25, #T_3a80a_row1_col26, #T_3a80a_row1_col27, #T_3a80a_row1_col28, #T_3a80a_row1_col30, #T_3a80a_row1_col31, #T_3a80a_row1_col32, #T_3a80a_row1_col34, #T_3a80a_row1_col35, #T_3a80a_row1_col36, #T_3a80a_row1_col37, #T_3a80a_row1_col38, #T_3a80a_row1_col39, #T_3a80a_row1_col40, #T_3a80a_row1_col41, #T_3a80a_row1_col42, #T_3a80a_row1_col43, #T_3a80a_row1_col44, #T_3a80a_row1_col48, #T_3a80a_row1_col49, #T_3a80a_row1_col50, #T_3a80a_row1_col51, #T_3a80a_row1_col52, #T_3a80a_row1_col53, #T_3a80a_row1_col54, #T_3a80a_row1_col56, #T_3a80a_row1_col57, #T_3a80a_row2_col0, #T_3a80a_row2_col1, #T_3a80a_row2_col2, #T_3a80a_row2_col3, #T_3a80a_row2_col4, #T_3a80a_row2_col5, #T_3a80a_row2_col6, #T_3a80a_row2_col7, #T_3a80a_row2_col8, #T_3a80a_row2_col9, #T_3a80a_row2_col10, #T_3a80a_row2_col11, #T_3a80a_row2_col12, #T_3a80a_row2_col13, #T_3a80a_row2_col14, #T_3a80a_row2_col15, #T_3a80a_row2_col16, #T_3a80a_row2_col17, #T_3a80a_row2_col18, #T_3a80a_row2_col19, #T_3a80a_row2_col20, #T_3a80a_row2_col21, #T_3a80a_row2_col22, #T_3a80a_row2_col23, #T_3a80a_row2_col24, #T_3a80a_row2_col25, #T_3a80a_row2_col26, #T_3a80a_row2_col27, #T_3a80a_row2_col28, #T_3a80a_row2_col29, #T_3a80a_row2_col30, #T_3a80a_row2_col31, #T_3a80a_row2_col32, #T_3a80a_row2_col33, #T_3a80a_row2_col34, #T_3a80a_row2_col35, #T_3a80a_row2_col36, #T_3a80a_row2_col37, #T_3a80a_row2_col38, #T_3a80a_row2_col39, #T_3a80a_row2_col41, #T_3a80a_row2_col42, #T_3a80a_row2_col44, #T_3a80a_row2_col45, #T_3a80a_row2_col46, #T_3a80a_row2_col47, #T_3a80a_row2_col48, #T_3a80a_row2_col49, #T_3a80a_row2_col50, #T_3a80a_row2_col51, #T_3a80a_row2_col52, #T_3a80a_row2_col53, #T_3a80a_row2_col54, #T_3a80a_row2_col55, #T_3a80a_row2_col56, #T_3a80a_row2_col57, #T_3a80a_row2_col58, #T_3a80a_row3_col0, #T_3a80a_row3_col2, #T_3a80a_row3_col3, #T_3a80a_row3_col4, #T_3a80a_row3_col5, #T_3a80a_row3_col6, #T_3a80a_row3_col7, #T_3a80a_row3_col8, #T_3a80a_row3_col9, #T_3a80a_row3_col10, #T_3a80a_row3_col11, #T_3a80a_row3_col12, #T_3a80a_row3_col14, #T_3a80a_row3_col17, #T_3a80a_row3_col18, #T_3a80a_row3_col19, #T_3a80a_row3_col20, #T_3a80a_row3_col21, #T_3a80a_row3_col22, #T_3a80a_row3_col23, #T_3a80a_row3_col24, #T_3a80a_row3_col25, #T_3a80a_row3_col26, #T_3a80a_row3_col27, #T_3a80a_row3_col28, #T_3a80a_row3_col30, #T_3a80a_row3_col31, #T_3a80a_row3_col34, #T_3a80a_row3_col35, #T_3a8 ...

# %%
df.corr()[(abs(df.corr())>= 0.9) & (abs(df.corr()) < 1)].any().any()
# Out:
# True

# %%
df.shape
# Out:
# (5769, 99)

# %%
df.corr().unstack()
# Out:
# abdominalextensiondepthsitting  abdominalextensiondepthsitting   1.00
#                                 acromialheight                   0.35
#                                 acromionradialelength            0.31
#                                 anklecircumference               0.52
#                                 axillaheight                     0.28
#                                                                  ...
# Age                             weightkg                         0.23
#                                 wristcircumference               0.15
#                                 wristheight                      0.11
#                                 DODRace                          0.01
#                                 Age                              1.00
# Length: 9025, dtype: float64

# %%
# multicol modele bırakılıyor

df.corr().unstack().drop_duplicates().sort_values(key=abs, ascending=False).to_frame('Corr')
# Out:
#                                                                Corr
# abdominalextensiondepthsitting abdominalextensiondepthsitting  1.00
# cervicaleheight                stature                         0.99
# stature                        suprasternaleheight             0.99
# cervicaleheight                suprasternaleheight             0.99
# acromialheight                 axillaheight                    0.99
# ...                                                             ...
# elbowrestheight                lateralfemoralepicondyleheight  0.00
# buttockdepth                   DODRace                        -0.00
# buttockheight                  elbowrestheight                -0.00
# thighclearance                 DODRace                        -0.00
# hipbreadthsitting              lateralmalleolusheight         -0.00
#
# [4466 rows x 1 columns]

# %%
df.corr().unstack().drop_duplicates().sort_values(key=abs, ascending=False).to_frame('Corr').head(20)
# Out:
#                                                                Corr
# abdominalextensiondepthsitting abdominalextensiondepthsitting  1.00
# cervicaleheight                stature                         0.99
# stature                        suprasternaleheight             0.99
# cervicaleheight                suprasternaleheight             0.99
# acromialheight                 axillaheight                    0.99
#                                suprasternaleheight             0.98
#                                cervicaleheight                 0.98
# eyeheightsitting               sittingheight                   0.98
# axillaheight                   suprasternaleheight             0.98
# acromialheight                 stature                         0.98
# axillaheight                   cervicaleheight                 0.98
#                                stature                         0.98
# neckcircumference              neckcircumferencebase           0.97
# acromionradialelength          shoulderelbowlength             0.97
# chestheight                    suprasternaleheight             0.97
# cervicaleheight                chestheight                     0.97
# buttockheight                  trochanterionheight             0.97
# chestheight                    stature                         0.96
# iliocristaleheight             tenthribheight                  0.96
# forearmcenterofgriplength      forearmhandlength               0.96

# %%
plt.figure(figsize=(5,60))
corr = df.corr()[['DODRace']]
sns.heatmap(corr.round(2), annot=True);

# %%
df_numeric = df.select_dtypes('number')
df_object = df.select_dtypes('O')

df_numeric.shape, df_object.shape
# Out:
# ((5769, 95), (5769, 4))

# %%
# #histplot için:
# fig = df_numeric.hist(
# figsize=(16, 50), layout=(int(np.ceil(len(df_numeric.columns)/4)), 4),
# bins=50, color="darkcyan", 
# edgecolor="black", 
# xlabelsize=14, ylabelsize=14, 
# alpha=0.5, xrot=45
# )
# plt.tight_layout()
# plt.show()

# %%
# fig = plt.figure(figsize=(15, 30))
# plt.subplots_adjust(
#     left=0.1, right=0.9,
#     top=1.9, bottom=0.1,
#     wspace=0.4, hspace=0.15
# )
# for i, col in enumerate(df_numeric.columns):
#     plt.subplot(int(np.ceil(len(df_numeric.columns)/5)), 5, i+1)
#     sns.boxplot(y=col, data=df_numeric);

# %%
# fig = plt.figure(figsize=(15,50))
# plt.subplots_adjust(
#     left=0.1, right=0.9,
#     top=1.9, bottom=0.1,
#     wspace=0.4, hspace=0.2
# )
# for i, col in enumerate(df_numeric.columns):
#     plt.subplot(int(np.ceil(len(df_numeric.columns)/5)), 5, i+1)
#     sns.regplot(x=col, y="DODRace", data=df_numeric, scatter_kws={"s": 18});

# %%
# fig, axes = plt.subplots(int(np.ceil(len(df_object.columns)/3)), 3, figsize=(15, 12))

# for i, ax in enumerate(fig.axes):
#     # plot barplot of each feature skip target
#     if i < len(df_object.columns) - 1:
#         ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=45)
#         g = sns.countplot(x=df_object.columns[i], alpha=0.7, data=df_object, ax=ax, palette = "Set1")
#         g.bar_label(g.containers[0])
# fig.tight_layout();

# %%
# df_object= df.select_dtypes(include="O")
# fig, axes = plt.subplots(1, 3, figsize=(12, 5))
# for i, ax in enumerate(fig.axes):
#     # plot the variation of price in each feature skip target
#     if i < len(df_object.columns) - 1:
#         ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=75)
#         sns.boxplot(x=df_object.columns[i], y=df["DODRace"], data=df_object, ax=ax, palette="Spectral_r")
# fig.tight_layout()

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %% [markdown]
# ## Train-Test split

# %%
df.shape
# Out:
# (5769, 99)

# %%
X = df.drop(columns="DODRace")
y = df["DODRace"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4615, 98), (1154, 98), (4615,), (1154,))

# %% [markdown]
# ## OneHotEncoding operations

# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ### OneHotEncoder for X_train and X_test

# %%
def trans_2_OneHotEncoder(X_train, X_test):
    
    cat = X_train.select_dtypes("object").columns.to_list()    
    enc = OneHotEncoder(handle_unknown="ignore", sparse=False)
    
    X_train_cat = pd.DataFrame(enc.fit_transform(X_train[cat]), index = X_train.index, 
                           columns = enc.get_feature_names_out(cat))    
    X_test_cat  = pd.DataFrame(enc.transform(X_test[cat]), index = X_test.index, 
                               columns = enc.get_feature_names_out(cat))
    
    X_train = X_train_cat.join(X_train.select_dtypes("number"))
    X_test = X_test_cat.join(X_test.select_dtypes("number"))
        
    return X_train, X_test

# %%
X_train, X_test = trans_2_OneHotEncoder(X_train, X_test)

# %%
X_train.shape, X_test.shape
# Out:
# ((4615, 105), (1154, 105))

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %%
scaler = MinMaxScaler()  # dummy sütunlar old. için minmax seçildi
log_model = LogisticRegression(class_weight="balanced", random_state=42)

# %%
process = [("scaler", scaler),("log_model", log_model)]
log_pipe_model = Pipeline(steps=process)

# %%
log_pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('log_model',
#                  LogisticRegression(class_weight='balanced', random_state=42))])

# %%
y_pred_test = log_pipe_model.predict(X_test)
y_pred_train = log_pipe_model.predict(X_train)

# %%
log_accuracy_test = accuracy_score(y_test, y_pred_test)
log_accuracy_train = accuracy_score(y_train, y_pred_train)

log_f1_test = f1_score(y_test, y_pred_test, average='weighted')
log_f1_train = f1_score(y_train, y_pred_train, average='weighted')

log_accuracy_test, log_accuracy_train, log_f1_test, log_f1_train

# ROC-AUC score da karşılaştırılabilir.
# Out:
# (0.7998266897746967, 0.8242686890574215, 0.819459498536687, 0.8410654611283938)

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
    
    print("TEST REPORT")
    print(classification_report(y_test, y_pred_test))
    plot_confusion_matrix(model, X_test, y_test);

    print("\n"*3, "-*"*30)
    print("TRAIN REPORT")
    print(classification_report(y_train, y_pred_train))
    plot_confusion_matrix(model, X_train, y_train);

# %%
eval_metric(log_pipe_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            1       0.93      0.80      0.86       758
#            2       0.90      0.88      0.89       260
#            3       0.36      0.67      0.47       136
#
#     accuracy                           0.80      1154
#    macro avg       0.73      0.78      0.74      1154
# weighted avg       0.86      0.80      0.82      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            1       0.95      0.81      0.88      3034
#            2       0.91      0.91      0.91      1038
#            3       0.40      0.73      0.52       543
#
#     accuracy                           0.82      4615
#    macro avg       0.75      0.82      0.77      4615
# weighted avg       0.88      0.82      0.84      4615

# %% [markdown]
# ### Logistic Model Cross Validation

# %%
model = Pipeline(process)
scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision_weighted','recall_weighted',
                                                                   'f1_weighted'], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy             0.81
# test_precision_weighted   0.87
# test_recall_weighted      0.81
# test_f1_weighted          0.83
# dtype: float64

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
C = np.logspace(-1, 5, 10)
C
# Out:
# array([1.00000000e-01, 4.64158883e-01, 2.15443469e+00, 1.00000000e+01,
#        4.64158883e+01, 2.15443469e+02, 1.00000000e+03, 4.64158883e+03,
#        2.15443469e+04, 1.00000000e+05])

# %%
model = Pipeline(process) # reset the pipe model

penalty = ["l1", "l2", "elasticnet"]
C = np.logspace(-1, 5, 20)
class_weight = ['balanced', None]
param_grid = {"log_model__penalty" : penalty,
             "log_model__C" : C,
             "log_model__class_weight" : class_weight}

log_grid_model = GridSearchCV(model, param_grid = param_grid, scoring="f1_weighted", cv=5, n_jobs=-1)

# %%
# fit grid model on train data

log_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', MinMaxScaler()),
#                                        ('log_model',
#                                         LogisticRegression(class_weight='balanced',
#                                                            random_state=42))]),
#              n_jobs=-1,
#              param_grid={'log_model__C': array([1.00000000e-01, 2.06913808e-01, 4.28133240e-01, 8.85866790e-01,
#        1.83298071e+00, 3.79269019e+00, 7.84759970e+00, 1.62377674e+01,
#        3.35981829e+01, 6.95192796e+01, 1.43844989e+02, 2.97635144e+02,
#        6.15848211e+02, 1.27427499e+03, 2.63665090e+03, 5.45559478e+03,
#        1.12883789e+04, 2.33572147e+04, 4.83293024e+04, 1.00000000e+05]),
#                          'log_model__class_weight': ['balanced', None],
#                          'log_model__penalty': ['l1', 'l2', 'elasticnet']},
#              scoring='f1_weighted')

# %%
log_grid_model.best_params_
# Out:
# {'log_model__C': 5455.594781168515,
#  'log_model__class_weight': None,
#  'log_model__penalty': 'l2'}

# %%
y_pred_test = log_grid_model.predict(X_test)
y_pred_train = log_grid_model.predict(X_train)

# %%
log_accuracy_test = accuracy_score(y_test, y_pred_test)
log_accuracy_train = accuracy_score(y_train, y_pred_train)

log_f1_test = f1_score(y_test, y_pred_test, average='weighted')
log_f1_train = f1_score(y_train, y_pred_train, average='weighted')

log_accuracy_test, log_accuracy_train, log_f1_test, log_f1_train
# Out:
# (0.8769497400346621,
#  0.8847237269772481,
#  0.8680272418370139,
#  0.8737022124729239)

# %%
eval_metric(log_grid_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            1       0.89      0.95      0.92       758
#            2       0.90      0.90      0.90       260
#            3       0.64      0.41      0.50       136
#
#     accuracy                           0.88      1154
#    macro avg       0.81      0.75      0.78      1154
# weighted avg       0.87      0.88      0.87      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            1       0.90      0.96      0.93      3034
#            2       0.91      0.92      0.91      1038
#            3       0.69      0.39      0.50       543
#
#     accuracy                           0.88      4615
#    macro avg       0.83      0.76      0.78      4615
# weighted avg       0.87      0.88      0.87      4615

# %% [markdown]
# ### Evaluating ROC Curves and AUC

# %%
# for log_grid_model with best hyperparameters

from yellowbrick.classifier import ROCAUC
model = log_grid_model
visualizer = ROCAUC(model)

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show();

# %%
# for pipe model with default hyperparameters

from yellowbrick.classifier import ROCAUC
model = log_pipe_model
visualizer = ROCAUC(model)

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show();

# %%
# precision-recall curve for grid model

from yellowbrick.classifier import PrecisionRecallCurve

model = log_grid_model

viz = PrecisionRecallCurve(
    model,
    per_class=True,
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
# precision-recall curve for log_pipe model

from yellowbrick.classifier import PrecisionRecallCurve

model = log_pipe_model

viz = PrecisionRecallCurve(
    model,
    per_class=True,
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %%
svc_model = SVC(class_weight="balanced", random_state=42)
process = [("scaler", scaler),("svc_model", svc_model)]
svc_pipe_model = Pipeline(steps=process)

# %%
svc_pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('svc_model', SVC(class_weight='balanced', random_state=42))])

# %%
y_pred_test = svc_pipe_model.predict(X_test)
y_pred_train = svc_pipe_model.predict(X_train)

# %%
svc_accuracy_test = accuracy_score(y_test, y_pred_test)
svc_accuracy_train = accuracy_score(y_train, y_pred_train)

svc_f1_test = f1_score(y_test, y_pred_test, average='weighted')
svc_f1_train = f1_score(y_train, y_pred_train, average='weighted')

svc_accuracy_test, svc_accuracy_train, svc_f1_test, svc_f1_train
# Out:
# (0.7842287694974004, 0.856771397616468, 0.8039644626182758, 0.8687503562189041)

# %% [markdown]
# **without class_weight**
# (0.8552859618717504,
#  0.8736728060671722,
#  0.8132943159192254,
#  0.8392715244952955)

# %%
eval_metric(svc_pipe_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            1       0.92      0.78      0.84       758
#            2       0.88      0.90      0.89       260
#            3       0.34      0.62      0.44       136
#
#     accuracy                           0.78      1154
#    macro avg       0.71      0.76      0.72      1154
# weighted avg       0.84      0.78      0.80      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            1       0.96      0.84      0.90      3034
#            2       0.93      0.94      0.93      1038
#            3       0.48      0.80      0.60       543
#
#     accuracy                           0.86      4615
#    macro avg       0.79      0.86      0.81      4615
# weighted avg       0.90      0.86      0.87      4615

# %% [markdown]
# ### SVC Model Cross validation

# %%
model = Pipeline(process)
scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision_weighted','recall_weighted',
                                                                   'f1_weighted'], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy             0.86
# test_precision_weighted   0.84
# test_recall_weighted      0.86
# test_f1_weighted          0.81
# dtype: float64

# %% [markdown]
# ###  SVC Model GridsearchCV

# %%
process = [("scaler", scaler),("SVC", SVC(probability=True, class_weight="balanced", random_state=42))]
model = Pipeline(process) # reset the pipe model

param_grid = {'SVC__C': [0.001, 0.01, 0.1],
              'SVC__gamma': ["scale", "auto"],
              'SVC__kernel': ['poly', 'rbf'],
             "SVC__degree" : [1, 2, 3]}

SVC_grid_model = GridSearchCV(model, param_grid = param_grid, scoring="f1_weighted", cv=5, n_jobs=-1)

# %%
SVC_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', MinMaxScaler()),
#                                        ('SVC',
#                                         SVC(class_weight='balanced',
#                                             probability=True,
#                                             random_state=42))]),
#              n_jobs=-1,
#              param_grid={'SVC__C': [0.001, 0.01, 0.1], 'SVC__degree': [1, 2, 3],
#                          'SVC__gamma': ['scale', 'auto'],
#                          'SVC__kernel': ['poly', 'rbf']},
#              scoring='f1_weighted')

# %%
SVC_grid_model.best_params_
# Out:
# {'SVC__C': 0.1, 'SVC__degree': 3, 'SVC__gamma': 'scale', 'SVC__kernel': 'poly'}

# %%
y_pred_test = SVC_grid_model.predict(X_test)
y_pred_train = SVC_grid_model.predict(X_train)

# %%
SVC_accuracy_test = accuracy_score(y_test, y_pred_test)
SVC_accuracy_train = accuracy_score(y_train, y_pred_train)

SVC_f1_test = f1_score(y_test, y_pred_test, average='weighted')
SVC_f1_train = f1_score(y_train, y_pred_train, average='weighted')

SVC_accuracy_test, SVC_accuracy_train, SVC_f1_test, SVC_f1_train
# Out:
# (0.7850953206239168,
#  0.8485373781148429,
#  0.8086387421250942,
#  0.8633658624374626)

# %% [markdown]
# **without class weight**
# (0.7850953206239168,
#  0.8485373781148429,
#  0.8086387421250942,
#  0.8633658624374626)

# %%
eval_metric(SVC_grid_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            1       0.93      0.77      0.84       758
#            2       0.92      0.89      0.91       260
#            3       0.33      0.66      0.44       136
#
#     accuracy                           0.79      1154
#    macro avg       0.73      0.77      0.73      1154
# weighted avg       0.85      0.79      0.81      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            1       0.97      0.82      0.89      3034
#            2       0.94      0.93      0.93      1038
#            3       0.46      0.84      0.59       543
#
#     accuracy                           0.85      4615
#    macro avg       0.79      0.86      0.80      4615
# weighted avg       0.90      0.85      0.86      4615

# %% [markdown]
# ### Evaluating ROC Curves and AUC

# %%
# for grid model

from yellowbrick.classifier import ROCAUC
model = SVC_grid_model
visualizer = ROCAUC(model)

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show();

# %%
# for svc_pipe_model with default hyperparameters

from yellowbrick.classifier import ROCAUC
model = svc_pipe_model
visualizer = ROCAUC(model)

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show();

# %%
# precision-recall curve for grid model

from yellowbrick.classifier import PrecisionRecallCurve

model = SVC_grid_model

viz = PrecisionRecallCurve(
    model,
    per_class=True,
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
# precision-recall curve for log_pipe model

from yellowbrick.classifier import PrecisionRecallCurve

model = svc_pipe_model

viz = PrecisionRecallCurve(
    model,
    per_class=True,
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ## 3. DT

# %% [markdown]
# ### Ordinal Encoding Before Tree Based Models

# %%
# Since we applied ordinal encoder on splitted data before implementing Logistic model, we should reset train, test split operation. 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# Get categorical columns name to use in ordinal encoding step

cat = X_train.select_dtypes("object").columns
cat
# Out:
# Index(['Gender', 'Component', 'Branch', 'WritingPreference'], dtype='object')

# %%
from sklearn.compose import make_column_transformer
# make_column_transformer transform işlemlerinin gerşekleştirilmesi için

from sklearn.preprocessing import OrdinalEncoder


ord_enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1) # bilmediği bir veri gelirse -1 vermesi için
# handle_unknown='use_encoded_value' bilinmeyen bir veri geldiğinde encoded değeri kullanması için
# unknown_value=-1 bilinmeyen bir veri geldiğinde kullanılacak encode değeri

column_trans = make_column_transformer((ord_enc, cat), remainder='passthrough')
# remainder='passthrough' kalan feature ların pass geçilmesi için

# %%
# Built pipeline contains ordinal encoder and DT model

from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor


operations = [("OrdinalEncoder", column_trans), ("DT_model", DecisionTreeClassifier(random_state=42))]

DT_pipe_model = Pipeline(steps=operations)

DT_pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'Component', 'Branch', 'WritingPreference'], dtype='object'))])),
#                 ('DT_model', DecisionTreeClassifier(random_state=42))])

# %%
y_pred_test = DT_pipe_model.predict(X_test)
y_pred_train = DT_pipe_model.predict(X_train)

# %%
DT_accuracy_test = accuracy_score(y_test, y_pred_test)
DT_accuracy_train = accuracy_score(y_train, y_pred_train)

DT_f1_test = f1_score(y_test, y_pred_test, average='weighted')
DT_f1_train = f1_score(y_train, y_pred_train, average='weighted')

DT_accuracy_test, DT_accuracy_train, DT_f1_test, DT_f1_train
# Out:
# (0.7019064124783362, 1.0, 0.7060256825991841, 1.0)

# %%
eval_metric(DT_pipe_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            1       0.81      0.79      0.80       758
#            2       0.66      0.67      0.67       260
#            3       0.22      0.25      0.24       136
#
#     accuracy                           0.70      1154
#    macro avg       0.57      0.57      0.57      1154
# weighted avg       0.71      0.70      0.71      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      3034
#            2       1.00      1.00      1.00      1038
#            3       1.00      1.00      1.00       543
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615

# %% [markdown]
# ### DT Model Cross Validation

# %%
model = Pipeline(operations)
scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision_weighted','recall_weighted',
                                                                   'f1_weighted'], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy             0.69
# test_precision_weighted   0.69
# test_recall_weighted      0.69
# test_f1_weighted          0.69
# dtype: float64

# %% [markdown]
# ### DT Model GridSearch

# %%
# reset the model
operations = [("OrdinalEncoder", column_trans), ("DT_model", DecisionTreeClassifier(random_state=42))]
model = Pipeline(steps=operations)

# define the hyperparameters to be used in grid search
param_grid = {"DT_model__splitter":["best", "random"],
              "DT_model__max_features":[None, "auto", "log2", 10, 50],
              "DT_model__max_depth": [None, 2, 5, 10],
              "DT_model__min_samples_leaf": [1, 2, 3, 4, 5, 6,7],
              "DT_model__min_samples_split": [2, 3, 5]}

# best parameters uç değerler çıktığı için güncellenip tekrar yapılabilir.

# %%
DT_grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='f1_weighted',
                          cv=10,
                          n_jobs = -1)

# %%
DT_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          Index(['Gender', 'Component', 'Branch', 'WritingPreference'], dtype='object'))])),
#                                        ('DT_model',
#                                         DecisionTreeClassifier(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'DT_model__max_depth': [None, 2, 5, 10],
#                          'DT_model__max_features': [None, 'auto', 'log2', 10,
#                                                     50],
#                          'DT_model__min_samples_leaf': [1, 2, 3, 4, 5, 6, 7],
#                          'DT_model__min_samples_split': [2, 3, 5],
#                          'DT_model__splitter': ['best', 'random']},
#              scoring='f1_weighted')

# %%
DT_grid_model.best_score_
# Out:
# 0.7315524823345287

# %%
DT_grid_model.best_params_
# Out:
# {'DT_model__max_depth': 10,
#  'DT_model__max_features': 50,
#  'DT_model__min_samples_leaf': 1,
#  'DT_model__min_samples_split': 5,
#  'DT_model__splitter': 'best'}

# %%
DT_grid_model.best_estimator_ # default'da olmayan değerleri getirir
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'Component', 'Branch', 'WritingPreference'], dtype='object'))])),
#                 ('DT_model',
#                  DecisionTreeClassifier(max_depth=10, max_features=50,
#                                         min_samples_split=5,
#                                         random_state=42))])

# %%
y_pred_test = DT_grid_model.predict(X_test)
y_pred_train = DT_grid_model.predict(X_train)

# %%
DT_accuracy_test = accuracy_score(y_test, y_pred_test)
DT_accuracy_train = accuracy_score(y_train, y_pred_train)

DT_f1_test = f1_score(y_test, y_pred_test, average='weighted')
DT_f1_train = f1_score(y_train, y_pred_train, average='weighted')

DT_accuracy_test, DT_accuracy_train, DT_f1_test, DT_f1_train
# Out:
# (0.7305025996533796,
#  0.9157096424702058,
#  0.7179340589099316,
#  0.9101208007289531)

# %%
eval_metric(DT_grid_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            1       0.80      0.86      0.83       758
#            2       0.69      0.64      0.67       260
#            3       0.26      0.18      0.21       136
#
#     accuracy                           0.73      1154
#    macro avg       0.58      0.56      0.57      1154
# weighted avg       0.71      0.73      0.72      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            1       0.90      0.99      0.94      3034
#            2       0.96      0.89      0.92      1038
#            3       0.91      0.57      0.70       543
#
#     accuracy                           0.92      4615
#    macro avg       0.92      0.81      0.86      4615
# weighted avg       0.92      0.92      0.91      4615

# %% [markdown]
# ### DT with Bagging

# %%
from sklearn.ensemble import BaggingClassifier

operations = [("OrdinalEncoder", column_trans), ("Bag_DT_model", BaggingClassifier(DecisionTreeClassifier(random_state=42), n_jobs=-1, max_samples=1.0, n_estimators=10))]

Bag_DT_pipe_model = Pipeline(steps=operations)

Bag_DT_pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'Component', 'Branch', 'WritingPreference'], dtype='object'))])),
#                 ('Bag_DT_model',
#                  BaggingClassifier(base_estimator=DecisionTreeClassifier(random_state=42),
#                                    n_jobs=-1))])

# %%
y_pred_test = Bag_DT_pipe_model.predict(X_test)
y_pred_train = Bag_DT_pipe_model.predict(X_train)

# %%
Bag_DT_accuracy_test = accuracy_score(y_test, y_pred_test)
Bag_DT_accuracy_train = accuracy_score(y_train, y_pred_train)

Bag_DT_f1_test = f1_score(y_test, y_pred_test, average='weighted')
Bag_DT_f1_train = f1_score(y_train, y_pred_train, average='weighted')

Bag_DT_accuracy_test, Bag_DT_accuracy_train, Bag_DT_f1_test, Bag_DT_f1_train
# Out:
# (0.804159445407279, 0.9841820151679307, 0.7743715991184678, 0.9839370601052452)

# %%
eval_metric(Bag_DT_pipe_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            1       0.82      0.94      0.88       758
#            2       0.82      0.76      0.79       260
#            3       0.41      0.12      0.18       136
#
#     accuracy                           0.80      1154
#    macro avg       0.68      0.61      0.62      1154
# weighted avg       0.77      0.80      0.77      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            1       0.98      1.00      0.99      3034
#            2       0.99      0.99      0.99      1038
#            3       1.00      0.90      0.95       543
#
#     accuracy                           0.98      4615
#    macro avg       0.99      0.96      0.97      4615
# weighted avg       0.98      0.98      0.98      4615

# %% [markdown]
# ### Bagging_DT Model Cross validation

# %%
model = Pipeline(operations)
scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision_weighted','recall_weighted',
                                                                   'f1_weighted'], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy             0.80
# test_precision_weighted   0.76
# test_recall_weighted      0.80
# test_f1_weighted          0.77
# dtype: float64

# %% [markdown]
# ### Baggin_DT Model GridSearch

# %%
operations = [("OrdinalEncoder", column_trans), ("Bag_DT_model", BaggingClassifier(DecisionTreeClassifier(random_state=42), n_jobs=-1))]

model = Pipeline(steps=operations)

param_grid = {"Bag_DT_model__max_features":[10, 50, 70, 95],
              "Bag_DT_model__n_estimators": [10, 50, 100],
              "Bag_DT_model__max_samples": [0.5, 1]}

# %%
grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='f1_weighted',
                          cv=5,
                          n_jobs = -1)

# %%
grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          Index(['Gender', 'Component', 'Branch', 'WritingPreference'], dtype='object'))])),
#                                        ('Bag_DT_model',
#                                         BaggingClassifier(base_estimator=DecisionTreeClassifier(random_state=42),
#                                                           n_jobs=-1))]),
#              n_jobs=-1,
#              param_grid={'Bag_DT_model__max_features': [10, 50, 70, 95],
#                          'Bag_DT_model__max_samples': [0.5, 1],
#                          'Bag_DT_model__n_estimators': [10, 50, 100]},
#              scoring='f1_weighted')

# %%
grid_model.best_score_
# Out:
# 0.7785637114724157

# %%
grid_model.best_params_
# Out:
# {'Bag_DT_model__max_features': 95,
#  'Bag_DT_model__max_samples': 0.5,
#  'Bag_DT_model__n_estimators': 100}

# %%
y_pred_test = grid_model.predict(X_test)
y_pred_train = grid_model.predict(X_train)

# %%
Bag_DT_accuracy_test = accuracy_score(y_test, y_pred_test)
Bag_DT_accuracy_train = accuracy_score(y_train, y_pred_train)

Bag_DT_f1_test = f1_score(y_test, y_pred_test, average='weighted')
Bag_DT_f1_train = f1_score(y_train, y_pred_train, average='weighted')

Bag_DT_accuracy_test, Bag_DT_accuracy_train, Bag_DT_f1_test, Bag_DT_f1_train
# Out:
# (0.8188908145580589,
#  0.9625135427952329,
#  0.7806830097036311,
#  0.9608540306730934)

# %%
eval_metric(grid_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            1       0.82      0.97      0.88       758
#            2       0.84      0.77      0.81       260
#            3       0.71      0.09      0.16       136
#
#     accuracy                           0.82      1154
#    macro avg       0.79      0.61      0.62      1154
# weighted avg       0.81      0.82      0.78      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            1       0.95      1.00      0.97      3034
#            2       0.99      0.97      0.98      1038
#            3       1.00      0.75      0.86       543
#
#     accuracy                           0.96      4615
#    macro avg       0.98      0.91      0.94      4615
# weighted avg       0.96      0.96      0.96      4615

# %% [markdown]
# ### Evaluating ROC Curves and AUC

# %%
# Bagging grid_model

from yellowbrick.classifier import ROCAUC

model = Bag_DT_pipe_model

visualizer = ROCAUC(model)

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show();

# %%
# Bag_DT_pipe_model with default parameters

from yellowbrick.classifier import ROCAUC

model = grid_model

visualizer = ROCAUC(model)

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show();

# %% [markdown]
# ## 4. RF

# %% [markdown]
# ### Vanilla RF Model

# %%
operations = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(random_state=42))]

RF_pipe_model = Pipeline(steps=operations)

RF_pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'Component', 'Branch', 'WritingPreference'], dtype='object'))])),
#                 ('RF_model', RandomForestClassifier(random_state=42))])

# %%
y_pred_test = RF_pipe_model.predict(X_test)
y_pred_train = RF_pipe_model.predict(X_train)

# %%
RF_accuracy_test = accuracy_score(y_test, y_pred_test)
RF_accuracy_train = accuracy_score(y_train, y_pred_train)

RF_f1_test = f1_score(y_test, y_pred_test, average='weighted')
RF_f1_train = f1_score(y_train, y_pred_train, average='weighted')

RF_accuracy_test, RF_accuracy_train, RF_f1_test, RF_f1_train
# Out:
# (0.8180242634315424, 1.0, 0.7800400653301159, 1.0)

# %%
eval_metric(RF_pipe_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            1       0.81      0.97      0.88       758
#            2       0.88      0.75      0.81       260
#            3       0.63      0.09      0.15       136
#
#     accuracy                           0.82      1154
#    macro avg       0.77      0.60      0.62      1154
# weighted avg       0.80      0.82      0.78      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      3034
#            2       1.00      1.00      1.00      1038
#            3       1.00      1.00      1.00       543
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615

# %% [markdown]
# ### RF Model Cross validation

# %%
model = Pipeline(operations)
scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision_weighted','recall_weighted',
                                                                   'f1_weighted'], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy             0.82
# test_precision_weighted   0.80
# test_recall_weighted      0.82
# test_f1_weighted          0.77
# dtype: float64

# %% [markdown]
# ### RF Model GridsearchCV

# %%
operations = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(random_state=42))]
model = Pipeline(steps=operations)

param_grid = {"RF_model__n_estimators":[10, 30, 50],
             "RF_model__criterion":["entropy","gini"],
              "RF_model__max_features":['auto',"log2", 10, 20],
              "RF_model__max_depth": [10, 15],
             "RF_model__min_samples_split": [2, 5, 10],
             "RF_model__min_samples_leaf" : [1, 5]}

# %%
RF_grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='f1_weighted',
                          cv=5,
                          n_jobs = -1)

# %%
RF_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          Index(['Gender', 'Component', 'Branch', 'WritingPreference'], dtype='object'))])),
#                                        ('RF_model',
#                                         RandomForestClassifier(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'RF_model__criterion': ['entropy', 'gini'],
#                          'RF_model__max_depth': [10, 15],
#                          'RF_model__max_features': ['auto', 'log2', 10, 20],
#                          'RF_model__min_samples_leaf': [1, 5],
#                          'RF_model__min_samples_split': [2, 5, 10],
#                          'RF_model__n_estimators': [10, 30, 50]},
#              scoring='f1_weighted')

# %%
RF_grid_model.best_score_
# Out:
# 0.7671986655868442

# %%
RF_grid_model.best_params_
# Out:
# {'RF_model__criterion': 'entropy',
#  'RF_model__max_depth': 10,
#  'RF_model__max_features': 10,
#  'RF_model__min_samples_leaf': 1,
#  'RF_model__min_samples_split': 5,
#  'RF_model__n_estimators': 50}

# %%
RF_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'Component', 'Branch', 'WritingPreference'], dtype='object'))])),
#                 ('RF_model',
#                  RandomForestClassifier(criterion='entropy', max_depth=10,
#                                         max_features=10, min_samples_split=5,
#                                         n_estimators=50, random_state=42))])

# %%
y_pred_test = RF_grid_model.predict(X_test)
y_pred_train = RF_grid_model.predict(X_train)

# %%
RF_accuracy_test = accuracy_score(y_test, y_pred_test)
RF_accuracy_train = accuracy_score(y_train, y_pred_train)

RF_f1_test = f1_score(y_test, y_pred_test, average='weighted')
RF_f1_train = f1_score(y_train, y_pred_train, average='weighted')

RF_accuracy_test, RF_accuracy_train, RF_f1_test, RF_f1_train
# Out:
# (0.8223570190641247,
#  0.9284940411700975,
#  0.7815286285607161,
#  0.9189252020521954)

# %%
eval_metric(RF_grid_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            1       0.81      0.98      0.89       758
#            2       0.88      0.76      0.82       260
#            3       0.71      0.07      0.13       136
#
#     accuracy                           0.82      1154
#    macro avg       0.80      0.60      0.61      1154
# weighted avg       0.81      0.82      0.78      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            1       0.90      1.00      0.95      3034
#            2       0.99      0.96      0.98      1038
#            3       1.00      0.47      0.64       543
#
#     accuracy                           0.93      4615
#    macro avg       0.97      0.81      0.86      4615
# weighted avg       0.94      0.93      0.92      4615

# %% [markdown]
# ### Evaluating ROC Curves and AUC

# %%
# for grid model

from yellowbrick.classifier import ROCAUC
model = RF_grid_model
visualizer = ROCAUC(model)

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show();

# %%
# for svc_pipe_model with default hyperparameters

from yellowbrick.classifier import ROCAUC
model = RF_pipe_model
visualizer = ROCAUC(model)

visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
visualizer.score(X_test, y_test)        # Evaluate the model on the test data
visualizer.show();

# %%
# precision-recall curve for grid model

from yellowbrick.classifier import PrecisionRecallCurve

model = RF_grid_model

viz = PrecisionRecallCurve(
    model,
    per_class=True,
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
# precision-recall curve for log_pipe model

from yellowbrick.classifier import PrecisionRecallCurve

model = RF_pipe_model

viz = PrecisionRecallCurve(
    model,
    per_class=True,
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
from sklearn.metrics import classification_report, accuracy_score, recall_score, precision_score, f1_score, log_loss
from sklearn.metrics import plot_confusion_matrix, confusion_matrix

def eval_metric(model, X_train, y_train, X_test, y_test, model_name='', average='weighted'):
    """ average (None, 'micro', 'macro', 'weighted', 'samples')"""
    y_pred_test = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    
    print("TEST REPORT")
    print(classification_report(y_test, y_pred_test))
    plot_confusion_matrix(model, X_test, y_test);
    print("\n"*3, "-*"*30)
    print("TRAIN REPORT")
    print(classification_report(y_train, y_pred_train))
    plot_confusion_matrix(model, X_train, y_train);
    
    return {
        f'{model_name}'+'_accuracy_test':accuracy_score(y_test, y_pred_test),
        f'{model_name}'+'_f1_test':f1_score(y_test, y_pred_test, average=average),
        f'{model_name}'+'_accuracy_train':accuracy_score(y_train, y_pred_train),
        f'{model_name}'+'_f1_train':f1_score(y_train, y_pred_train, average=average),}

# %%
eval_metric(RF_grid_model, X_train, y_train, X_test, y_test, 'RF_grid_')
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            1       0.81      0.96      0.88       758
#            2       0.84      0.77      0.80       260
#            3       0.56      0.07      0.13       136
#
#     accuracy                           0.81      1154
#    macro avg       0.73      0.60      0.60      1154
# weighted avg       0.79      0.81      0.77      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            1       0.96      1.00      0.98      3034
#            2       1.00      0.98      0.99      1038
#            3       1.00      0.79      0.88       543
#
#     accuracy                           0.97      4615
#    macro avg       0.98      0.92      0.95      4615
# weighted avg       0.97      0.97      0.97      4615
# {'RF_grid__accuracy_test': 0.8119584055459272,
#  'RF_grid__f1_test': 0.7729808984646117,
#  'RF_grid__accuracy_train': 0.9696641386782232,
#  'RF_grid__f1_train': 0.9684629276278941}

# %%
out_score_log = eval_metric(RF_grid_model, X_train, y_train, X_test, y_test, 'RF_grid_')
out_score_log
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            1       0.80      0.97      0.88       758
#            2       0.87      0.72      0.79       260
#            3       0.60      0.04      0.08       136
#
#     accuracy                           0.81      1154
#    macro avg       0.75      0.58      0.58      1154
# weighted avg       0.79      0.81      0.76      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            1       0.91      1.00      0.96      3034
#            2       1.00      0.97      0.98      1038
#            3       1.00      0.54      0.70       543
#
#     accuracy                           0.94      4615
#    macro avg       0.97      0.84      0.88      4615
# weighted avg       0.94      0.94      0.93      4615
# {'RF_grid__accuracy_test': 0.8084922010398613,
#  'RF_grid__f1_test': 0.7634370740524137,
#  'RF_grid__accuracy_train': 0.9384615384615385,
#  'RF_grid__f1_train': 0.9315239789442671}

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %% [markdown]
# XGBoost ta class weight i balanced yapmak için farklı bir yol izlemek gerekiyor.

# %%
operations = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=42))]

XGB_pipe_model = Pipeline(steps=operations)

XGB_pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'Component', 'Branch', 'WritingPreference'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(objective='multi:softprob', random_state=42))])

# %%
y_pred_test = XGB_pipe_model.predict(X_test)
y_pred_train = XGB_pipe_model.predict(X_train)

# %%
XGB_accuracy_test = accuracy_score(y_test, y_pred_test)
XGB_accuracy_train = accuracy_score(y_train, y_pred_train)

XGB_f1_test = f1_score(y_test, y_pred_test, average='weighted')
XGB_f1_train = f1_score(y_train, y_pred_train, average='weighted')

XGB_accuracy_test, XGB_accuracy_train, XGB_f1_test, XGB_f1_train
# Out:
# (0.8353552859618717,
#  0.8931744312026002,
#  0.8067597738855096,
#  0.8779758663264399)

# %%
eval_metric(XGB_pipe_model, X_train, y_train, X_test, y_test)
# Out:
# TEST REPORT
#               precision    recall  f1-score   support
#
#            1       0.84      0.96      0.90       758
#            2       0.85      0.82      0.84       260
#            3       0.58      0.15      0.24       136
#
#     accuracy                           0.84      1154
#    macro avg       0.76      0.65      0.66      1154
# weighted avg       0.81      0.84      0.81      1154
#
#
#
#
#  -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# TRAIN REPORT
#               precision    recall  f1-score   support
#
#            1       0.88      0.99      0.93      3034
#            2       0.95      0.90      0.92      1038
#            3       0.90      0.35      0.51       543
#
#     accuracy                           0.89      4615
#    macro avg       0.91      0.75      0.79      4615
# weighted avg       0.90      0.89      0.88      4615

# %% [markdown]
# ### XGB Model Cross Validation

# %%
model = Pipeline(operations)
scores = cross_validate(model, X_train, y_train, scoring = ['accuracy', 'precision_weighted','recall_weighted',
                                                                   'f1_weighted'], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy             0.84
# test_precision_weighted   0.82
# test_recall_weighted      0.84
# test_f1_weighted          0.81
# dtype: float64

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %%
operations = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=42))]
model = Pipeline(steps=operations)

param_grid = {"XGB_model__n_estimators":[50, 100, 200],
              "XGB_model__max_depth":[3,4,5],
              "XGB_model__learning_rate": [0.1, 0.2],
              "XGB_model__subsample":[0.5, 0.8, 1],
              "XGB_model__colsample_bytree":[0.5,0.7, 1]}

# %%
XGB_grid_model = GridSearchCV(estimator=model,
                          param_grid=param_grid,
                          scoring='f1_weighted',
                          cv=5,
                          n_jobs = -1)

# %%
XGB_grid_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          Index(['Gender', 'Component', 'Branch', 'WritingPreference'], dtype='object'))])),
#                                        ('XGB_model',
#                                         XGBClassifier(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'XGB_model__colsample_bytree': [0.5, 0.7, 1],
#                          'XGB_model__learning_rate': [0.1, 0.2],
#                          'XGB_model__max_depth': [3, 4, 5],
#                          'XGB_model__n_estimators': [50, 100, 200],
#                          'XGB_model__subsample': [0.5, 0.8, 1]},
#              scoring='f1_weighted')

# %%
XGB_grid_model.best_score_
# Out:
# 0.8430680316019341

# %%
XGB_grid_model.best_params_
# Out:
# {'XGB_model__colsample_bytree': 0.5,
#  'XGB_model__learning_rate': 0.2,
#  'XGB_model__max_depth': 3,
#  'XGB_model__n_estimators': 200,
#  'XGB_model__subsample': 0.5}

# %%
XGB_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'Component', 'Branch', 'WritingPreference'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(colsample_bytree=0.5, learning_rate=0.2,
#                                n_estimators=200, objective='multi:softprob',
#                                random_state=42, subsample=0.5))])

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %%
SMOTE(Synthetic Minority Oversampling Technique)

# %% [markdown]
# ##  Smote implement

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

# %% [markdown]
# ## SVC Over/Under Sampling

# %% [markdown]
# ## Xgboost Over/ Under Sampling

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %%
from sklearn.metrics import matthews_corrcoef

matthews_corrcoef(y_test, y_pred)
# Out:
# 0.7380728719663084

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)
# Out:
# 0.7376215262514891

# %% [markdown]
# #  SHAP
#
# https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.40.0-cp38-cp38-win_amd64.whl (431 kB)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\madcat\anaconda3\lib\site-packages (from shap) (4.59.0)
# Requirement already satisfied: numba in c:\users\madcat\anaconda3\lib\site-packages (from shap) (0.53.1)
# Collecting packaging>20.9
#   Downloading packaging-21.2-py3-none-any.whl (40 kB)
# Requirement already satisfied: scikit-learn in c:\users\madcat\anaconda3\lib\site-packages (from shap) (0.24.1)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.6.2)
# Requirement already satisfied: cloudpickle in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.6.0)
# Requirement already satisfied: pandas in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.3.4)
# Requirement already satisfied: numpy in c:\users\madcat\anaconda3\lib\site-packages (from shap) (1.20.1)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\madcat\anaconda3\lib\site-packages (from packaging>20.9->shap) (2.4.7)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in c:\users\madcat\anaconda3\lib\site-packages (from numba->shap) (0.36.0)
# Requirement already satisfied: setuptools in c:\users\madcat\anaconda3\lib\site-packages (from numba->shap) (52.0.0.post20210125)
# Requirement already satisfied: pytz>=2017.3 in c:\users\madcat\anaconda3\lib\site-packages (from pandas->shap) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\madcat\anaconda3\lib\site-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\madcat\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\madcat\anaconda3\lib\site-packages (from scikit-learn->shap) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\madcat\anaconda3\lib\site-packages (from scikit-learn->shap) (2.1.0)
# Installing collected packages: slicer, packaging, shap
#   Attempting uninstall: packaging
#     Found existing installation: packaging 20.9
#     Uninstalling packaging-20.9:
#       Successfully uninstalled packaging-20.9
# Successfully installed packaging-21.2 shap-0.40.0 slicer-0.0.7

# %%
import shap
explainer = shap.Explainer(log_model,X_train)
start_index = 203
end_index = 204
shap_values = explainer.shap_values(X_test[start_index:end_index])

# %%
shap_values

# %%
print(shap_values[0].shape)
# Out:
# (1, 232)

# %%
# %% >> Visualize local predictions
shap.initjs()
# Force plot
prediction = log_model.predict(X_test[start_index:end_index])[0]
print(f"The log_model predicted: {prediction}")
shap.force_plot(explainer.expected_value[1],
                shap_values[1],
                X_test[start_index:end_index], # for values
                feature_names= X.columns,)

# %%
shap.summary_plot(shap_values, X_train,max_display=300,feature_names = X.columns)

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
