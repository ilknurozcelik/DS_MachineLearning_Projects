# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix, average_precision_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
# df_male = pd.read_csv('https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr', encoding='latin-1')

# %%
# df_female= pd.read_csv('https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq')

# %%
df_female= pd.read_csv('ANSUR II FEMALE Public.csv')

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %%
df_male.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0      10027                             266            1467                    337                 222          1347                      253               202                401                        369               274               493                  71               319                        291                 142                   979           240            882                619                     509                373             1535           291                1074         259         1292           877                    607                             351          36         71             19              247               802                    101         273                        349                         299                    575                477                 1136           90                214         193          150                583         206                     326           70         332                366                1071
# 1      10032                             233            1395                    326                 220          1293                      245               193                394                        338               257               479                  67               344                        320                 135                   944           232            870                584                     468                357             1471           269                1021         253         1244           851                    615                             376          33         62             18              232               781                     98         263                        348                         289                    523                476                 1096           86                203         195          146                568         201                     334           72         312                356                1046
# 2      10033                             287            1430                    341                 230          1327                      256               196                427                        408               261               544                  75               345                        330                 135                  1054           258            901                623                     506                412             1501           288                1120         267         1288           854                    636                             359          40         61             23              237               810                    103         270                        355                         357                    575                491                 1115           93                220         203          148                573         202                     356           70         349                393                1053
# 3      10092                             234            1347                    310                 230          1239                      262               199                401                        359               262               518                  73               328                        309                 143                   991           242            821                560                     437                395             1423           296                1114         262         1205           769                    590                             341          39         66             25              272               794                    106         267                        352                         318                    593                467                 1034           91                217         194          158                576         199                     341           68         338                367                 986
# 4      10093                             250            1585                    372                 247          1478                      267               224                435                        356               263               524                  80               340                        310                 138                  1029           275           1080                706                     567                425             1684           304                1048         232         1452          1014                    682                             382          32         56             19              188               814                    111         305                        399                         324                    605                550                 1279           94                222         218          153                566         197                     374           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight Gender       Date Installation     Component                  Branch PrimaryMOS SubjectsBirthLocation  SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs WritingPreference
# 0                    685         422          441                   502                560                             500                      77                      391                  118                400                    436                           1447         113              437                   273                   1151                  368             145            928                     883            600  1782     1776                 1449            1092                 610             164            786           491               140                  919                           1700              501           329                 933         240                      440                  1054       815                 175          853   Male   4-Oct-10    Fort Hood  Regular Army             Combat Arms        19D          North Dakota                   1       NaN        1   41        71        180        Right hand
# 1                    620         441          447                   490                540                             488                      73                      371                  131                380                    420                           1380         118              417                   254                   1119                  353             141            884                     868            564  1745     1702                 1387            1076                 572             169            822           476               120                  918                           1627              432           316                 870         225                      371                  1054       726                 167          815   Male   4-Oct-10    Fort Hood  Regular Army          Combat Support        68W              New York                   1       NaN        1   35        68        160         Left hand
# 2                    665         462          475                   496                556                             482                      72                      409                  123                403                    434                           1447         121              431                   268                   1276                  367             167            917                     910            604  1867     1735                 1438            1105                 685             198            807           477               125                  918                           1678              472           329                 964         255                      411                  1041       929                 180          831   Male   4-Oct-10    Fort Hood  Regular Army          Combat Support        68W              New York                   2       NaN        2   42        68        205         Left hand
# 3                    640         458          461                   460                511                             452                      76                      393                  106                407                    446                           1357         118              393                   249                   1155                  330             148            903                     848            550  1708     1655                 1346            1021                 604             180            803           445               127                  847                           1625              461           315                 857         205                      399                   968       794                 176          793   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support        88M             Wisconsin                   1       NaN        1   31        66        175        Right hand
# 4                    675         481          505                   612                666                             585                      85                      458                  135                398                    430                           1572         132              523                   302                   1231                  400             180            919                     995            641  2035     1914                 1596            1292                 672             194            962           584               122                 1090                           1679              467           303                 868         214                      379                  1245       946                 188          954   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support        92G        North Carolina                   2       NaN        2   21        77        213        Right hand

# %%
df_female.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0      10037                             231            1282                    301                 204          1180                      222               177                373                        315               263               466                  65               338                        301                 141                  1011           223            836                587                     476                360             1336           274                 922         245         1095           759                    557                             310          35         65             16              220               713                     91         246                        316                         265                    517                432                 1028           75                182         184          141                548         191                     314           69         345                388                 966
# 1      10038                             194            1379                    320                 207          1292                      225               178                372                        272               250               430                  64               294                        270                 126                   893           186            900                583                     483                350             1440           261                 839         206         1234           835                    549                             329          32         60             23              208               726                     91         249                        341                         247                    468                463                 1117           78                187         189          138                535         180                     307           60         315                335                1048
# 2      10042                             183            1369                    329                 233          1271                      237               196                397                        300               276               450                  69               309                        270                 128                   987           204            861                583                     466                384             1451           287                 874         223         1226           821                    643                             374          36         65             26              204               790                    100         265                        343                         262                    488                469                 1060           84                198         195          146                588         207                     331           70         356                399                1043
# 3      10043                             261            1356                    306                 214          1250                      240               188                384                        364               276               484                  68               340                        294                 144                  1012           253            897                599                     471                372             1430           269                1008         285         1170           804                    640                             351          38         62             22              244               775                     97         265                        331                         309                    529                455                 1069           80                192         186          153                593         206                     332           68         337                402                1029
# 4      10051                             309            1303                    308                 214          1210                      217               182                378                        320               336               525                  67               300                        295                 135                  1281           284            811                607                     467                433             1362           305                1089         290         1112           726                    686                             356          34         65             18              233               732                     88         247                        339                         260                    596                447                 1039           78                183         187          140                522         181                     308           63         448                499                 964
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight  Gender      Date Installation     Component                  Branch PrimaryMOS SubjectsBirthLocation  SubjectNumericRace           Ethnicity  DODRace  Age  Heightin  Weightlbs WritingPreference
# 0                    645         363          399                   435                496                             447                      55                      404                  118                335                    368                           1268         113              362                   235                   1062                  327             148            803                     809            513  1647     1560                 1280            1013                 622             174            736           430               110                  844                           1488              406           295                 850         217                      345                   942       657                 152          756  Female  5-Oct-10    Fort Hood  Regular Army          Combat Support        92Y               Germany                   2                 NaN        2   26        61        142        Right hand
# 1                    595         340          375                   483                532                             492                      69                      334                  115                302                    345                           1389         110              426                   259                   1014                  346             142            835                     810            575  1751     1665                 1372            1107                 524             152            771           475               125                  901                           1470              422           254                 708         168                      329                  1032       534                 155          815  Female  5-Oct-10    Fort Hood  Regular Army  Combat Service Support        25U            California                   3             Mexican        3   21        64        120        Right hand
# 2                    655         345          399                   470                530                             469                      64                      401                  135                325                    369                           1414         122              398                   258                   1049                  362             164            904                     855            568  1779     1711                 1383            1089                 577             164            814           458               129                  882                           1542              419           269                 727         159                      367                  1035       663                 162          799  Female  5-Oct-10    Fort Hood  Regular Army  Combat Service Support        35D                 Texas                   1                 NaN        1   23        68        147        Right hand
# 3                    655         392          435                   469                520                             478                      67                      402                  118                357                    386                           1329         115              394                   250                   1121                  333             157            875                     815            536  1708     1660                 1358            1065                 679             187            736           463               125                  866                           1627              451           302                 923         235                      371                   999       782                 173          818  Female  5-Oct-10    Fort Hood  Regular Army  Combat Service Support        25U  District of Columbia                   8  Caribbean Islander        2   22        66        175        Right hand
# 4                    635         428          435                   440                491                             441                      63                      479                  114                340                    358                           1350         116              345                   242                   1151                  329             156            824                     810            559  1702     1572                 1292            1030                 766             197            766           429               116                  800                           1698              452           405                1163         300                      380                   911       886                 152          762  Female  5-Oct-10    Fort Hood  Regular Army             Combat Arms        42A                 Texas                   1                 NaN        1   45        63        195        Right hand

# %%
print(df_male.shape)
print(df_female.shape)
# Out:
# (4082, 108)
# (1986, 108)

# %%
data = pd.concat([df_male,df_female], axis=0, ignore_index=True)
data.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0    10027.0                             266            1467                    337                 222          1347                      253               202                401                        369               274               493                  71               319                        291                 142                   979           240            882                619                     509                373             1535           291                1074         259         1292           877                    607                             351          36         71             19              247               802                    101         273                        349                         299                    575                477                 1136           90                214         193          150                583         206                     326           70         332                366                1071
# 1    10032.0                             233            1395                    326                 220          1293                      245               193                394                        338               257               479                  67               344                        320                 135                   944           232            870                584                     468                357             1471           269                1021         253         1244           851                    615                             376          33         62             18              232               781                     98         263                        348                         289                    523                476                 1096           86                203         195          146                568         201                     334           72         312                356                1046
# 2    10033.0                             287            1430                    341                 230          1327                      256               196                427                        408               261               544                  75               345                        330                 135                  1054           258            901                623                     506                412             1501           288                1120         267         1288           854                    636                             359          40         61             23              237               810                    103         270                        355                         357                    575                491                 1115           93                220         203          148                573         202                     356           70         349                393                1053
# 3    10092.0                             234            1347                    310                 230          1239                      262               199                401                        359               262               518                  73               328                        309                 143                   991           242            821                560                     437                395             1423           296                1114         262         1205           769                    590                             341          39         66             25              272               794                    106         267                        352                         318                    593                467                 1034           91                217         194          158                576         199                     341           68         338                367                 986
# 4    10093.0                             250            1585                    372                 247          1478                      267               224                435                        356               263               524                  80               340                        310                 138                  1029           275           1080                706                     567                425             1684           304                1048         232         1452          1014                    682                             382          32         56             19              188               814                    111         305                        399                         324                    605                550                 1279           94                222         218          153                566         197                     374           69         332                372                1251
#
#    interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight Gender       Date Installation     Component                  Branch PrimaryMOS SubjectsBirthLocation  SubjectNumericRace Ethnicity  DODRace  Age  Heightin  Weightlbs WritingPreference  SubjectId
# 0                    685         422          441                   502                560                             500                      77                      391                  118                400                    436                           1447         113              437                   273                   1151                  368             145            928                     883            600  1782     1776                 1449            1092                 610             164            786           491               140                  919                           1700              501           329                 933         240                      440                  1054       815                 175          853   Male   4-Oct-10    Fort Hood  Regular Army             Combat Arms        19D          North Dakota                   1       NaN        1   41        71        180        Right hand        NaN
# 1                    620         441          447                   490                540                             488                      73                      371                  131                380                    420                           1380         118              417                   254                   1119                  353             141            884                     868            564  1745     1702                 1387            1076                 572             169            822           476               120                  918                           1627              432           316                 870         225                      371                  1054       726                 167          815   Male   4-Oct-10    Fort Hood  Regular Army          Combat Support        68W              New York                   1       NaN        1   35        68        160         Left hand        NaN
# 2                    665         462          475                   496                556                             482                      72                      409                  123                403                    434                           1447         121              431                   268                   1276                  367             167            917                     910            604  1867     1735                 1438            1105                 685             198            807           477               125                  918                           1678              472           329                 964         255                      411                  1041       929                 180          831   Male   4-Oct-10    Fort Hood  Regular Army          Combat Support        68W              New York                   2       NaN        2   42        68        205         Left hand        NaN
# 3                    640         458          461                   460                511                             452                      76                      393                  106                407                    446                           1357         118              393                   249                   1155                  330             148            903                     848            550  1708     1655                 1346            1021                 604             180            803           445               127                  847                           1625              461           315                 857         205                      399                   968       794                 176          793   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support        88M             Wisconsin                   1       NaN        1   31        66        175        Right hand        NaN
# 4                    675         481          505                   612                666                             585                      85                      458                  135                398                    430                           1572         132              523                   302                   1231                  400             180            919                     995            641  2035     1914                 1596            1292                 672             194            962           584               122                 1090                           1679              467           303                 868         214                      379                  1245       946                 188          954   Male  12-Oct-10    Fort Hood  Regular Army  Combat Service Support        92G        North Carolina                   2       NaN        2   21        77        213        Right hand        NaN

# %%
data.shape
# Out:
# (6068, 109)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Columns: 109 entries, subjectid to SubjectId
# dtypes: float64(2), int64(98), object(9)
# memory usage: 5.0+ MB

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6068 entries, 0 to 6067
# Data columns (total 109 columns):
#  #    Column                          Dtype
# ---   ------                          -----
#  0    subjectid                       float64
#  1    abdominalextensiondepthsitting  int64
#  2    acromialheight                  int64
#  3    acromionradialelength           int64
#  4    anklecircumference              int64
#  5    axillaheight                    int64
#  6    balloffootcircumference         int64
#  7    balloffootlength                int64
#  8    biacromialbreadth               int64
#  9    bicepscircumferenceflexed       int64
#  10   bicristalbreadth                int64
#  11   bideltoidbreadth                int64
#  12   bimalleolarbreadth              int64
#  13   bitragionchinarc                int64
#  14   bitragionsubmandibulararc       int64
#  15   bizygomaticbreadth              int64
#  16   buttockcircumference            int64
#  17   buttockdepth                    int64
#  18   buttockheight                   int64
#  19   buttockkneelength               int64
#  20   buttockpopliteallength          int64
#  21   calfcircumference               int64
#  22   cervicaleheight                 int64
#  23   chestbreadth                    int64
#  24   chestcircumference              int64
#  25   chestdepth                      int64
#  26   chestheight                     int64
#  27   crotchheight                    int64
#  28   crotchlengthomphalion           int64
#  29   crotchlengthposterioromphalion  int64
#  30   earbreadth                      int64
#  31   earlength                       int64
#  32   earprotrusion                   int64
#  33   elbowrestheight                 int64
#  34   eyeheightsitting                int64
#  35   footbreadthhorizontal           int64
#  36   footlength                      int64
#  37   forearmcenterofgriplength       int64
#  38   forearmcircumferenceflexed      int64
#  39   forearmforearmbreadth           int64
#  40   forearmhandlength               int64
#  41   functionalleglength             int64
#  42   handbreadth                     int64
#  43   handcircumference               int64
#  44   handlength                      int64
#  45   headbreadth                     int64
#  46   headcircumference               int64
#  47   headlength                      int64
#  48   heelanklecircumference          int64
#  49   heelbreadth                     int64
#  50   hipbreadth                      int64
#  51   hipbreadthsitting               int64
#  52   iliocristaleheight              int64
#  53   interpupillarybreadth           int64
#  54   interscyei                      int64
#  55   interscyeii                     int64
#  56   kneeheightmidpatella            int64
#  57   kneeheightsitting               int64
#  58   lateralfemoralepicondyleheight  int64
#  59   lateralmalleolusheight          int64
#  60   lowerthighcircumference         int64
#  61   mentonsellionlength             int64
#  62   neckcircumference               int64
#  63   neckcircumferencebase           int64
#  64   overheadfingertipreachsitting   int64
#  65   palmlength                      int64
#  66   poplitealheight                 int64
#  67   radialestylionlength            int64
#  68   shouldercircumference           int64
#  69   shoulderelbowlength             int64
#  70   shoulderlength                  int64
#  71   sittingheight                   int64
#  72   sleevelengthspinewrist          int64
#  73   sleeveoutseam                   int64
#  74   span                            int64
#  75   stature                         int64
#  76   suprasternaleheight             int64
#  77   tenthribheight                  int64
#  78   thighcircumference              int64
#  79   thighclearance                  int64
#  80   thumbtipreach                   int64
#  81   tibialheight                    int64
#  82   tragiontopofhead                int64
#  83   trochanterionheight             int64
#  84   verticaltrunkcircumferenceusa   int64
#  85   waistbacklength                 int64
#  86   waistbreadth                    int64
#  87   waistcircumference              int64
#  88   waistdepth                      int64
#  89   waistfrontlengthsitting         int64
#  90   waistheightomphalion            int64
#  91   weightkg                        int64
#  92   wristcircumference              int64
#  93   wristheight                     int64
#  94   Gender                          object
#  95   Date                            object
#  96   Installation                    object
#  97   Component                       object
#  98   Branch                          object
#  99   PrimaryMOS                      object
#  100  SubjectsBirthLocation           object
#  101  SubjectNumericRace              int64
#  102  Ethnicity                       object
#  103  DODRace                         int64
#  104  Age                             int64
#  105  Heightin                        int64
#  106  Weightlbs                       int64
#  107  WritingPreference               object
#  108  SubjectId                       float64
# dtypes: float64(2), int64(98), object(9)
# memory usage: 5.0+ MB

# %%
data.isnull().sum().any()
# Out:
# True

# %%
data.duplicated().sum()
# Out:
# 0

# %%
print(data["DODRace"].value_counts())
data["DODRace"].value_counts().plot(kind="pie", autopct='%1.1f%%',figsize=(10,10));
# Out:
# 1    3792
# 2    1298
# 3     679
# 4     188
# 6      59
# 5      49
# 8       3
# Name: DODRace, dtype: int64

# %%
drop_list =[]
for col in data:
  if data[col].isnull().sum()>1800:
    print(f"{col} = {data[col].isnull().sum()}")
    drop_list.append(col)
  
  
drop_list
# Out:
# subjectid = 1986
# Ethnicity = 4647
# SubjectId = 4082
# ['subjectid', 'Ethnicity', 'SubjectId']

# %%
data.drop(drop_list, axis=1, inplace=True)

# %%
data.isnull().sum().any()
# Out:
# False

# %%
data.shape
# Out:
# (6068, 106)

# %%
# to find how many unique values object features have
for col in data.select_dtypes("object"):
  print(f"{col} has {data[col].nunique()} unique value")
# Out:
# Gender has 2 unique value
# Date has 253 unique value
# Installation has 12 unique value
# Component has 3 unique value
# Branch has 3 unique value
# PrimaryMOS has 285 unique value
# SubjectsBirthLocation has 152 unique value
# WritingPreference has 3 unique value

# %%
data.DODRace.unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 8])

# %%
data["DODRace"] = data.DODRace.map({
    1: "White",
    2: "Black",
    3: "Hispanic",
    4: "Asian",
    5: "Native American",
    6: "Pacific Islander",
    8: "Other"
})

# %%
data.groupby(["Component"])["DODRace"].value_counts(normalize=True)
# Out:
# Component            DODRace
# Army National Guard  White               0.685007
#                      Black               0.184269
#                      Hispanic            0.093427
#                      Asian               0.022157
#                      Native American     0.008863
#                      Pacific Islander    0.006278
# Army Reserve         White               0.518182
#                      Black               0.236364
#                      Hispanic            0.186364
#                      Asian               0.040909
#                      Pacific Islander    0.013636
#                      Native American     0.004545
# Regular Army         White               0.580573
#                      Black               0.237898
#                      Hispanic            0.122611
#                      Asian               0.037898
#                      Pacific Islander    0.012420
#                      Native American     0.007643
#                      Other               0.000955
# Name: DODRace, dtype: float64

# %%
data.groupby(["Component"])["DODRace"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='Component,DODRace'>

# %%
data.groupby(["Component", "Branch"])["DODRace"].value_counts(normalize=True) #.iplot(kind="barh")
# Out:
# Component            Branch                  DODRace
# Army National Guard  Combat Arms             White               0.771995
#                                              Black               0.097893
#                                              Hispanic            0.091698
#                                              Asian               0.022305
#                                              Native American     0.011152
#                                              Pacific Islander    0.004957
#                      Combat Service Support  White               0.643509
#                                              Black               0.218947
#                                              Hispanic            0.099649
#                                              Asian               0.023158
#                                              Pacific Islander    0.007719
#                                              Native American     0.007018
#                      Combat Support          White               0.661765
#                                              Black               0.226891
#                                              Hispanic            0.077731
#                                              Asian               0.018908
#                                              Native American     0.010504
#                                              Pacific Islander    0.004202
# Army Reserve         Combat Arms             White               0.833333
#                                              Hispanic            0.166667
#                      Combat Service Support  White               0.561644
#                                              Hispanic            0.205479
#                                              Black               0.164384
#                                              Asian               0.047945
#                                              Pacific Islander    0.013699
#                                              Native American     0.006849
#                      Combat Support          Black               0.411765
#                                              White               0.397059
#                                              Hispanic            0.147059
#                                              Asian               0.029412
#                                              Pacific Islander    0.014706
# Regular Army         Combat Arms             White               0.673602
#                                              Hispanic            0.148244
#                                              Black               0.122237
#                                              Asian               0.033810
#                                              Pacific Islander    0.011704
#                                              Native American     0.009103
#                                              Other               0.001300
#                      Combat Service Support  White               0.568933
#                                              Black               0.255147
#                                              Hispanic            0.120399
#                                              Asian               0.036806
#                                              Native American     0.008734
#                                              Pacific Islander    0.008734
#                                              Other               0.001248
#                      Combat Support          White               0.511719
#                                              Black               0.317708
#                                              Hispanic            0.101562
#                                              Asian               0.044271
#                                              Pacific Islander    0.020833
#                                              Native American     0.003906
# Name: DODRace, dtype: float64

# %%
drop_list1 = [
    "Date", "Installation", "Component", "Branch", "PrimaryMOS",
    "Weightlbs", "Heightin"   
]

data.drop(drop_list1, axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['abdominalextensiondepthsitting', 'acromialheight', 'acromionradialelength', 'anklecircumference', 'axillaheight', 'balloffootcircumference', 'balloffootlength', 'biacromialbreadth', 'bicepscircumferenceflexed', 'bicristalbreadth', 'bideltoidbreadth', 'bimalleolarbreadth', 'bitragionchinarc', 'bitragionsubmandibulararc', 'bizygomaticbreadth', 'buttockcircumference', 'buttockdepth', 'buttockheight', 'buttockkneelength', 'buttockpopliteallength', 'calfcircumference', 'cervicaleheight', 'chestbreadth', 'chestcircumference', 'chestdepth', 'chestheight', 'crotchheight', 'crotchlengthomphalion', 'crotchlengthposterioromphalion', 'earbreadth', 'earlength', 'earprotrusion', 'elbowrestheight', 'eyeheightsitting', 'footbreadthhorizontal', 'footlength', 'forearmcenterofgriplength', 'forearmcircumferenceflexed', 'forearmforearmbreadth', 'forearmhandlength', 'functionalleglength', 'handbreadth', 'handcircumference', 'handlength', 'headbreadth', 'headcircumference', 'headlength',
#        'heelanklecircumference', 'heelbreadth', 'hipbreadth', 'hipbreadthsitting', 'iliocristaleheight', 'interpupillarybreadth', 'interscyei', 'interscyeii', 'kneeheightmidpatella', 'kneeheightsitting', 'lateralfemoralepicondyleheight', 'lateralmalleolusheight', 'lowerthighcircumference', 'mentonsellionlength', 'neckcircumference', 'neckcircumferencebase', 'overheadfingertipreachsitting', 'palmlength', 'poplitealheight', 'radialestylionlength', 'shouldercircumference', 'shoulderelbowlength', 'shoulderlength', 'sittingheight', 'sleevelengthspinewrist', 'sleeveoutseam', 'span', 'stature', 'suprasternaleheight', 'tenthribheight', 'thighcircumference', 'thighclearance', 'thumbtipreach', 'tibialheight', 'tragiontopofhead', 'trochanterionheight', 'verticaltrunkcircumferenceusa', 'waistbacklength', 'waistbreadth', 'waistcircumference', 'waistdepth', 'waistfrontlengthsitting', 'waistheightomphalion', 'weightkg', 'wristcircumference', 'wristheight', 'Gender', 'SubjectsBirthLocation',
#        'SubjectNumericRace', 'DODRace', 'Age', 'WritingPreference'],
#       dtype='object')

# %%
data.SubjectNumericRace.value_counts()
# Out:
# 1        3561
# 2        1026
# 3         541
# 31        160
# 51        126
# 8         116
# 4         109
# 21         60
# 6          59
# 41         46
# 61         35
# 23         34
# 28         26
# 251        20
# 5          18
# 18         18
# 25         14
# 351        10
# 38          9
# 64          8
# 62          8
# 35          8
# 42          7
# 63          7
# 231         6
# 43          5
# 235         4
# 218         3
# 651         2
# 2351        2
# 318         2
# 641         2
# 451         2
# 423         2
# 431         2
# 2518        2
# 48          1
# 631         1
# 4251        1
# 428         1
# 238         1
# 358         1
# 425         1
# 42351       1
# Name: SubjectNumericRace, dtype: int64

# %%
data.drop("SubjectNumericRace",axis=1,inplace=True)

# %%
data.DODRace.value_counts()
# Out:
# White               3792
# Black               1298
# Hispanic             679
# Asian                188
# Pacific Islander      59
# Native American       49
# Other                  3
# Name: DODRace, dtype: int64

# %%
data = data[(data["DODRace"] == "White") | (data["DODRace"] == "Black") |
                (data["DODRace"] == "Hispanic")]
data
# Out:
#       abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0                                266            1467                    337                 222          1347                      253               202                401                        369               274               493                  71               319                        291                 142                   979           240            882                619                     509                373             1535           291                1074         259         1292           877                    607                             351          36         71             19              247               802                    101         273                        349                         299                    575                477                 1136           90                214         193          150                583         206                     326           70         332                366                1071
# 1                                233            1395                    326                 220          1293                      245               193                394                        338               257               479                  67               344                        320                 135                   944           232            870                584                     468                357             1471           269                1021         253         1244           851                    615                             376          33         62             18              232               781                     98         263                        348                         289                    523                476                 1096           86                203         195          146                568         201                     334           72         312                356                1046
# 2                                287            1430                    341                 230          1327                      256               196                427                        408               261               544                  75               345                        330                 135                  1054           258            901                623                     506                412             1501           288                1120         267         1288           854                    636                             359          40         61             23              237               810                    103         270                        355                         357                    575                491                 1115           93                220         203          148                573         202                     356           70         349                393                1053
# 3                                234            1347                    310                 230          1239                      262               199                401                        359               262               518                  73               328                        309                 143                   991           242            821                560                     437                395             1423           296                1114         262         1205           769                    590                             341          39         66             25              272               794                    106         267                        352                         318                    593                467                 1034           91                217         194          158                576         199                     341           68         338                367                 986
# 4                                250            1585                    372                 247          1478                      267               224                435                        356               263               524                  80               340                        310                 138                  1029           275           1080                706                     567                425             1684           304                1048         232         1452          1014                    682                             382          32         56             19              188               814                    111         305                        399                         324                    605                550                 1279           94                222         218          153                566         197                     374           69         332                372                1251
# ...                              ...             ...                    ...                 ...           ...                      ...               ...                ...                        ...               ...               ...                 ...               ...                        ...                 ...                   ...           ...            ...                ...                     ...                ...              ...           ...                 ...         ...          ...           ...                    ...                             ...         ...        ...            ...              ...               ...                    ...         ...                        ...                         ...                    ...                ...                  ...          ...                ...         ...          ...                ...         ...                     ...          ...         ...                ...                 ...
# 6063                             285            1392                    335                 223          1297                      252               196                368                        299               312               477                  72               306                        282                 136                  1089           255            856                652                     541                373             1457           290                1082         293         1258           779                    732                             382          36         60             19              210               746                    103         259                        328                         262                    514                456                 1085           81                197         193          151                582         205                     321           75         381                413                1048
# 6064                             262            1324                    301                 202          1204                      236               181                378                        294               287               468                  66               309                        311                 145                  1016           246            818                572                     464                375             1390           291                1016         269         1151           732                    647                             331          36         65             23              274               770                    101         245                        319                         261                    514                440                  985           81                196         183          160                570         186                     296           61         347                377                 974
# 6065                             260            1334                    318                 213          1259                      234               183                363                        332               299               460                  70               317                        311                 139                  1063           262            846                637                     525                370             1412           285                1093         286         1166           793                    609                             326          39         62             18              204               739                     97         249                        338                         288                    530                459                 1050           82                192         191          144                559         190                     318           72         364                400                 986
# 6066                             205            1293                    302                 199          1207                      213               163                376                        276               280               426                  62               282                        267                 137                  1051           225            786                582                     480                370             1377           270                 922         243         1137           763                    575                             310          35         62             21              222               738                     91         226                        306                         258                    430                425                  995           74                177         176          149                558         186                     280           59         369                411                 971
# 6067                             238            1346                    308                 210          1256                      236               188                361                        285               279               433                  71               304                        278                 129                   974           217            820                586                     479                343             1401           272                 902         219         1186           783                    536                             307          35         58             23              243               754                    100         239                        314                         259                    464                439                 1053           78                187         177          148                561         189                     310           78         332                376                 994
#
#       interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight  Gender SubjectsBirthLocation   DODRace  Age WritingPreference
# 0                       685         422          441                   502                560                             500                      77                      391                  118                400                    436                           1447         113              437                   273                   1151                  368             145            928                     883            600  1782     1776                 1449            1092                 610             164            786           491               140                  919                           1700              501           329                 933         240                      440                  1054       815                 175          853    Male          North Dakota     White   41        Right hand
# 1                       620         441          447                   490                540                             488                      73                      371                  131                380                    420                           1380         118              417                   254                   1119                  353             141            884                     868            564  1745     1702                 1387            1076                 572             169            822           476               120                  918                           1627              432           316                 870         225                      371                  1054       726                 167          815    Male              New York     White   35         Left hand
# 2                       665         462          475                   496                556                             482                      72                      409                  123                403                    434                           1447         121              431                   268                   1276                  367             167            917                     910            604  1867     1735                 1438            1105                 685             198            807           477               125                  918                           1678              472           329                 964         255                      411                  1041       929                 180          831    Male              New York     Black   42         Left hand
# 3                       640         458          461                   460                511                             452                      76                      393                  106                407                    446                           1357         118              393                   249                   1155                  330             148            903                     848            550  1708     1655                 1346            1021                 604             180            803           445               127                  847                           1625              461           315                 857         205                      399                   968       794                 176          793    Male             Wisconsin     White   31        Right hand
# 4                       675         481          505                   612                666                             585                      85                      458                  135                398                    430                           1572         132              523                   302                   1231                  400             180            919                     995            641  2035     1914                 1596            1292                 672             194            962           584               122                 1090                           1679              467           303                 868         214                      379                  1245       946                 188          954    Male        North Carolina     Black   21        Right hand
# ...                     ...         ...          ...                   ...                ...                             ...                     ...                      ...                  ...                ...                    ...                            ...         ...              ...                   ...                    ...                  ...             ...            ...                     ...            ...   ...      ...                  ...             ...                 ...             ...            ...           ...               ...                  ...                            ...              ...           ...                 ...         ...                      ...                   ...       ...                 ...          ...     ...                   ...       ...  ...               ...
# 6063                    615         373          390                   462                535                             486                      61                      423                  121                369                    391                           1307         118              414                   237                   1036                  354             145            865                     840            555  1716     1687                 1391            1119                 660             155            749           446               136                  872                           1706              447           334                1043         265                      370                  1002       832                 162          836  Female                 Texas  Hispanic   51        Right hand
# 6064                    650         400          411                   433                483                             457                      58                      383                  130                359                    399                           1323          99              377                   237                   1051                  318             142            881                     794            525  1620     1613                 1316            1043                 616             157            721           422               131                  838                           1648              446           334                 971         243                      374                   958       717                 157          804  Female                 Texas  Hispanic   40        Right hand
# 6065                    640         400          412                   450                517                             476                      57                      412                  111                352                    402                           1318         116              392                   259                   1054                  338             136            841                     848            566  1740     1644                 1337            1054                 640             159            758           449               127                  862                           1590              444           335                 982         254                      351                   970       762                 159          774  Female                 Texas     Black   40        Right hand
# 6066                    640         383          418                   432                491                             445                      58                      400                  119                326                    380                           1286         111              375                   230                    996                  321             136            854                     791            530  1628     1616                 1288            1028                 623             163            725           419               135                  802                           1525              450           298                 837         208                      335                   952       632                 146          769  Female                 Texas  Hispanic   31        Right hand
# 6067                    595         333          373                   444                504                             445                      66                      372                  114                325                    381                           1372         112              390                   249                    997                  339             135            861                     821            542  1685     1641                 1334            1089                 592             162            762           436               130                  849                           1547              462           299                 891         223                      394                   943       610                 154          797  Female                 Texas  Hispanic   27        Right hand
#
# [5769 rows x 98 columns]

# %%
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#       abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference  chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion  earbreadth  earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal  footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference  handlength  headbreadth  headcircumference  headlength  heelanklecircumference  heelbreadth  hipbreadth  hipbreadthsitting  iliocristaleheight  \
# 0                                266            1467                    337                 222          1347                      253               202                401                        369               274               493                  71               319                        291                 142                   979           240            882                619                     509                373             1535           291                1074         259         1292           877                    607                             351          36         71             19              247               802                    101         273                        349                         299                    575                477                 1136           90                214         193          150                583         206                     326           70         332                366                1071
# 1                                233            1395                    326                 220          1293                      245               193                394                        338               257               479                  67               344                        320                 135                   944           232            870                584                     468                357             1471           269                1021         253         1244           851                    615                             376          33         62             18              232               781                     98         263                        348                         289                    523                476                 1096           86                203         195          146                568         201                     334           72         312                356                1046
# 2                                287            1430                    341                 230          1327                      256               196                427                        408               261               544                  75               345                        330                 135                  1054           258            901                623                     506                412             1501           288                1120         267         1288           854                    636                             359          40         61             23              237               810                    103         270                        355                         357                    575                491                 1115           93                220         203          148                573         202                     356           70         349                393                1053
# 3                                234            1347                    310                 230          1239                      262               199                401                        359               262               518                  73               328                        309                 143                   991           242            821                560                     437                395             1423           296                1114         262         1205           769                    590                             341          39         66             25              272               794                    106         267                        352                         318                    593                467                 1034           91                217         194          158                576         199                     341           68         338                367                 986
# 4                                250            1585                    372                 247          1478                      267               224                435                        356               263               524                  80               340                        310                 138                  1029           275           1080                706                     567                425             1684           304                1048         232         1452          1014                    682                             382          32         56             19              188               814                    111         305                        399                         324                    605                550                 1279           94                222         218          153                566         197                     374           69         332                372                1251
# ...                              ...             ...                    ...                 ...           ...                      ...               ...                ...                        ...               ...               ...                 ...               ...                        ...                 ...                   ...           ...            ...                ...                     ...                ...              ...           ...                 ...         ...          ...           ...                    ...                             ...         ...        ...            ...              ...               ...                    ...         ...                        ...                         ...                    ...                ...                  ...          ...                ...         ...          ...                ...         ...                     ...          ...         ...                ...                 ...
# 5764                             285            1392                    335                 223          1297                      252               196                368                        299               312               477                  72               306                        282                 136                  1089           255            856                652                     541                373             1457           290                1082         293         1258           779                    732                             382          36         60             19              210               746                    103         259                        328                         262                    514                456                 1085           81                197         193          151                582         205                     321           75         381                413                1048
# 5765                             262            1324                    301                 202          1204                      236               181                378                        294               287               468                  66               309                        311                 145                  1016           246            818                572                     464                375             1390           291                1016         269         1151           732                    647                             331          36         65             23              274               770                    101         245                        319                         261                    514                440                  985           81                196         183          160                570         186                     296           61         347                377                 974
# 5766                             260            1334                    318                 213          1259                      234               183                363                        332               299               460                  70               317                        311                 139                  1063           262            846                637                     525                370             1412           285                1093         286         1166           793                    609                             326          39         62             18              204               739                     97         249                        338                         288                    530                459                 1050           82                192         191          144                559         190                     318           72         364                400                 986
# 5767                             205            1293                    302                 199          1207                      213               163                376                        276               280               426                  62               282                        267                 137                  1051           225            786                582                     480                370             1377           270                 922         243         1137           763                    575                             310          35         62             21              222               738                     91         226                        306                         258                    430                425                  995           74                177         176          149                558         186                     280           59         369                411                 971
# 5768                             238            1346                    308                 210          1256                      236               188                361                        285               279               433                  71               304                        278                 129                   974           217            820                586                     479                343             1401           272                 902         219         1186           783                    536                             307          35         58             23              243               754                    100         239                        314                         259                    464                439                 1053           78                187         177          148                561         189                     310           78         332                376                 994
#
#       interpupillarybreadth  interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting  palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam  span  stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference  waistdepth  waistfrontlengthsitting  waistheightomphalion  weightkg  wristcircumference  wristheight  Gender SubjectsBirthLocation   DODRace  Age WritingPreference
# 0                       685         422          441                   502                560                             500                      77                      391                  118                400                    436                           1447         113              437                   273                   1151                  368             145            928                     883            600  1782     1776                 1449            1092                 610             164            786           491               140                  919                           1700              501           329                 933         240                      440                  1054       815                 175          853    Male          North Dakota     White   41        Right hand
# 1                       620         441          447                   490                540                             488                      73                      371                  131                380                    420                           1380         118              417                   254                   1119                  353             141            884                     868            564  1745     1702                 1387            1076                 572             169            822           476               120                  918                           1627              432           316                 870         225                      371                  1054       726                 167          815    Male              New York     White   35         Left hand
# 2                       665         462          475                   496                556                             482                      72                      409                  123                403                    434                           1447         121              431                   268                   1276                  367             167            917                     910            604  1867     1735                 1438            1105                 685             198            807           477               125                  918                           1678              472           329                 964         255                      411                  1041       929                 180          831    Male              New York     Black   42         Left hand
# 3                       640         458          461                   460                511                             452                      76                      393                  106                407                    446                           1357         118              393                   249                   1155                  330             148            903                     848            550  1708     1655                 1346            1021                 604             180            803           445               127                  847                           1625              461           315                 857         205                      399                   968       794                 176          793    Male             Wisconsin     White   31        Right hand
# 4                       675         481          505                   612                666                             585                      85                      458                  135                398                    430                           1572         132              523                   302                   1231                  400             180            919                     995            641  2035     1914                 1596            1292                 672             194            962           584               122                 1090                           1679              467           303                 868         214                      379                  1245       946                 188          954    Male        North Carolina     Black   21        Right hand
# ...                     ...         ...          ...                   ...                ...                             ...                     ...                      ...                  ...                ...                    ...                            ...         ...              ...                   ...                    ...                  ...             ...            ...                     ...            ...   ...      ...                  ...             ...                 ...             ...            ...           ...               ...                  ...                            ...              ...           ...                 ...         ...                      ...                   ...       ...                 ...          ...     ...                   ...       ...  ...               ...
# 5764                    615         373          390                   462                535                             486                      61                      423                  121                369                    391                           1307         118              414                   237                   1036                  354             145            865                     840            555  1716     1687                 1391            1119                 660             155            749           446               136                  872                           1706              447           334                1043         265                      370                  1002       832                 162          836  Female                 Texas  Hispanic   51        Right hand
# 5765                    650         400          411                   433                483                             457                      58                      383                  130                359                    399                           1323          99              377                   237                   1051                  318             142            881                     794            525  1620     1613                 1316            1043                 616             157            721           422               131                  838                           1648              446           334                 971         243                      374                   958       717                 157          804  Female                 Texas  Hispanic   40        Right hand
# 5766                    640         400          412                   450                517                             476                      57                      412                  111                352                    402                           1318         116              392                   259                   1054                  338             136            841                     848            566  1740     1644                 1337            1054                 640             159            758           449               127                  862                           1590              444           335                 982         254                      351                   970       762                 159          774  Female                 Texas     Black   40        Right hand
# 5767                    640         383          418                   432                491                             445                      58                      400                  119                326                    380                           1286         111              375                   230                    996                  321             136            854                     791            530  1628     1616                 1288            1028                 623             163            725           419               135                  802                           1525              450           298                 837         208                      335                   952       632                 146          769  Female                 Texas  Hispanic   31        Right hand
# 5768                    595         333          373                   444                504                             445                      66                      372                  114                325                    381                           1372         112              390                   249                    997                  339             135            861                     821            542  1685     1641                 1334            1089                 592             162            762           436               130                  849                           1547              462           299                 891         223                      394                   943       610                 154          797  Female                 Texas  Hispanic   27        Right hand
#
# [5769 rows x 98 columns]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data.corr(), cmap ="coolwarm")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %%
X = data.drop("DODRace",axis=1)
y = data.DODRace

# %%
cat = X.select_dtypes("object").columns
cat
# Out:
# Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101, stratify = y)

# %%
print("Train features shape : ", X_train.shape)
print("Train target shape   : ", y_train.shape)
print("Test features shape  : ", X_test.shape)
print("Test target shape    : ", y_test.shape)
# Out:
# Train features shape :  (4615, 97)
# Train target shape   :  (4615,)
# Test features shape  :  (1154, 97)
# Test target shape    :  (1154,)

# %%
# dummy işlemi taninmayan degerde fail veriyor onehot ignore ediyor.

from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, StandardScaler

column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), 
                                       remainder=MinMaxScaler())  # kategorik feature lara onehotencoding, diğer feature lara minmax scaler yap demek

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Vanilla Logistic Model

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
from sklearn.pipeline import Pipeline
operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=101))]

pipe_log_model = Pipeline(steps=operations)

# %%
pipe_log_model.fit(X_train,y_train)
eval_metric(pipe_log_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[239  14   7]
#  [  5 111  20]
#  [ 25  89 644]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.92      0.90       260
#     Hispanic       0.52      0.82      0.63       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.81      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 971   38   29]
#  [  20  456   67]
#  [  56  363 2615]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.94      0.93      1038
#     Hispanic       0.53      0.84      0.65       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.91      0.88      0.88      4615

# %%
# Burada amacımız Hispanic olanları doğru tespit etmek olduğu için burada scoring'i Hispaniclere göre düzenliyoruz.

scoring = {"f1_Hispanic" : make_scorer(f1_score, average = None, labels =["Hispanic"]),
           "precision_Hispanic" : make_scorer(precision_score, average = None, labels =["Hispanic"]),
           "recall_Hispanic" : make_scorer(recall_score, average = None, labels =["Hispanic"])}

# %%
operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=101))]

model = Pipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.598988
# test_precision_Hispanic    0.489686
# test_recall_Hispanic       0.773333
# dtype: float64

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
# Grid search de de hispanic recall değerini maksimize etmek istediğim için buna göre scorer'ımı ayarlıyorum.

recall_Hispanic =  make_scorer(recall_score, average=None, labels=["Hispanic"])

# %%
param_grid = {
    "log__C": [1, 5, 10],
    'log__penalty': ["l1", "l2"],
    'log__solver': ['liblinear', 'lbfgs'],
}

# %%
operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=101))]

model = Pipeline(steps=operations)

log_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=3,
                              scoring=recall_Hispanic,
                              n_jobs=-1, cv=5)

# %%
log_model_grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 3/5] END log__C=1, log__penalty=l1, log__solver=liblinear;, score=0.606 total time=   7.7s
# [CV 2/5] END log__C=1, log__penalty=l1, log__solver=liblinear;, score=0.688 total time=   7.9s
# [CV 1/5] END log__C=1, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.1s
# [CV 2/5] END log__C=1, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.1s
# [CV 1/5] END log__C=1, log__penalty=l1, log__solver=liblinear;, score=0.670 total time=   8.3s
# [CV 3/5] END log__C=1, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.1s
# [CV 4/5] END log__C=1, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END log__C=1, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.1s
# [CV 1/5] END log__C=1, log__penalty=l2, log__solver=liblinear;, score=0.661 total time=   0.9s
# [CV 2/5] END log__C=1, log__penalty=l2, log__solver=liblinear;, score=0.670 total time=   0.9s
# [CV 4/5] END log__C=1, log__penalty=l1, log__solver=liblinear;, score=0.639 total time=   9.9s
# [CV 3/5] END log__C=1, log__penalty=l2, log__solver=liblinear;, score=0.578 total time=   0.9s
# [CV 4/5] END log__C=1, log__penalty=l2, log__solver=liblinear;, score=0.639 total time=   0.9s
# [CV 5/5] END log__C=1, log__penalty=l2, log__solver=liblinear;, score=0.630 total time=   0.8s
# [CV 1/5] END log__C=1, log__penalty=l2, log__solver=lbfgs;, score=0.789 total time=   4.4s
# [CV 2/5] END log__C=1, log__penalty=l2, log__solver=lbfgs;, score=0.752 total time=   4.3s
# [CV 3/5] END log__C=1, log__penalty=l2, log__solver=lbfgs;, score=0.789 total time=   4.9s
# [CV 5/5] END log__C=1, log__penalty=l1, log__solver=liblinear;, score=0.639 total time=   9.0s
# [CV 5/5] END log__C=1, log__penalty=l2, log__solver=lbfgs;, score=0.769 total time=   5.0s
# [CV 4/5] END log__C=1, log__penalty=l2, log__solver=lbfgs;, score=0.759 total time=   5.4s
# [CV 1/5] END log__C=5, log__penalty=l1, log__solver=liblinear;, score=0.697 total time=  24.6s
# [CV 3/5] END log__C=5, log__penalty=l1, log__solver=liblinear;, score=0.642 total time=  20.7s
# [CV 1/5] END log__C=5, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END log__C=5, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.1s
# [CV 3/5] END log__C=5, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.1s
# [CV 4/5] END log__C=5, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END log__C=5, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.1s
# [CV 2/5] END log__C=5, log__penalty=l1, log__solver=liblinear;, score=0.688 total time=  25.1s
# [CV 1/5] END log__C=5, log__penalty=l2, log__solver=liblinear;, score=0.688 total time=   1.0s
# [CV 4/5] END log__C=5, log__penalty=l1, log__solver=liblinear;, score=0.630 total time=  22.1s
# [CV 2/5] END log__C=5, log__penalty=l2, log__solver=liblinear;, score=0.697 total time=   1.1s
# [CV 3/5] END log__C=5, log__penalty=l2, log__solver=liblinear;, score=0.633 total time=   1.2s
# [CV 4/5] END log__C=5, log__penalty=l2, log__solver=liblinear;, score=0.639 total time=   1.3s
# [CV 5/5] END log__C=5, log__penalty=l2, log__solver=liblinear;, score=0.630 total time=   1.2s
# [CV 1/5] END log__C=5, log__penalty=l2, log__solver=lbfgs;, score=0.798 total time=   8.7s
# [CV 2/5] END log__C=5, log__penalty=l2, log__solver=lbfgs;, score=0.771 total time=   8.5s
# [CV 3/5] END log__C=5, log__penalty=l2, log__solver=lbfgs;, score=0.789 total time=   8.8s
# [CV 5/5] END log__C=5, log__penalty=l1, log__solver=liblinear;, score=0.639 total time=  22.2s
# [CV 5/5] END log__C=5, log__penalty=l2, log__solver=lbfgs;, score=0.750 total time=  10.0s
# [CV 4/5] END log__C=5, log__penalty=l2, log__solver=lbfgs;, score=0.741 total time=  11.9s
# [CV 1/5] END log__C=10, log__penalty=l1, log__solver=liblinear;, score=0.716 total time=  43.8s
# [CV 3/5] END log__C=10, log__penalty=l1, log__solver=liblinear;, score=0.642 total time=  38.6s
# [CV 1/5] END log__C=10, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.1s
# [CV 2/5] END log__C=10, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.1s
# [CV 3/5] END log__C=10, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.1s
# [CV 4/5] END log__C=10, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.1s
# [CV 5/5] END log__C=10, log__penalty=l1, log__solver=lbfgs;, score=nan total time=   0.1s
# [CV 4/5] END log__C=10, log__penalty=l1, log__solver=liblinear;, score=0.620 total time=  38.4s
# [CV 1/5] END log__C=10, log__penalty=l2, log__solver=liblinear;, score=0.706 total time=   2.2s
# [CV 2/5] END log__C=10, log__penalty=l2, log__solver=liblinear;, score=0.679 total time=   2.1s
# [CV 3/5] END log__C=10, log__penalty=l2, log__solver=liblinear;, score=0.633 total time=   1.7s
# [CV 4/5] END log__C=10, log__penalty=l2, log__solver=liblinear;, score=0.639 total time=   2.1s
# [CV 5/5] END log__C=10, log__penalty=l2, log__solver=liblinear;, score=0.648 total time=   1.9s
# [CV 2/5] END log__C=10, log__penalty=l1, log__solver=liblinear;, score=0.697 total time=  52.6s
# [CV 1/5] END log__C=10, log__penalty=l2, log__solver=lbfgs;, score=0.789 total time=   9.4s
# [CV 2/5] END log__C=10, log__penalty=l2, log__solver=lbfgs;, score=0.761 total time=  11.3s
# [CV 3/5] END log__C=10, log__penalty=l2, log__solver=lbfgs;, score=0.780 total time=  11.8s
# [CV 4/5] END log__C=10, log__penalty=l2, log__solver=lbfgs;, score=0.750 total time=  10.7s
# [CV 5/5] END log__C=10, log__penalty=l2, log__solver=lbfgs;, score=0.750 total time=   9.1s
# [CV 5/5] END log__C=10, log__penalty=l1, log__solver=liblinear;, score=0.639 total time=  36.3s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                                        ('log',
#                                         LogisticRegression(class_weight='balanced',
#                                                            max_iter=10000,
#                                                            random_state=101))]),
#              n_jobs=-1,
#              param_grid={'log__C': [1, 5, 10], 'log__penalty': ['l1', 'l2'],
#                          'log__solver': ['liblinear', 'lbfgs']},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
log_model_grid.best_estimator_
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                 ('log',
#                  LogisticRegression(C=1, class_weight='balanced',
#                                     max_iter=10000, random_state=101))])

# %%
log_model_grid.best_params_
# Out:
# {'log__C': 1, 'log__penalty': 'l2', 'log__solver': 'lbfgs'}

# %%
log_model_grid.best_score_
# Out:
# 0.7716106014271152

# %%
eval_metric(log_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[239  14   7]
#  [  5 111  20]
#  [ 25  89 644]]
#               precision    recall  f1-score   support
#
#        Black       0.89      0.92      0.90       260
#     Hispanic       0.52      0.82      0.63       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.81      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 971   38   29]
#  [  20  456   67]
#  [  56  363 2615]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.94      0.93      1038
#     Hispanic       0.53      0.84      0.65       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.91      0.88      0.88      4615

# %%
from yellowbrick.classifier import PrecisionRecallCurve

operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=101))]

model = Pipeline(steps=operations)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
viz.score_#["Hispanic"]
# Out:
# {'Black': 0.9739822045968579,
#  'Hispanic': 0.7355600784657885,
#  'White': 0.9714329291116479,
#  'micro': 0.9382554076898975}

# %%
y_pred = log_model_grid.predict(X_test)

log_AP = viz.score_["Hispanic"]
log_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
log_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## Lojistic Regression solver "liblenear" for small dataset

# %%
operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                    random_state=101, solver="liblinear", penalty="l1"))]

pipe_log_model_libl = Pipeline(steps=operations)

# %%
pipe_log_model_libl.fit(X_train,y_train)
eval_metric(pipe_log_model_libl, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[245   4  11]
#  [  5  96  35]
#  [ 18  34 706]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.94      0.93       260
#     Hispanic       0.72      0.71      0.71       136
#        White       0.94      0.93      0.94       758
#
#     accuracy                           0.91      1154
#    macro avg       0.86      0.86      0.86      1154
# weighted avg       0.91      0.91      0.91      1154
#
#
# Train_Set
# [[ 975   19   44]
#  [  29  386  128]
#  [  43  146 2845]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.94      0.94      1038
#     Hispanic       0.70      0.71      0.71       543
#        White       0.94      0.94      0.94      3034
#
#     accuracy                           0.91      4615
#    macro avg       0.86      0.86      0.86      4615
# weighted avg       0.91      0.91      0.91      4615

# %%
operations = [("OneHotEncoder", column_trans), ("log", LogisticRegression(class_weight='balanced',max_iter=10000, 
                                                                    random_state=101,solver="liblinear", penalty="l1"))]

model = Pipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 5)
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.656005
# test_precision_Hispanic    0.664780
# test_recall_Hispanic       0.648216
# dtype: float64

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %%
operations_svc = [("OneHotEncoder", column_trans), ("svc", SVC(class_weight="balanced",random_state=101))]

pipe_svc_model = Pipeline(steps=operations_svc)

# %%
pipe_svc_model.fit(X_train, y_train)

eval_metric(pipe_svc_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[240  12   8]
#  [  5 111  20]
#  [ 20 109 629]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.92      0.91       260
#     Hispanic       0.48      0.82      0.60       136
#        White       0.96      0.83      0.89       758
#
#     accuracy                           0.85      1154
#    macro avg       0.78      0.86      0.80      1154
# weighted avg       0.89      0.85      0.86      1154
#
#
# Train_Set
# [[ 956   42   40]
#  [  23  456   64]
#  [  54  426 2554]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.92      0.92      1038
#     Hispanic       0.49      0.84      0.62       543
#        White       0.96      0.84      0.90      3034
#
#     accuracy                           0.86      4615
#    macro avg       0.79      0.87      0.81      4615
# weighted avg       0.90      0.86      0.87      4615

# %%
model = Pipeline(steps=operations_svc)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 5)
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.567945
# test_precision_Hispanic    0.452935
# test_recall_Hispanic       0.762368
# dtype: float64

# %% [markdown]
# ###  SVC Model GridsearchCV

# %%
param_grid = {
    'svc__C': [1,2],
    'svc__gamma': ["scale", "auto", 1, 0.1, 0.01]
}

# %%
operations_svc = [("OneHotEncoder", column_trans), ("svc", SVC(class_weight="balanced",random_state=101))]

model = Pipeline(steps=operations_svc)

svm_model_grid = GridSearchCV(model,
                              param_grid,
                              verbose=3,
                              scoring=recall_Hispanic,
                              n_jobs=-1)

# %%
svm_model_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END ........svc__C=1, svc__gamma=scale;, score=0.798 total time=  11.7s
# [CV 3/5] END ........svc__C=1, svc__gamma=scale;, score=0.771 total time=  11.9s
# [CV 2/5] END ........svc__C=1, svc__gamma=scale;, score=0.752 total time=  12.0s
# [CV 4/5] END ........svc__C=1, svc__gamma=scale;, score=0.750 total time=  12.4s
# [CV 5/5] END ........svc__C=1, svc__gamma=scale;, score=0.741 total time=  10.8s
# [CV 1/5] END .........svc__C=1, svc__gamma=auto;, score=0.697 total time=  17.4s
# [CV 2/5] END .........svc__C=1, svc__gamma=auto;, score=0.752 total time=  17.6s
# [CV 3/5] END .........svc__C=1, svc__gamma=auto;, score=0.679 total time=  17.6s
# [CV 4/5] END .........svc__C=1, svc__gamma=auto;, score=0.722 total time=  17.2s
# [CV 5/5] END .........svc__C=1, svc__gamma=auto;, score=0.648 total time=  17.6s
# [CV 1/5] END ............svc__C=1, svc__gamma=1;, score=0.532 total time=  17.9s
# [CV 2/5] END ............svc__C=1, svc__gamma=1;, score=0.514 total time=  18.2s
# [CV 3/5] END ............svc__C=1, svc__gamma=1;, score=0.541 total time=  16.4s
# [CV 1/5] END ..........svc__C=1, svc__gamma=0.1;, score=0.807 total time=   8.6s
# [CV 4/5] END ............svc__C=1, svc__gamma=1;, score=0.454 total time=  14.6s
# [CV 5/5] END ............svc__C=1, svc__gamma=1;, score=0.509 total time=  14.7s
# [CV 2/5] END ..........svc__C=1, svc__gamma=0.1;, score=0.771 total time=   8.3s
# [CV 3/5] END ..........svc__C=1, svc__gamma=0.1;, score=0.780 total time=   8.2s
# [CV 4/5] END ..........svc__C=1, svc__gamma=0.1;, score=0.731 total time=  10.4s
# [CV 5/5] END ..........svc__C=1, svc__gamma=0.1;, score=0.731 total time=   9.8s
# [CV 1/5] END .........svc__C=1, svc__gamma=0.01;, score=0.734 total time=  13.6s
# [CV 2/5] END .........svc__C=1, svc__gamma=0.01;, score=0.743 total time=  14.0s
# [CV 3/5] END .........svc__C=1, svc__gamma=0.01;, score=0.734 total time=  15.2s
# [CV 4/5] END .........svc__C=1, svc__gamma=0.01;, score=0.759 total time=  15.1s
# [CV 1/5] END ........svc__C=2, svc__gamma=scale;, score=0.807 total time=  11.3s
# [CV 5/5] END .........svc__C=1, svc__gamma=0.01;, score=0.676 total time=  16.9s
# [CV 2/5] END ........svc__C=2, svc__gamma=scale;, score=0.752 total time=  10.7s
# [CV 3/5] END ........svc__C=2, svc__gamma=scale;, score=0.780 total time=  10.7s
# [CV 4/5] END ........svc__C=2, svc__gamma=scale;, score=0.759 total time=  10.8s
# [CV 5/5] END ........svc__C=2, svc__gamma=scale;, score=0.722 total time=  11.2s
# [CV 1/5] END .........svc__C=2, svc__gamma=auto;, score=0.725 total time=  17.0s
# [CV 2/5] END .........svc__C=2, svc__gamma=auto;, score=0.743 total time=  17.0s
# [CV 3/5] END .........svc__C=2, svc__gamma=auto;, score=0.734 total time=  16.2s
# [CV 4/5] END .........svc__C=2, svc__gamma=auto;, score=0.759 total time=  16.9s
# [CV 5/5] END .........svc__C=2, svc__gamma=auto;, score=0.667 total time=  15.0s
# [CV 1/5] END ............svc__C=2, svc__gamma=1;, score=0.468 total time=  19.9s
# [CV 2/5] END ............svc__C=2, svc__gamma=1;, score=0.468 total time=  19.4s
# [CV 3/5] END ............svc__C=2, svc__gamma=1;, score=0.431 total time=  18.3s
# [CV 1/5] END ..........svc__C=2, svc__gamma=0.1;, score=0.817 total time=   9.6s
# [CV 4/5] END ............svc__C=2, svc__gamma=1;, score=0.435 total time=  21.4s
# [CV 2/5] END ..........svc__C=2, svc__gamma=0.1;, score=0.752 total time=  10.1s
# [CV 5/5] END ............svc__C=2, svc__gamma=1;, score=0.481 total time=  19.9s
# [CV 3/5] END ..........svc__C=2, svc__gamma=0.1;, score=0.780 total time=   9.8s
# [CV 4/5] END ..........svc__C=2, svc__gamma=0.1;, score=0.713 total time=  10.9s
# [CV 5/5] END ..........svc__C=2, svc__gamma=0.1;, score=0.713 total time=  10.5s
# [CV 1/5] END .........svc__C=2, svc__gamma=0.01;, score=0.771 total time=  17.8s
# [CV 2/5] END .........svc__C=2, svc__gamma=0.01;, score=0.771 total time=  18.7s
# [CV 3/5] END .........svc__C=2, svc__gamma=0.01;, score=0.780 total time=  20.3s
# [CV 4/5] END .........svc__C=2, svc__gamma=0.01;, score=0.750 total time=  20.5s
# [CV 5/5] END .........svc__C=2, svc__gamma=0.01;, score=0.657 total time=  13.1s
# GridSearchCV(estimator=Pipeline(steps=[('OneHotEncoder',
#                                         ColumnTransformer(remainder=MinMaxScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore',
#                                                                                        sparse=False),
#                                                                          Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                                        ('svc',
#                                         SVC(class_weight='balanced',
#                                             random_state=101))]),
#              n_jobs=-1,
#              param_grid={'svc__C': [1, 2],
#                          'svc__gamma': ['scale', 'auto', 1, 0.1, 0.01]},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
svm_model_grid.best_params_
# Out:
# {'svc__C': 2, 'svc__gamma': 'scale'}

# %%
svm_model_grid.best_score_
# Out:
# 0.764186204553177

# %%
eval_metric(svm_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[240  10  10]
#  [  5 111  20]
#  [ 22  94 642]]
#               precision    recall  f1-score   support
#
#        Black       0.90      0.92      0.91       260
#     Hispanic       0.52      0.82      0.63       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.86      0.81      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 970   35   33]
#  [  16  466   61]
#  [  52  373 2609]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.93      0.93      1038
#     Hispanic       0.53      0.86      0.66       543
#        White       0.97      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.91      0.88      0.89      4615

# %%
operations_svc = [("OneHotEncoder", column_trans), ("svc", SVC(C=2, class_weight="balanced",random_state=101))]

model = Pipeline(steps=operations_svc)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
y_pred = svm_model_grid.predict(X_test)

svc_AP = viz.score_["Hispanic"]
svc_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
svc_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 3. RF

# %%
cat
# Out:
# Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object')

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OrdinalEncoder


ord_enc = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

column_trans = make_column_transformer((ord_enc, cat), remainder='passthrough')

# %% [markdown]
# ### Vanilla RF Model

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier


operations_rf = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(class_weight="balanced", 
                                                                                    random_state=101))]

pipe_model_rf = Pipeline(steps=operations_rf)

pipe_model_rf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                 ('RF_model',
#                  RandomForestClassifier(class_weight='balanced',
#                                         random_state=101))])

# %%
eval_metric(pipe_model_rf, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[191   0  69]
#  [ 10   6 120]
#  [ 10   2 746]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.73      0.81       260
#     Hispanic       0.75      0.04      0.08       136
#        White       0.80      0.98      0.88       758
#
#     accuracy                           0.82      1154
#    macro avg       0.82      0.59      0.59      1154
# weighted avg       0.82      0.82      0.77      1154
#
#
# Train_Set
# [[1038    0    0]
#  [   0  542    1]
#  [   0    0 3034]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00      1038
#     Hispanic       1.00      1.00      1.00       543
#        White       1.00      1.00      1.00      3034
#
#     accuracy                           1.00      4615
#    macro avg       1.00      1.00      1.00      4615
# weighted avg       1.00      1.00      1.00      4615

# %%
operations_rf = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(class_weight="balanced", 
                                                                                    random_state=101))]

model = Pipeline(steps=operations_rf)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 5)
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.049538
# test_precision_Hispanic    0.777143
# test_recall_Hispanic       0.025807
# dtype: float64

# %% [markdown]
# ### RF Model GridsearchCV

# %%
param_grid = {'RF_model__n_estimators':[400,500],
             'RF_model__max_depth':[2,3]} #'min_samples_split':[18,20,22], 'max_features': ['auto', None, 15, 20]

# %%
operations_rf = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(class_weight="balanced", 
                                                                                    random_state=101))]

model = Pipeline(steps=operations_rf)
rf_grid_model = GridSearchCV(model,
                             param_grid,
                             verbose=3,
                             scoring=recall_Hispanic,
                             n_jobs=-1)

# %%
rf_grid_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END RF_model__max_depth=2, RF_model__n_estimators=400;, score=0.606 total time=   6.8s
# [CV 2/5] END RF_model__max_depth=2, RF_model__n_estimators=400;, score=0.679 total time=   6.8s
# [CV 3/5] END RF_model__max_depth=2, RF_model__n_estimators=400;, score=0.541 total time=   6.9s
# [CV 4/5] END RF_model__max_depth=2, RF_model__n_estimators=400;, score=0.630 total time=   7.0s
# [CV 5/5] END RF_model__max_depth=2, RF_model__n_estimators=400;, score=0.593 total time=   3.9s
# [CV 1/5] END RF_model__max_depth=2, RF_model__n_estimators=500;, score=0.596 total time=   4.8s
# [CV 3/5] END RF_model__max_depth=2, RF_model__n_estimators=500;, score=0.541 total time=   4.8s
# [CV 2/5] END RF_model__max_depth=2, RF_model__n_estimators=500;, score=0.670 total time=   4.9s
# [CV 4/5] END RF_model__max_depth=2, RF_model__n_estimators=500;, score=0.630 total time=   5.2s
# [CV 5/5] END RF_model__max_depth=2, RF_model__n_estimators=500;, score=0.593 total time=   5.2s
# [CV 1/5] END RF_model__max_depth=3, RF_model__n_estimators=400;, score=0.624 total time=   5.2s
# [CV 2/5] END RF_model__max_depth=3, RF_model__n_estimators=400;, score=0.651 total time=   5.3s
# [CV 3/5] END RF_model__max_depth=3, RF_model__n_estimators=400;, score=0.532 total time=   6.2s
# [CV 4/5] END RF_model__max_depth=3, RF_model__n_estimators=400;, score=0.620 total time=   6.2s
# [CV 5/5] END RF_model__max_depth=3, RF_model__n_estimators=400;, score=0.602 total time=   6.2s
# [CV 1/5] END RF_model__max_depth=3, RF_model__n_estimators=500;, score=0.624 total time=   7.7s
# [CV 2/5] END RF_model__max_depth=3, RF_model__n_estimators=500;, score=0.661 total time=   8.2s
# [CV 3/5] END RF_model__max_depth=3, RF_model__n_estimators=500;, score=0.541 total time=   7.8s
# [CV 4/5] END RF_model__max_depth=3, RF_model__n_estimators=500;, score=0.611 total time=   7.7s
# [CV 5/5] END RF_model__max_depth=3, RF_model__n_estimators=500;, score=0.593 total time=   6.8s
# GridSearchCV(estimator=Pipeline(steps=[('OrdinalEncoder',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ordinalencoder',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                                        ('RF_model',
#                                         RandomForestClassifier(class_weight='balanced',
#                                                                random_state=101))]),
#              n_jobs=-1,
#              param_grid={'RF_model__max_depth': [2, 3],
#                          'RF_model__n_estimators': [400, 500]},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
rf_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                 ('RF_model',
#                  RandomForestClassifier(class_weight='balanced', max_depth=2,
#                                         n_estimators=400, random_state=101))])

# %%
rf_grid_model.best_params_
# Out:
# {'RF_model__max_depth': 2, 'RF_model__n_estimators': 400}

# %%
rf_grid_model.best_score_
# Out:
# 0.6095820591233435

# %%
eval_metric(rf_grid_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[174  50  36]
#  [ 16  76  44]
#  [ 91 244 423]]
#               precision    recall  f1-score   support
#
#        Black       0.62      0.67      0.64       260
#     Hispanic       0.21      0.56      0.30       136
#        White       0.84      0.56      0.67       758
#
#     accuracy                           0.58      1154
#    macro avg       0.56      0.60      0.54      1154
# weighted avg       0.72      0.58      0.62      1154
#
#
# Train_Set
# [[ 702  204  132]
#  [  45  346  152]
#  [ 246 1105 1683]]
#               precision    recall  f1-score   support
#
#        Black       0.71      0.68      0.69      1038
#     Hispanic       0.21      0.64      0.31       543
#        White       0.86      0.55      0.67      3034
#
#     accuracy                           0.59      4615
#    macro avg       0.59      0.62      0.56      4615
# weighted avg       0.75      0.59      0.64      4615

# %%
operations_rf = [("OrdinalEncoder", column_trans), ("RF_model", RandomForestClassifier(class_weight="balanced", 
                                                    max_depth=2, n_estimators=400, random_state=101))]

model = Pipeline(steps=operations_rf)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
y_pred = rf_grid_model.predict(X_test)

rf_AP = viz.score_["Hispanic"]
rf_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
rf_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %%
#!pip install xgboost==0.90

# %%
import xgboost as xgb

xgb.__version__
# Out:
# '0.90'

# %%
# help(XGBClassifier)
# Out:
# Help on class XGBClassifier in module xgboost.sklearn:
#
# class XGBClassifier(XGBModel, sklearn.base.ClassifierMixin)
#  |  XGBClassifier(max_depth=3, learning_rate=0.1, n_estimators=100, verbosity=1, silent=None, objective='binary:logistic', booster='gbtree', n_jobs=1, nthread=None, gamma=0, min_child_weight=1, max_delta_step=0, subsample=1, colsample_bytree=1, colsample_bylevel=1, colsample_bynode=1, reg_alpha=0, reg_lambda=1, scale_pos_weight=1, base_score=0.5, random_state=0, seed=None, missing=None, **kwargs)
#  |
#  |  Implementation of the scikit-learn API for XGBoost classification.
#  |
#  |  Parameters
#  |  ----------
#  |  max_depth : int
#  |      Maximum tree depth for base learners.
#  |  learning_rate : float
#  |      Boosting learning rate (xgb's "eta")
#  |  n_estimators : int
#  |      Number of trees to fit.
#  |  verbosity : int
#  |      The degree of verbosity. Valid values are 0 (silent) - 3 (debug).
#  |  silent : boolean
#  |      Whether to print messages while running boosting. Deprecated. Use verbosity instead.
#  |  objective : string or callable
#  |      Specify the learning task and the corresponding learning objective or
#  |      a custom objective function to be used (see note below).
#  |  booster: string
#  |      Specify which booster to use: gbtree, gblinear or dart.
#  |  nthread : int
#  |      Number of parallel threads used to run xgboost.  (Deprecated, please use ``n_jobs``)
#  |  n_jobs : int
#  |      Number of parallel threads used to run xgboost.  (replaces ``nthread``)
#  |  gamma : float
#  |      Minimum loss reduction required to make a further partition on a leaf node of the tree.
#  |  min_child_weight : int
#  |      Minimum sum of instance weight(hessian) needed in a child.
#  |  max_delta_step : int
#  |      Maximum delta step we allow each tree's weight estimation to be.
#  |  subsample : float
#  |      Subsample ratio of the training instance.
#  |  colsample_bytree : float
#  |      Subsample ratio of columns when constructing each tree.
#  |  colsample_bylevel : float
#  |      Subsample ratio of columns for each level.
#  |  colsample_bynode : float
#  |      Subsample ratio of columns for each split.
#  |  reg_alpha : float (xgb's alpha)
#  |      L1 regularization term on weights
#  |  reg_lambda : float (xgb's lambda)
#  |      L2 regularization term on weights
#  |  scale_pos_weight : float
#  |      Balancing of positive and negative weights.
#  |  base_score:
#  |      The initial prediction score of all instances, global bias.
#  |  seed : int
#  |      Random number seed.  (Deprecated, please use random_state)
#  |  random_state : int
#  |      Random number seed.  (replaces seed)
#  |  missing : float, optional
#  |      Value in the data which needs to be present as a missing value. If
#  |      None, defaults to np.nan.
#  |  importance_type: string, default "gain"
#  |      The feature importance type for the feature_importances_ property: either "gain",
#  |      "weight", "cover", "total_gain" or "total_cover".
#  |  \*\*kwargs : dict, optional
#  |      Keyword arguments for XGBoost Booster object.  Full documentation of parameters can
#  |      be found here: https://github.com/dmlc/xgboost/blob/master/doc/parameter.rst.
#  |      Attempting to set a parameter via the constructor args and \*\*kwargs dict simultaneously
#  |      will result in a TypeError.
#  |
#  |      .. note:: \*\*kwargs unsupported by scikit-learn
#  |
#  |          \*\*kwargs is unsupported by scikit-learn.  We do not guarantee that parameters
#  |          passed via this argument will interact properly with scikit-learn.
#  |
#  |  Note
#  |  ----
#  |  A custom objective function can be provided for the ``objective``
#  |  parameter. In this case, it should have the signature
#  |  ``objective(y_true, y_pred) -> grad, hess``:
#  |
#  |  y_true: array_like of shape [n_samples]
#  |      The target values
#  |  y_pred: array_like of shape [n_samples]
#  |      The predicted values
#  |
#  |  grad: array_like of shape [n_samples]
#  |      The value of the gradient for each sample point.
#  |  hess: array_like of shape [n_samples]
#  |      The value of the second derivative for each sample point
#  |
#  |  Method resolution order:
#  |      XGBClassifier
#  |      XGBModel
#  |      sklearn.base.BaseEstimator
#  |      sklearn.base.ClassifierMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, max_depth=3, learning_rate=0.1, n_estimators=100, verbosity=1, silent=None, objective='binary:logistic', booster='gbtree', n_jobs=1, nthread=None, gamma=0, min_child_weight=1, max_delta_step=0, subsample=1, colsample_bytree=1, colsample_bylevel=1, colsample_bynode=1, reg_alpha=0, reg_lambda=1, scale_pos_weight=1, base_score=0.5, random_state=0, seed=None, missing=None, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  evals_result(self)
#  |      Return the evaluation results.
#  |
#  |      If **eval_set** is passed to the `fit` function, you can call
#  |      ``evals_result()`` to get evaluation results for all passed **eval_sets**.
#  |      When **eval_metric** is also passed to the `fit` function, the
#  |      **evals_result** will contain the **eval_metrics** passed to the `fit` function.
#  |
#  |      Returns
#  |      -------
#  |      evals_result : dictionary
#  |
#  |      Example
#  |      -------
#  |
#  |      .. code-block:: python
#  |
#  |          param_dist = {'objective':'binary:logistic', 'n_estimators':2}
#  |
#  |          clf = xgb.XGBClassifier(**param_dist)
#  |
#  |          clf.fit(X_train, y_train,
#  |                  eval_set=[(X_train, y_train), (X_test, y_test)],
#  |                  eval_metric='logloss',
#  |                  verbose=True)
#  |
#  |          evals_result = clf.evals_result()
#  |
#  |      The variable **evals_result** will contain
#  |
#  |      .. code-block:: python
#  |
#  |          {'validation_0': {'logloss': ['0.604835', '0.531479']},
#  |          'validation_1': {'logloss': ['0.41965', '0.17686']}}
#  |
#  |  fit(self, X, y, sample_weight=None, eval_set=None, eval_metric=None, early_stopping_rounds=None, verbose=True, xgb_model=None, sample_weight_eval_set=None, callbacks=None)
#  |      Fit gradient boosting classifier
#  |
#  |      Parameters
#  |      ----------
#  |      X : array_like
#  |          Feature matrix
#  |      y : array_like
#  |          Labels
#  |      sample_weight : array_like
#  |          Weight for each instance
#  |      eval_set : list, optional
#  |          A list of (X, y) pairs to use as a validation set for
#  |          early-stopping
#  |      sample_weight_eval_set : list, optional
#  |          A list of the form [L_1, L_2, ..., L_n], where each L_i is a list of
#  |          instance weights on the i-th validation set.
#  |      eval_metric : str, callable, optional
#  |          If a str, should be a built-in evaluation metric to use. See
#  |          doc/parameter.rst. If callable, a custom evaluation metric. The call
#  |          signature is func(y_predicted, y_true) where y_true will be a
#  |          DMatrix object such that you may need to call the get_label
#  |          method. It must return a str, value pair where the str is a name
#  |          for the evaluation and value is the value of the evaluation
#  |          function. This objective is always minimized.
#  |      early_stopping_rounds : int, optional
#  |          Activates early stopping. Validation error needs to decrease at
#  |          least every <early_stopping_rounds> round(s) to continue training.
#  |          Requires at least one item in evals. If there's more than one,
#  |          will use the last. If early stopping occurs, the model will have
#  |          three additional fields: bst.best_score, bst.best_iteration and
#  |          bst.best_ntree_limit (bst.best_ntree_limit is the ntree_limit parameter
#  |          default value in predict method if not any other value is specified).
#  |          (Use bst.best_ntree_limit to get the correct value if num_parallel_tree
#  |          and/or num_class appears in the parameters)
#  |      verbose : bool
#  |          If `verbose` and an evaluation set is used, writes the evaluation
#  |          metric measured on the validation set to stderr.
#  |      xgb_model : str
#  |          file name of stored xgb model or 'Booster' instance Xgb model to be
#  |          loaded before training (allows training continuation).
#  |      callbacks : list of callback functions
#  |          List of callback functions that are applied at end of each iteration.
#  |          It is possible to use predefined callbacks by using :ref:`callback_api`.
#  |          Example:
#  |
#  |          .. code-block:: python
#  |
#  |              [xgb.callback.reset_learning_rate(custom_rates)]
#  |
#  |  predict(self, data, output_margin=False, ntree_limit=None, validate_features=True)
#  |      Predict with `data`.
#  |
#  |      .. note:: This function is not thread safe.
#  |
#  |        For each booster object, predict can only be called from one thread.
#  |        If you want to run prediction using multiple thread, call ``xgb.copy()`` to make copies
#  |        of model object and then call ``predict()``.
#  |
#  |      .. note:: Using ``predict()`` with DART booster
#  |
#  |        If the booster object is DART type, ``predict()`` will perform dropouts, i.e. only
#  |        some of the trees will be evaluated. This will produce incorrect results if ``data`` is
#  |        not the training data. To obtain correct results on test sets, set ``ntree_limit`` to
#  |        a nonzero value, e.g.
#  |
#  |        .. code-block:: python
#  |
#  |          preds = bst.predict(dtest, ntree_limit=num_round)
#  |
#  |      Parameters
#  |      ----------
#  |      data : DMatrix
#  |          The dmatrix storing the input.
#  |      output_margin : bool
#  |          Whether to output the raw untransformed margin value.
#  |      ntree_limit : int
#  |          Limit number of trees in the prediction; defaults to best_ntree_limit if defined
#  |          (i.e. it has been trained with early stopping), otherwise 0 (use all trees).
#  |      validate_features : bool
#  |          When this is True, validate that the Booster's and data's feature_names are identical.
#  |          Otherwise, it is assumed that the feature_names are the same.
#  |      Returns
#  |      -------
#  |      prediction : numpy array
#  |
#  |  predict_proba(self, data, ntree_limit=None, validate_features=True)
#  |      Predict the probability of each `data` example being of a given class.
#  |
#  |      .. note:: This function is not thread safe
#  |
#  |          For each booster object, predict can only be called from one thread.
#  |          If you want to run prediction using multiple thread, call ``xgb.copy()`` to make copies
#  |          of model object and then call predict
#  |
#  |      Parameters
#  |      ----------
#  |      data : DMatrix
#  |          The dmatrix storing the input.
#  |      ntree_limit : int
#  |          Limit number of trees in the prediction; defaults to best_ntree_limit if defined
#  |          (i.e. it has been trained with early stopping), otherwise 0 (use all trees).
#  |      validate_features : bool
#  |          When this is True, validate that the Booster's and data's feature_names are identical.
#  |          Otherwise, it is assumed that the feature_names are the same.
#  |
#  |      Returns
#  |      -------
#  |      prediction : numpy array
#  |          a numpy array with the probability of each data example being of a given class.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from XGBModel:
#  |
#  |  __setstate__(self, state)
#  |
#  |  apply(self, X, ntree_limit=0)
#  |      Return the predicted leaf every tree for each sample.
#  |
#  |      Parameters
#  |      ----------
#  |      X : array_like, shape=[n_samples, n_features]
#  |          Input features matrix.
#  |
#  |      ntree_limit : int
#  |          Limit number of trees in the prediction; defaults to 0 (use all trees).
#  |
#  |      Returns
#  |      -------
#  |      X_leaves : array_like, shape=[n_samples, n_trees]
#  |          For each datapoint x in X and for each tree, return the index of the
#  |          leaf x ends up in. Leaves are numbered within
#  |          ``[0; 2**(self.max_depth+1))``, possibly with gaps in the numbering.
#  |
#  |  get_booster(self)
#  |      Get the underlying xgboost Booster of this model.
#  |
#  |      This will raise an exception when fit was not called
#  |
#  |      Returns
#  |      -------
#  |      booster : a xgboost booster of underlying model
#  |
#  |  get_num_boosting_rounds(self)
#  |      Gets the number of xgboost boosting rounds.
#  |
#  |  get_params(self, deep=False)
#  |      Get parameters.
#  |
#  |  get_xgb_params(self)
#  |      Get xgboost type parameters.
#  |
#  |  load_model(self, fname)
#  |      Load the model from a file.
#  |
#  |      The model is loaded from an XGBoost internal binary format which is
#  |      universal among the various XGBoost interfaces. Auxiliary attributes of
#  |      the Python Booster object (such as feature names) will not be loaded.
#  |      Label encodings (text labels to numeric labels) will be also lost.
#  |      **If you are using only the Python interface, we recommend pickling the
#  |      model object for best results.**
#  |
#  |      Parameters
#  |      ----------
#  |      fname : string or a memory buffer
#  |          Input file name or memory buffer(see also save_raw)
#  |
#  |  save_model(self, fname)
#  |      Save the model to a file.
#  |
#  |      The model is saved in an XGBoost internal binary format which is
#  |      universal among the various XGBoost interfaces. Auxiliary attributes of
#  |      the Python Booster object (such as feature names) will not be loaded.
#  |      Label encodings (text labels to numeric labels) will be also lost.
#  |      **If you are using only the Python interface, we recommend pickling the
#  |      model object for best results.**
#  |
#  |      Parameters
#  |      ----------
#  |      fname : string
#  |          Output file name
#  |
#  |  set_params(self, **params)
#  |      Set the parameters of this estimator.
#  |      Modification of the sklearn method to allow unknown kwargs. This allows using
#  |      the full range of xgboost parameters that are not defined as member variables
#  |      in sklearn grid search.
#  |      Returns
#  |      -------
#  |      self
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from XGBModel:
#  |
#  |  coef_
#  |      Coefficients property
#  |
#  |      .. note:: Coefficients are defined only for linear learners
#  |
#  |          Coefficients are only defined when the linear model is chosen as base
#  |          learner (`booster=gblinear`). It is not defined for other base learner types, such
#  |          as tree learners (`booster=gbtree`).
#  |
#  |      Returns
#  |      -------
#  |      coef_ : array of shape ``[n_features]`` or ``[n_classes, n_features]``
#  |
#  |  feature_importances_
#  |      Feature importances property
#  |
#  |      .. note:: Feature importance is defined only for tree boosters
#  |
#  |          Feature importance is only defined when the decision tree model is chosen as base
#  |          learner (`booster=gbtree`). It is not defined for other base learner types, such
#  |          as linear learners (`booster=gblinear`).
#  |
#  |      Returns
#  |      -------
#  |      feature_importances_ : array of shape ``[n_features]``
#  |
#  |  intercept_
#  |      Intercept (bias) property
#  |
#  |      .. note:: Intercept is defined only for linear learners
#  |
#  |          Intercept (bias) is only defined when the linear model is chosen as base
#  |          learner (`booster=gblinear`). It is not defined for other base learner types, such
#  |          as tree learners (`booster=gbtree`).
#  |
#  |      Returns
#  |      -------
#  |      intercept_ : array of shape ``(1,)`` or ``[n_classes]``
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from sklearn.base.BaseEstimator:
#  |
#  |  __getstate__(self)
#  |
#  |  __repr__(self, N_CHAR_MAX=700)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from sklearn.base.BaseEstimator:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from sklearn.base.ClassifierMixin:
#  |
#  |  score(self, X, y, sample_weight=None)
#  |      Return the mean accuracy on the given test data and labels.
#  |
#  |      In multi-label classification, this is the subset accuracy
#  |      which is a harsh metric since you require for each sample that
#  |      each label set be correctly predicted.
#  |
#  |      Parameters
#  |      ----------
#  |      X : array-like of shape (n_samples, n_features)
#  |          Test samples.
#  |
#  |      y : array-like of shape (n_samples,) or (n_samples, n_outputs)
#  |          True labels for `X`.
#  |
#  |      sample_weight : array-like of shape (n_samples,), default=None
#  |          Sample weights.
#  |
#  |      Returns
#  |      -------
#  |      score : float
#  |          Mean accuracy of ``self.predict(X)`` wrt. `y`.

# %%
operations_xgb = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=101))]

pipe_model_xgb = Pipeline(steps=operations_xgb)

pipe_model_xgb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(objective='multi:softprob', random_state=101))])

# %%
# XGBoost ta class weight i balanced yapmak için farklı bir yol izlemek gerekiyor.

from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train)
classes_weights
# Out:
# array([2.8330264 , 0.50703142, 0.50703142, ..., 0.50703142, 1.4820167 ,
#        0.50703142])

# %%
comp = pd.DataFrame(classes_weights)

comp["label"] = y_train.reset_index(drop=True)
comp.groupby("label")[0].value_counts()
# Out:
# label     0
# Black     1.482017    1038
# Hispanic  2.833026     543
# White     0.507031    3034
# Name: 0, dtype: int64

# %%
pipe_model_xgb.fit(X_train,y_train, XGB_model__sample_weight=classes_weights)

# weight parameter in XGBoost is per instance not per class.
# Therefore, we need to assign the weight of each class to its instances, which is the same thing.
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(objective='multi:softprob', random_state=101))])

# %%
eval_metric(pipe_model_xgb, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[229  11  20]
#  [ 11  89  36]
#  [ 45 104 609]]
#               precision    recall  f1-score   support
#
#        Black       0.80      0.88      0.84       260
#     Hispanic       0.44      0.65      0.52       136
#        White       0.92      0.80      0.86       758
#
#     accuracy                           0.80      1154
#    macro avg       0.72      0.78      0.74      1154
# weighted avg       0.83      0.80      0.81      1154
#
#
# Train_Set
# [[ 977   27   34]
#  [  15  471   57]
#  [  79  323 2632]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.94      0.93      1038
#     Hispanic       0.57      0.87      0.69       543
#        White       0.97      0.87      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.82      0.89      0.84      4615
# weighted avg       0.91      0.88      0.89      4615

# %%
operations_xgb = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=101))]

model = Pipeline(steps=operations_xgb)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 5,
                        fit_params={"XGB_model__sample_weight":classes_weights})
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.501299
# test_precision_Hispanic    0.427803
# test_recall_Hispanic       0.605878
# dtype: float64

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %%
param_grid = {"XGB_model__n_estimators":[50, 100],
              'XGB_model__max_depth':[1,2],
              "XGB_model__learning_rate": [0.1, 0.3],
              "XGB_model__subsample":[0.8, 1],
              "XGB_model__colsample_bytree":[0.8, 1]}

# %%
operations_xgb = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(random_state=101))]

model = Pipeline(steps=operations_xgb)

xgb_grid_model = GridSearchCV(model, 
                              param_grid, 
                              scoring=recall_Hispanic, 
                              n_jobs = -1, 
                              verbose = 2).fit(X_train, y_train, XGB_model__sample_weight=classes_weights)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   3.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   3.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   3.6s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   3.6s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   5.9s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   6.0s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   6.0s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   6.3s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.6s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  10.7s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  10.8s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=   9.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=   9.6s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=   8.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=   8.3s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  10.1s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  10.3s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  10.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  10.3s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   6.3s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   6.2s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   5.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   5.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   5.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.4s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.3s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.3s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.6s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.6s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  11.7s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  11.7s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  11.0s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  11.2s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  11.1s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  11.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  12.1s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  12.0s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   6.3s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   6.4s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   5.8s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   5.9s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  15.2s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  15.3s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   5.0s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.2s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.2s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   6.3s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   6.1s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  11.8s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  11.7s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=   9.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=   9.4s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=   8.6s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=   8.8s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  10.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  10.3s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  11.7s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  11.7s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   7.2s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   7.3s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   7.2s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   7.2s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   7.2s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   7.2s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.0s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.0s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.1s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   5.0s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  12.3s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  12.4s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  12.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  12.6s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  12.4s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  12.5s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  12.0s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  11.8s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   7.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   7.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   3.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   4.0s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  12.7s
# [CV] END XGB_model__colsample_bytree=0.8, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  12.8s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   4.1s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   4.0s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   4.0s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   4.1s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   4.2s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   4.3s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=   8.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=   8.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=   8.6s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=   8.6s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=   8.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=   8.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=   9.7s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=   9.7s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  10.8s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  11.0s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   8.1s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   8.0s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   9.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=  10.0s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=  10.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=  10.6s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=  12.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=  12.2s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=  10.6s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=  10.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  17.7s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  17.8s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  17.6s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  17.7s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  12.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  12.7s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  12.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  12.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   8.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   8.7s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   7.0s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   7.0s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  19.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.1, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  19.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   4.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   4.7s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   4.6s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   4.7s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   6.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   6.8s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  11.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  12.1s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  11.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  11.7s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  11.3s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  11.6s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  11.0s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  10.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  12.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   9.1s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   8.8s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=1, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  12.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   6.6s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   6.4s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=0.8; total time=   6.3s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   6.4s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   6.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   6.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   7.0s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=50, XGB_model__subsample=1; total time=   6.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  12.6s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  12.4s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  12.5s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  12.6s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  11.7s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=0.8; total time=  11.8s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  11.9s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=  11.6s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=   6.1s
# [CV] END XGB_model__colsample_bytree=1, XGB_model__learning_rate=0.3, XGB_model__max_depth=2, XGB_model__n_estimators=100, XGB_model__subsample=1; total time=   6.1s

# %%
xgb_grid_model.best_estimator_
# Out:
# Pipeline(steps=[('OrdinalEncoder',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                 ('XGB_model',
#                  XGBClassifier(colsample_bytree=0.8, learning_rate=0.3,
#                                max_depth=2, n_estimators=50,
#                                objective='multi:softprob', random_state=101,
#                                subsample=0.8))])

# %%
xgb_grid_model.best_params_
# Out:
# {'XGB_model__colsample_bytree': 0.8,
#  'XGB_model__learning_rate': 0.3,
#  'XGB_model__max_depth': 2,
#  'XGB_model__n_estimators': 50,
#  'XGB_model__subsample': 0.8}

# %%
xgb_grid_model.best_score_
# Out:
# 0.6427964661909616

# %%
eval_metric(xgb_grid_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[227  15  18]
#  [  8  93  35]
#  [ 39 116 603]]
#               precision    recall  f1-score   support
#
#        Black       0.83      0.87      0.85       260
#     Hispanic       0.42      0.68      0.52       136
#        White       0.92      0.80      0.85       758
#
#     accuracy                           0.80      1154
#    macro avg       0.72      0.78      0.74      1154
# weighted avg       0.84      0.80      0.81      1154
#
#
# Train_Set
# [[ 945   46   47]
#  [  26  440   77]
#  [ 102  412 2520]]
#               precision    recall  f1-score   support
#
#        Black       0.88      0.91      0.90      1038
#     Hispanic       0.49      0.81      0.61       543
#        White       0.95      0.83      0.89      3034
#
#     accuracy                           0.85      4615
#    macro avg       0.77      0.85      0.80      4615
# weighted avg       0.88      0.85      0.86      4615

# %%
#!pip install scikit-plot

# %%
from scikitplot.metrics import plot_roc, precision_recall_curve
from scikitplot.metrics import plot_precision_recall


perations_xgb = [("OrdinalEncoder", column_trans), ("XGB_model", XGBClassifier(learning_rate=0.3, max_depth=1,
                            random_state=101, subsample=0.8))]

model = Pipeline(steps=operations_xgb)

model.fit(X_train, y_train, XGB_model__sample_weight=classes_weights)

y_pred_proba = model.predict_proba(X_test)
#y_pred = model.predict(X_test)
#Plot metrics 
#plot_roc(y_test, y_score)
#plt.show()
    
plot_precision_recall(y_test, y_pred_proba)
plt.show()

# %%
y_test_dummies = pd.get_dummies(y_test, drop_first=False).values

average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])
# Out:
# 0.6103270539987586

# %%
y_pred = xgb_grid_model.predict(X_test)

xgb_AP = average_precision_score(y_test_dummies[:, 1], y_pred_proba[:, 1])
xgb_f1 = f1_score(y_test, y_pred, average=None, labels=["Hispanic"])
xgb_recall = recall_score(y_test, y_pred, average=None, labels=["Hispanic"])

# %% [markdown]
# ## Comparing Models

# %%
compare = pd.DataFrame({"Model": ["Logistic Regression", "SVM",  "Random Forest", "XGBoost"],
                        "F1": [log_f1[0], svc_f1[0], rf_f1[0], xgb_f1[0]],
                        "Recall": [log_recall[0], svc_recall[0], rf_recall[0], xgb_recall[0]],
                        "AP": [log_AP, svc_AP, rf_AP, xgb_AP]})

def labels(ax):
    for p in ax.patches:
        width = p.get_width()                        # get bar length
        ax.text(width,                               # set the text at 1 unit right of the bar
                p.get_y() + p.get_height() / 2,      # get Y coordinate + X coordinate / 2
                '{:1.3f}'.format(width),             # set variable to display, 2 decimals
                ha = 'left',                         # horizontal alignment
                va = 'center')                       # vertical alignment
    
plt.figure(figsize=(14,10))
plt.subplot(311)
compare = compare.sort_values(by="F1", ascending=False)
ax=sns.barplot(x="F1", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(312)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
labels(ax)

plt.subplot(313)
compare = compare.sort_values(by="AP", ascending=False)
ax=sns.barplot(x="AP", y="Model", data=compare, palette="Blues_d")
labels(ax)
plt.show()

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Before the Deployment
# - Choose the model that works best based on your chosen metric
# - For final step, fit the best model with whole dataset to get better performance.
# - And your model ready to deploy, dump your model and scaler.

# %%
column_trans_final = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), 
                                       remainder=MinMaxScaler())

operations_final = [("OneHotEncoder",column_trans_final),("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                                          random_state=101))]

final_model = Pipeline(steps=operations_final)

# %%
final_model.fit(X, y)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                 ('log',
#                  LogisticRegression(class_weight='balanced', max_iter=10000,
#                                     random_state=101))])

# %%
X.describe()
# Out:
#        abdominalextensiondepthsitting  acromialheight  acromionradialelength  anklecircumference  axillaheight  balloffootcircumference  balloffootlength  biacromialbreadth  bicepscircumferenceflexed  bicristalbreadth  bideltoidbreadth  bimalleolarbreadth  bitragionchinarc  bitragionsubmandibulararc  bizygomaticbreadth  buttockcircumference  buttockdepth  buttockheight  buttockkneelength  buttockpopliteallength  calfcircumference  cervicaleheight  chestbreadth  chestcircumference   chestdepth  chestheight  crotchheight  crotchlengthomphalion  crotchlengthposterioromphalion   earbreadth    earlength  earprotrusion  elbowrestheight  eyeheightsitting  footbreadthhorizontal   footlength  forearmcenterofgriplength  forearmcircumferenceflexed  forearmforearmbreadth  forearmhandlength  functionalleglength  handbreadth  handcircumference   handlength  headbreadth  headcircumference   headlength  heelanklecircumference  heelbreadth   hipbreadth  hipbreadthsitting  iliocristaleheight  \
# count                     5769.000000     5769.000000            5769.000000         5769.000000   5769.000000              5769.000000       5769.000000        5769.000000                5769.000000       5769.000000       5769.000000         5769.000000       5769.000000                5769.000000         5769.000000           5769.000000   5769.000000    5769.000000        5769.000000             5769.000000        5769.000000      5769.000000   5769.000000         5769.000000  5769.000000  5769.000000   5769.000000            5769.000000                     5769.000000  5769.000000  5769.000000    5769.000000      5769.000000       5769.000000            5769.000000  5769.000000                5769.000000                 5769.000000            5769.000000        5769.000000          5769.000000  5769.000000        5769.000000  5769.000000  5769.000000        5769.000000  5769.000000             5769.000000  5769.000000  5769.000000        5769.000000         5769.000000
# mean                       247.254290     1408.630265             328.071590          225.201768   1301.902583               244.408043        195.118911         399.706015                 341.663027        274.903449        491.454845           72.335413        324.962212                 306.677760          139.529381           1022.059456    242.234356     872.112845         610.449991              498.331773         386.316519      1479.952158    283.232623         1024.206622   252.322586  1254.290172    827.105738             622.693708                      351.880222    35.175420    62.606171      22.227249       240.553302        786.399203              98.915063   263.512394                 339.458832                  295.661640             553.098284         467.898769          1104.347201    85.098111         204.215635   189.574796   152.043682         570.424337   196.640839              333.274918    70.834113   348.930837         386.417923         1042.152366
# std                         37.457748       78.303123              20.444554           15.965783     71.260913                16.803556         13.379000          30.124094                  41.270615         19.239580         42.011888            5.326965         17.050426                  20.818789            7.248670             75.952953     26.409001      54.064846          33.120828               28.512562          30.577787        83.590746     20.612214          100.375776    26.660255    78.882449     54.056267              45.087220                       29.807293     3.221118     4.861629       3.149012        28.595503         41.843182               6.658949    17.231642                  23.081597                   29.857253              62.255490          29.785714            67.719289     6.320915          15.486056    11.422521     6.176650          18.245395     8.322907               22.260663     5.932530    25.191381          32.273943           59.102058
# min                        155.000000     1146.000000             249.000000          156.000000   1062.000000               186.000000        151.000000         283.000000                 216.000000        197.000000        357.000000           55.000000        267.000000                 245.000000          116.000000            737.000000    168.000000     656.000000         479.000000              380.000000         266.000000      1208.000000    213.000000          695.000000   170.000000  1000.000000    610.000000             473.000000                      243.000000    25.000000    46.000000      13.000000       138.000000        654.000000              77.000000   210.000000                 258.000000                  200.000000             376.000000         342.000000           835.000000    67.000000         160.000000   150.000000   131.000000         502.000000   168.000000              258.000000    48.000000   264.000000         280.000000          816.000000
# 25%                        220.000000     1353.000000             314.000000          214.000000   1252.000000               233.000000        186.000000         377.000000                 312.000000        262.000000        461.000000           68.000000        314.000000                 292.000000          134.000000            970.000000    223.000000     834.000000         587.000000              478.000000         365.000000      1421.000000    269.000000          952.000000   234.000000  1199.000000    789.000000             592.000000                      331.000000    33.000000    59.000000      20.000000       222.000000        757.000000              94.000000   252.000000                 323.000000                  273.000000             507.000000         447.000000          1057.000000    80.000000         192.000000   182.000000   148.000000         558.000000   191.000000              317.000000    67.000000   332.000000         364.000000         1001.000000
# 50%                        243.000000     1412.000000             328.000000          225.000000   1304.000000               245.000000        196.000000         404.000000                 342.000000        274.000000        493.000000           73.000000        326.000000                 307.000000          140.000000           1019.000000    241.000000     870.000000         610.000000              498.000000         385.000000      1487.000000    283.000000         1023.000000   251.000000  1261.000000    827.000000             621.000000                      351.000000    35.000000    62.000000      22.000000       241.000000        788.000000              99.000000   265.000000                 341.000000                  297.000000             554.000000         470.000000          1106.000000    86.000000         206.000000   190.000000   152.000000         570.000000   197.000000              335.000000    71.000000   347.000000         384.000000         1042.000000
# 75%                        272.000000     1464.000000             342.000000          235.000000   1351.000000               256.000000        205.000000         422.000000                 370.000000        288.000000        520.000000           76.000000        336.000000                 321.000000          145.000000           1071.000000    259.000000     908.000000         633.000000              518.000000         406.000000      1539.000000    297.000000         1093.000000   270.000000  1310.000000    864.000000             652.000000                      372.000000    37.000000    66.000000      24.000000       260.000000        816.000000             104.000000   276.000000                 356.000000                  317.000000             598.000000         488.000000          1150.000000    90.000000         216.000000   197.000000   156.000000         583.000000   202.000000              349.000000    75.000000   364.000000         407.000000         1083.000000
# max                        451.000000     1683.000000             393.000000          293.000000   1553.000000               306.000000        245.000000         489.000000                 490.000000        362.000000        637.000000           91.000000        385.000000                 390.000000          166.000000           1341.000000    349.000000    1080.000000         736.000000              605.000000         523.000000      1738.000000    363.000000         1469.000000   383.000000  1506.000000   1031.000000             799.000000                      468.000000    46.000000    81.000000      34.000000       345.000000        912.000000             126.000000   323.000000                 416.000000                  402.000000             778.000000         574.000000          1316.000000   105.000000         248.000000   239.000000   177.000000         635.000000   225.000000              403.000000    93.000000   473.000000         541.000000         1253.000000
#
#        interpupillarybreadth   interscyei  interscyeii  kneeheightmidpatella  kneeheightsitting  lateralfemoralepicondyleheight  lateralmalleolusheight  lowerthighcircumference  mentonsellionlength  neckcircumference  neckcircumferencebase  overheadfingertipreachsitting   palmlength  poplitealheight  radialestylionlength  shouldercircumference  shoulderelbowlength  shoulderlength  sittingheight  sleevelengthspinewrist  sleeveoutseam         span      stature  suprasternaleheight  tenthribheight  thighcircumference  thighclearance  thumbtipreach  tibialheight  tragiontopofhead  trochanterionheight  verticaltrunkcircumferenceusa  waistbacklength  waistbreadth  waistcircumference   waistdepth  waistfrontlengthsitting  waistheightomphalion     weightkg  wristcircumference  wristheight          Age
# count            5769.000000  5769.000000  5769.000000           5769.000000        5769.000000                     5769.000000              5769.00000              5769.000000          5769.000000        5769.000000            5769.000000                    5769.000000  5769.000000      5769.000000           5769.000000            5769.000000          5769.000000     5769.000000    5769.000000             5769.000000    5769.000000  5769.000000  5769.000000          5769.000000     5769.000000         5769.000000     5769.000000    5769.000000   5769.000000       5769.000000          5769.000000                    5769.000000      5769.000000   5769.000000         5769.000000  5769.000000              5769.000000           5769.000000  5769.000000         5769.000000  5769.000000  5769.000000
# mean              632.534928   412.773964   433.017334            476.665280         541.376668                      484.316693                69.76183               406.943144           119.601664         376.127578             414.554516                    1390.525048   114.106604       417.227076            259.757670            1131.214422           354.805166      145.202288     898.592477              868.361068     578.013001  1766.951118  1716.938984          1405.392442     1101.631479          623.583637      176.696481     791.044548    459.389149        129.580343           884.659386                    1632.470966       460.990293    318.409950          916.817126   230.459178               377.352054           1033.591090   800.981106          169.308372   831.334547    29.776391
# std                36.644621    42.868488    38.513152             32.643757          33.737243                       28.977173                 7.24541                33.098625             7.860484          39.724315              38.037263                      85.519035     7.105352        30.954287             19.619717              92.350728            22.330743       12.394681      45.257322               56.904175      37.905418   109.925336    89.256478            78.008905       59.786688           57.529947       16.124405      53.486543     29.274797          6.635641            53.766243                      98.204399        36.706353     36.395675          114.386464    35.691681                31.714316             61.957938   155.990338           13.060900    47.321580     8.706610
# min               510.000000   270.000000   306.000000            346.000000         407.000000                      352.000000                43.00000               290.000000            91.000000         275.000000             302.000000                    1111.000000    92.000000       305.000000            169.000000             852.000000           271.000000      107.000000     750.000000              636.000000     410.000000  1323.000000  1442.000000          1150.000000      874.000000          412.000000      121.000000     602.000000    347.000000        105.000000           660.000000                    1342.000000       345.000000    211.000000          611.000000   138.000000               289.000000            808.000000   358.000000          124.000000   688.000000    17.000000
# 25%               610.000000   382.000000   405.000000            453.000000         517.000000                      465.000000                65.00000               384.000000           114.000000         342.000000             383.000000                    1330.000000   109.000000       395.000000            246.000000            1059.000000           339.000000      137.000000     867.000000              826.000000     551.000000  1690.000000  1655.000000          1350.000000     1059.000000          585.000000      166.000000     754.000000    439.000000        125.000000           847.000000                    1561.000000       435.000000    292.000000          831.000000   204.000000               355.000000            990.000000   686.000000          159.000000   798.000000    23.000000
# 50%               635.000000   412.000000   435.000000            477.000000         543.000000                      484.000000                70.00000               406.000000           120.000000         381.000000             419.000000                    1395.000000   114.000000       418.000000            261.000000            1141.000000           356.000000      145.000000     900.000000              874.000000     580.000000  1774.000000  1722.000000          1409.000000     1102.000000          622.000000      176.000000     793.000000    459.000000        130.000000           883.000000                    1631.000000       463.000000    316.000000          910.000000   226.000000               376.000000           1035.000000   790.000000          171.000000   831.000000    28.000000
# 75%               655.000000   443.000000   461.000000            498.000000         565.000000                      504.000000                75.00000               427.000000           125.000000         405.000000             443.000000                    1451.000000   119.000000       439.000000            273.000000            1199.000000           370.000000      154.000000     931.000000              910.000000     605.000000  1844.000000  1781.000000          1461.000000     1143.000000          661.000000      187.000000     828.000000    479.000000        134.000000           920.000000                    1697.000000       486.000000    344.000000          995.000000   253.000000               398.000000           1077.000000   900.000000          179.000000   864.000000    36.000000
# max               770.000000   562.000000   577.000000            612.000000         666.000000                      594.000000                93.00000               600.000000           156.000000         514.000000             545.000000                    1651.000000   140.000000       525.000000            328.000000            1413.000000           423.000000      185.000000    1039.000000             1058.000000     709.000000  2121.000000  1993.000000          1650.000000     1305.000000          870.000000      259.000000     998.000000    584.000000        150.000000          1095.000000                    1991.000000       598.000000    461.000000         1379.000000   406.000000               494.000000           1245.000000  1442.000000          216.000000  1009.000000    58.000000

# %%
mean_human = X.describe(include="all").loc["mean"]
mean_human
# Out:
# abdominalextensiondepthsitting      247.25429
# acromialheight                    1408.630265
# acromionradialelength               328.07159
# anklecircumference                 225.201768
# axillaheight                      1301.902583
# balloffootcircumference            244.408043
# balloffootlength                   195.118911
# biacromialbreadth                  399.706015
# bicepscircumferenceflexed          341.663027
# bicristalbreadth                   274.903449
# bideltoidbreadth                   491.454845
# bimalleolarbreadth                  72.335413
# bitragionchinarc                   324.962212
# bitragionsubmandibulararc           306.67776
# bizygomaticbreadth                 139.529381
# buttockcircumference              1022.059456
# buttockdepth                       242.234356
# buttockheight                      872.112845
# buttockkneelength                  610.449991
# buttockpopliteallength             498.331773
# calfcircumference                  386.316519
# cervicaleheight                   1479.952158
# chestbreadth                       283.232623
# chestcircumference                1024.206622
# chestdepth                         252.322586
# chestheight                       1254.290172
# crotchheight                       827.105738
# crotchlengthomphalion              622.693708
# crotchlengthposterioromphalion     351.880222
# earbreadth                           35.17542
# earlength                           62.606171
# earprotrusion                       22.227249
# elbowrestheight                    240.553302
# eyeheightsitting                   786.399203
# footbreadthhorizontal               98.915063
# footlength                         263.512394
# forearmcenterofgriplength          339.458832
# forearmcircumferenceflexed          295.66164
# forearmforearmbreadth              553.098284
# forearmhandlength                  467.898769
# functionalleglength               1104.347201
# handbreadth                         85.098111
# handcircumference                  204.215635
# handlength                         189.574796
# headbreadth                        152.043682
# headcircumference                  570.424337
# headlength                         196.640839
# heelanklecircumference             333.274918
# heelbreadth                         70.834113
# hipbreadth                         348.930837
# hipbreadthsitting                  386.417923
# iliocristaleheight                1042.152366
# interpupillarybreadth              632.534928
# interscyei                         412.773964
# interscyeii                        433.017334
# kneeheightmidpatella                476.66528
# kneeheightsitting                  541.376668
# lateralfemoralepicondyleheight     484.316693
# lateralmalleolusheight               69.76183
# lowerthighcircumference            406.943144
# mentonsellionlength                119.601664
# neckcircumference                  376.127578
# neckcircumferencebase              414.554516
# overheadfingertipreachsitting     1390.525048
# palmlength                         114.106604
# poplitealheight                    417.227076
# radialestylionlength                259.75767
# shouldercircumference             1131.214422
# shoulderelbowlength                354.805166
# shoulderlength                     145.202288
# sittingheight                      898.592477
# sleevelengthspinewrist             868.361068
# sleeveoutseam                      578.013001
# span                              1766.951118
# stature                           1716.938984
# suprasternaleheight               1405.392442
# tenthribheight                    1101.631479
# thighcircumference                 623.583637
# thighclearance                     176.696481
# thumbtipreach                      791.044548
# tibialheight                       459.389149
# tragiontopofhead                   129.580343
# trochanterionheight                884.659386
# verticaltrunkcircumferenceusa     1632.470966
# waistbacklength                    460.990293
# waistbreadth                        318.40995
# waistcircumference                 916.817126
# waistdepth                         230.459178
# waistfrontlengthsitting            377.352054
# waistheightomphalion               1033.59109
# weightkg                           800.981106
# wristcircumference                 169.308372
# wristheight                        831.334547
# Gender                                    NaN
# SubjectsBirthLocation                     NaN
# Age                                 29.776391
# WritingPreference                         NaN
# Name: mean, dtype: object

# %%
mean_human["Gender"] = "Male"
mean_human["SubjectsBirthLocation"] = "California"
mean_human["WritingPreference"] = "Right hand"

# %%
pd.DataFrame(mean_human).T
# Out:
#      abdominalextensiondepthsitting acromialheight acromionradialelength anklecircumference axillaheight balloffootcircumference balloffootlength biacromialbreadth bicepscircumferenceflexed bicristalbreadth bideltoidbreadth bimalleolarbreadth bitragionchinarc bitragionsubmandibulararc bizygomaticbreadth buttockcircumference buttockdepth buttockheight buttockkneelength buttockpopliteallength calfcircumference cervicaleheight chestbreadth chestcircumference  chestdepth  chestheight crotchheight crotchlengthomphalion crotchlengthposterioromphalion earbreadth  earlength earprotrusion elbowrestheight eyeheightsitting footbreadthhorizontal  footlength forearmcenterofgriplength forearmcircumferenceflexed forearmforearmbreadth forearmhandlength functionalleglength handbreadth handcircumference  handlength headbreadth headcircumference  headlength heelanklecircumference heelbreadth  hipbreadth hipbreadthsitting iliocristaleheight interpupillarybreadth  interscyei interscyeii  \
# mean                      247.25429    1408.630265             328.07159         225.201768  1301.902583              244.408043       195.118911        399.706015                341.663027       274.903449       491.454845          72.335413       324.962212                 306.67776         139.529381          1022.059456   242.234356    872.112845        610.449991             498.331773        386.316519     1479.952158   283.232623        1024.206622  252.322586  1254.290172   827.105738            622.693708                     351.880222   35.17542  62.606171     22.227249      240.553302       786.399203             98.915063  263.512394                339.458832                  295.66164            553.098284        467.898769         1104.347201   85.098111        204.215635  189.574796  152.043682        570.424337  196.640839             333.274918   70.834113  348.930837        386.417923        1042.152366            632.534928  412.773964  433.017334
#
#      kneeheightmidpatella kneeheightsitting lateralfemoralepicondyleheight lateralmalleolusheight lowerthighcircumference mentonsellionlength neckcircumference neckcircumferencebase overheadfingertipreachsitting  palmlength poplitealheight radialestylionlength shouldercircumference shoulderelbowlength shoulderlength sittingheight sleevelengthspinewrist sleeveoutseam         span      stature suprasternaleheight tenthribheight thighcircumference thighclearance thumbtipreach tibialheight tragiontopofhead trochanterionheight verticaltrunkcircumferenceusa waistbacklength waistbreadth waistcircumference  waistdepth waistfrontlengthsitting waistheightomphalion    weightkg wristcircumference wristheight Gender SubjectsBirthLocation        Age WritingPreference
# mean            476.66528        541.376668                     484.316693               69.76183              406.943144          119.601664        376.127578            414.554516                   1390.525048  114.106604      417.227076            259.75767           1131.214422          354.805166     145.202288    898.592477             868.361068    578.013001  1766.951118  1716.938984         1405.392442    1101.631479         623.583637     176.696481    791.044548   459.389149       129.580343          884.659386                   1632.470966      460.990293    318.40995         916.817126  230.459178              377.352054           1033.59109  800.981106         169.308372  831.334547   Male            California  29.776391        Right hand

# %%
final_model.predict(pd.DataFrame(mean_human).T)
# Out:
# array(['Hispanic'], dtype=object)

# %%
y[201]
# Out:
# 'Hispanic'

# %%
final_model.predict(X.loc[[201]])
# Out:
# array(['Hispanic'], dtype=object)

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %%
from sklearn.metrics import matthews_corrcoef

y_pred = final_model.predict(X_test)

matthews_corrcoef(y_test, y_pred)
# Out:
# 0.7831660810065028

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)
# Out:
# 0.7739520999384765

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement (Synthetic Minority Oversampling Technique)

# %%
#!pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as imbpipeline

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), 
                                       remainder=MinMaxScaler())

# %%
X_train_ohe = column_trans.fit_transform(X_train)

# %%
over = SMOTE()
X_over, y_over = over.fit_resample(X_train_ohe, y_train)

# %%
X_over.shape
# Out:
# (9102, 227)

# %%
y_over.value_counts()
# Out:
# Hispanic    3034
# White       3034
# Black       3034
# Name: DODRace, dtype: int64

# %%
under = RandomUnderSampler()
X_under, y_under = under.fit_resample(X_train_ohe, y_train)

# %%
X_under.shape
# Out:
# (1629, 227)

# %%
y_under.value_counts()
# Out:
# Black       543
# Hispanic    543
# White       543
# Name: DODRace, dtype: int64

# %%
over = SMOTE(sampling_strategy={"Hispanic": 1000})
under = RandomUnderSampler(sampling_strategy={"White": 2500})

# %%
X_resampled_over, y_resampled_over = over.fit_resample(X_train_ohe, y_train)

# %%
y_train.value_counts()
# Out:
# White       3034
# Black       1038
# Hispanic     543
# Name: DODRace, dtype: int64

# %%
y_resampled_over.value_counts()
# Out:
# White       3034
# Black       1038
# Hispanic    1000
# Name: DODRace, dtype: int64

# %%
X_resampled_under, y_resampled_under = under.fit_resample(X_train_ohe, y_train) #X_resampled_over, y_resampled_over

# %%
y_resampled_under.value_counts()
# Out:
# White       2500
# Black       1038
# Hispanic     543
# Name: DODRace, dtype: int64

# %%
# we are configuring our pipeline steps
steps = [('o', over), ('u', under)]

# create a pipeline that will automatically apply over and under
# sampling in order to steps that we created.
pipeline = imbpipeline(steps=steps)

# we will create new data over X_train and y_train.
# We simply delete some of our samples if its race "white" and we add synthetic samples to "hispanics".
X_resampled, y_resampled = pipeline.fit_resample(X_train_ohe, y_train)

# %%
y_resampled.value_counts()
# Out:
# White       2500
# Black       1038
# Hispanic    1000
# Name: DODRace, dtype: int64

# %%
y_train.value_counts()
# Out:
# White       3034
# Black       1038
# Hispanic     543
# Name: DODRace, dtype: int64

# %% [markdown]
# ## Logistic Regression Over/Under Sampling

# %% [raw]
# What does the smote pipeline do?
#
# smote_pipeline.fit(X_train, y_train)
#
# --> column_trans.fit_transform(X_train) #(Onehooencoder and minmaxscaler)
#
# --> over.fit_resample(X_train_transform)
#
# --> under.fit_resample(X_train_transform_over)
#
# --> log_model.fit(X_train_transform_over_under, y_train)
#
#
# for predict, over and under sampling algortims do nothing for X_test.
#
# smote_pipeline.predict(X_test)
#
# --> column_trans.transform(X_test) #(Onehooencoder and minmaxscaler)
#
# --> log_model.predict(X_test_transform)

# %%
column_trans = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), 
                                       remainder=MinMaxScaler())

# %%
operations = [("OneHotEncoder",column_trans), ('o', over), ('u', under), 
              ("log", LogisticRegression(max_iter=10000,random_state=101))] #("scaler", MinMaxScaler())

# %%
smote_pipeline = imbpipeline(steps=operations)

# %%
smote_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                 ('o', SMOTE(sampling_strategy={'Hispanic': 1000})),
#                 ('u', RandomUnderSampler(sampling_strategy={'White': 2500})),
#                 ('log', LogisticRegression(max_iter=10000, random_state=101))])

# %%
eval_metric(smote_pipeline, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[235   8  17]
#  [  5  97  34]
#  [ 14  33 711]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.90      0.91       260
#     Hispanic       0.70      0.71      0.71       136
#        White       0.93      0.94      0.94       758
#
#     accuracy                           0.90      1154
#    macro avg       0.85      0.85      0.85      1154
# weighted avg       0.90      0.90      0.90      1154
#
#
# Train_Set
# [[ 943   33   62]
#  [  21  391  131]
#  [  28  146 2860]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.91      0.93      1038
#     Hispanic       0.69      0.72      0.70       543
#        White       0.94      0.94      0.94      3034
#
#     accuracy                           0.91      4615
#    macro avg       0.86      0.86      0.86      4615
# weighted avg       0.91      0.91      0.91      4615

# %%
model = imbpipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.638443
# test_precision_Hispanic    0.632415
# test_recall_Hispanic       0.646330
# dtype: float64

# %% [markdown]
# #  SHAP

# %% [markdown]
# https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %%
# pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.41.0-cp39-cp39-macosx_10_9_x86_64.whl (436 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.5/436.5 kB 2.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm>4.25.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from shap) (4.63.1)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from shap) (1.4.1)
# Collecting slicer==0.0.7
#   Using cached slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>20.9 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from shap) (21.3)
# Collecting numba
#   Downloading numba-0.56.2-cp39-cp39-macosx_10_14_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 4.7 MB/s eta 0:00:0000:0100:01m
# Collecting cloudpickle
#   Using cached cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from shap) (1.22.2)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from shap) (1.0.2)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from shap) (1.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from packaging>20.9->shap) (3.0.7)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp39-cp39-macosx_10_9_x86_64.whl (25.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.5/25.5 MB 3.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools<60 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from numba->shap) (56.0.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->shap) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->shap) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-learn->shap) (1.1.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, llvmlite, cloudpickle, numba, shap
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# umap-learn 0.5.3 requires pynndescent>=0.5, which is not installed.
# pyod 1.0.1 requires statsmodels, which is not installed.
# pycaret 2.3.10 requires pyyaml<6.0.0, which is not installed.
# mlflow 1.26.1 requires click>=7.0, which is not installed.
# mlflow 1.26.1 requires Flask, which is not installed.
# mlflow 1.26.1 requires prometheus-flask-exporter, which is not installed.
# mlflow 1.26.1 requires pyyaml>=5.1, which is not installed.
# mlflow 1.26.1 requires querystring-parser, which is not installed.
# mlflow 1.26.1 requires sqlalchemy, which is not installed.
# mlflow 1.26.1 requires sqlparse>=0.3.1, which is not installed.
# pycaret 2.3.10 requires numba<0.55, but you have numba 0.56.2 which is incompatible.
# pycaret 2.3.10 requires scikit-learn==0.23.2, but you have scikit-learn 1.0.2 which is incompatible.
# pycaret 2.3.10 requires scipy<=1.5.4, but you have scipy 1.8.0 which is incompatible.
# Successfully installed cloudpickle-2.1.0 llvmlite-0.39.1 numba-0.56.2 shap-0.41.0 slicer-0.0.7
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
column_trans_shap = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat), 
                                       remainder=MinMaxScaler())

X_train_trans = column_trans_shap.fit_transform(X_train)
X_test_trans = column_trans_shap.transform(X_test)

model_shap = LogisticRegression(class_weight='balanced',max_iter=10000, random_state=101, penalty="l1", solver='saga')

model_shap.fit(X_train_trans, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 column_trans_shap = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat),
#       2                                        remainder=MinMaxScaler())
#       4 X_train_trans = column_trans_shap.fit_transform(X_train)
#       5 X_test_trans = column_trans_shap.transform(X_test)
#
# NameError: name 'make_column_transformer' is not defined

# %%
X_train_trans
# Out:
# array([[0.        , 1.        , 0.        , ..., 0.44565217, 0.36760125,
#         0.19512195],
#        [0.        , 1.        , 0.        , ..., 0.60869565, 0.62616822,
#         0.3902439 ],
#        [0.        , 1.        , 0.        , ..., 0.47826087, 0.67912773,
#         0.46341463],
#        ...,
#        [0.        , 1.        , 0.        , ..., 0.4673913 , 0.65109034,
#         0.09756098],
#        [1.        , 0.        , 0.        , ..., 0.30434783, 0.31775701,
#         0.14634146],
#        [0.        , 1.        , 1.        , ..., 0.5326087 , 0.50155763,
#         0.29268293]])

# %%
eval_metric(model_shap, X_train_trans, y_train, X_test_trans, y_test)
# Out:
# Test_Set
# [[244   9   7]
#  [  5 111  20]
#  [ 28  89 641]]
#               precision    recall  f1-score   support
#
#        Black       0.88      0.94      0.91       260
#     Hispanic       0.53      0.82      0.64       136
#        White       0.96      0.85      0.90       758
#
#     accuracy                           0.86      1154
#    macro avg       0.79      0.87      0.82      1154
# weighted avg       0.89      0.86      0.87      1154
#
#
# Train_Set
# [[ 973   34   31]
#  [  19  457   67]
#  [  66  350 2618]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.94      0.93      1038
#     Hispanic       0.54      0.84      0.66       543
#        White       0.96      0.86      0.91      3034
#
#     accuracy                           0.88      4615
#    macro avg       0.81      0.88      0.83      4615
# weighted avg       0.90      0.88      0.89      4615

# %%
model = LogisticRegression(class_weight='balanced',max_iter=10000, random_state=101, penalty="l1", solver='saga')

scores = cross_validate(model, X_train_trans, y_train, scoring = scoring, cv = 5)
df_scores = pd.DataFrame(scores, index = range(1, 6))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.596820
# test_precision_Hispanic    0.488788
# test_recall_Hispanic       0.767890
# dtype: float64

# %%
X_train.columns
# Out:
# Index(['abdominalextensiondepthsitting', 'acromialheight', 'acromionradialelength', 'anklecircumference', 'axillaheight', 'balloffootcircumference', 'balloffootlength', 'biacromialbreadth', 'bicepscircumferenceflexed', 'bicristalbreadth', 'bideltoidbreadth', 'bimalleolarbreadth', 'bitragionchinarc', 'bitragionsubmandibulararc', 'bizygomaticbreadth', 'buttockcircumference', 'buttockdepth', 'buttockheight', 'buttockkneelength', 'buttockpopliteallength', 'calfcircumference', 'cervicaleheight', 'chestbreadth', 'chestcircumference', 'chestdepth', 'chestheight', 'crotchheight', 'crotchlengthomphalion', 'crotchlengthposterioromphalion', 'earbreadth', 'earlength', 'earprotrusion', 'elbowrestheight', 'eyeheightsitting', 'footbreadthhorizontal', 'footlength', 'forearmcenterofgriplength', 'forearmcircumferenceflexed', 'forearmforearmbreadth', 'forearmhandlength', 'functionalleglength', 'handbreadth', 'handcircumference', 'handlength', 'headbreadth', 'headcircumference', 'headlength',
#        'heelanklecircumference', 'heelbreadth', 'hipbreadth', 'hipbreadthsitting', 'iliocristaleheight', 'interpupillarybreadth', 'interscyei', 'interscyeii', 'kneeheightmidpatella', 'kneeheightsitting', 'lateralfemoralepicondyleheight', 'lateralmalleolusheight', 'lowerthighcircumference', 'mentonsellionlength', 'neckcircumference', 'neckcircumferencebase', 'overheadfingertipreachsitting', 'palmlength', 'poplitealheight', 'radialestylionlength', 'shouldercircumference', 'shoulderelbowlength', 'shoulderlength', 'sittingheight', 'sleevelengthspinewrist', 'sleeveoutseam', 'span', 'stature', 'suprasternaleheight', 'tenthribheight', 'thighcircumference', 'thighclearance', 'thumbtipreach', 'tibialheight', 'tragiontopofhead', 'trochanterionheight', 'verticaltrunkcircumferenceusa', 'waistbacklength', 'waistbreadth', 'waistcircumference', 'waistdepth', 'waistfrontlengthsitting', 'waistheightomphalion', 'weightkg', 'wristcircumference', 'wristheight', 'Gender', 'SubjectsBirthLocation', 'Age',
#        'WritingPreference'],
#       dtype='object')

# %%
features = column_trans_shap.get_feature_names_out(X_train.columns)
features
# Out:
# array(['onehotencoder__Gender_Female', 'onehotencoder__Gender_Male',
#        'onehotencoder__SubjectsBirthLocation_Alabama',
#        'onehotencoder__SubjectsBirthLocation_Alaska',
#        'onehotencoder__SubjectsBirthLocation_Antigua and Barbuda',
#        'onehotencoder__SubjectsBirthLocation_Argentina',
#        'onehotencoder__SubjectsBirthLocation_Arizona',
#        'onehotencoder__SubjectsBirthLocation_Arkansas',
#        'onehotencoder__SubjectsBirthLocation_Azerbaijan',
#        'onehotencoder__SubjectsBirthLocation_Bahamas',
#        'onehotencoder__SubjectsBirthLocation_Barbados',
#        'onehotencoder__SubjectsBirthLocation_Belarus',
#        'onehotencoder__SubjectsBirthLocation_Belgium',
#        'onehotencoder__SubjectsBirthLocation_Belize',
#        'onehotencoder__SubjectsBirthLocation_Bermuda',
#        'onehotencoder__SubjectsBirthLocation_Bolivia',
#        'onehotencoder__SubjectsBirthLocation_Brazil',
#        'onehotencoder__SubjectsBirthLocation_British Virgin Islands',
#        'onehotencoder__SubjectsBirthLocation_Bulgaria',
#        'onehotencoder__SubjectsBirthLocation_California',
#        'onehotencoder__SubjectsBirthLocation_Cameroon',
#        'onehotencoder__SubjectsBirthLocation_Canada',
#        'onehotencoder__SubjectsBirthLocation_Chile',
#        'onehotencoder__SubjectsBirthLocation_Colombia',
#        'onehotencoder__SubjectsBirthLocation_Colorado',
#        'onehotencoder__SubjectsBirthLocation_Connecticut',
#        'onehotencoder__SubjectsBirthLocation_Costa Rica',
#        'onehotencoder__SubjectsBirthLocation_Cuba',
#        'onehotencoder__SubjectsBirthLocation_Delaware',
#        'onehotencoder__SubjectsBirthLocation_Denmark',
#        'onehotencoder__SubjectsBirthLocation_District of Columbia',
#        'onehotencoder__SubjectsBirthLocation_Dominican Republic',
#        'onehotencoder__SubjectsBirthLocation_Ecuador',
#        'onehotencoder__SubjectsBirthLocation_Egypt',
#        'onehotencoder__SubjectsBirthLocation_El Salvador',
#        'onehotencoder__SubjectsBirthLocation_Ethiopia',
#        'onehotencoder__SubjectsBirthLocation_Florida',
#        'onehotencoder__SubjectsBirthLocation_France',
#        'onehotencoder__SubjectsBirthLocation_French Guiana',
#        'onehotencoder__SubjectsBirthLocation_Georgia',
#        'onehotencoder__SubjectsBirthLocation_Germany',
#        'onehotencoder__SubjectsBirthLocation_Ghana',
#        'onehotencoder__SubjectsBirthLocation_Grenada',
#        'onehotencoder__SubjectsBirthLocation_Guadalupe',
#        'onehotencoder__SubjectsBirthLocation_Guam',
#        'onehotencoder__SubjectsBirthLocation_Guyana',
#        'onehotencoder__SubjectsBirthLocation_Haiti',
#        'onehotencoder__SubjectsBirthLocation_Hawaii',
#        'onehotencoder__SubjectsBirthLocation_Honduras',
#        'onehotencoder__SubjectsBirthLocation_Iceland',
#        'onehotencoder__SubjectsBirthLocation_Idaho',
#        'onehotencoder__SubjectsBirthLocation_Illinois',
#        'onehotencoder__SubjectsBirthLocation_Indiana',
#        'onehotencoder__SubjectsBirthLocation_Iowa',
#        'onehotencoder__SubjectsBirthLocation_Iran',
#        'onehotencoder__SubjectsBirthLocation_Iraq',
#        'onehotencoder__SubjectsBirthLocation_Israel',
#        'onehotencoder__SubjectsBirthLocation_Italy',
#        'onehotencoder__SubjectsBirthLocation_Ivory Coast',
#        'onehotencoder__SubjectsBirthLocation_Jamaica',
#        'onehotencoder__SubjectsBirthLocation_Japan',
#        'onehotencoder__SubjectsBirthLocation_Kansas',
#        'onehotencoder__SubjectsBirthLocation_Kentucky',
#        'onehotencoder__SubjectsBirthLocation_Kenya',
#        'onehotencoder__SubjectsBirthLocation_Lebanon',
#        'onehotencoder__SubjectsBirthLocation_Liberia',
#        'onehotencoder__SubjectsBirthLocation_Louisiana',
#        'onehotencoder__SubjectsBirthLocation_Maine',
#        'onehotencoder__SubjectsBirthLocation_Maryland',
#        'onehotencoder__SubjectsBirthLocation_Massachusetts',
#        'onehotencoder__SubjectsBirthLocation_Mexico',
#        'onehotencoder__SubjectsBirthLocation_Michigan',
#        'onehotencoder__SubjectsBirthLocation_Minnesota',
#        'onehotencoder__SubjectsBirthLocation_Mississippi',
#        'onehotencoder__SubjectsBirthLocation_Missouri',
#        'onehotencoder__SubjectsBirthLocation_Montana',
#        'onehotencoder__SubjectsBirthLocation_Morocco',
#        'onehotencoder__SubjectsBirthLocation_Nebraska',
#        'onehotencoder__SubjectsBirthLocation_Netherlands',
#        'onehotencoder__SubjectsBirthLocation_Nevada',
#        'onehotencoder__SubjectsBirthLocation_New Hampshire',
#        'onehotencoder__SubjectsBirthLocation_New Jersey',
#        'onehotencoder__SubjectsBirthLocation_New Mexico',
#        'onehotencoder__SubjectsBirthLocation_New York',
#        'onehotencoder__SubjectsBirthLocation_New Zealand',
#        'onehotencoder__SubjectsBirthLocation_Nicaragua',
#        'onehotencoder__SubjectsBirthLocation_Nigeria',
#        'onehotencoder__SubjectsBirthLocation_North Carolina',
#        'onehotencoder__SubjectsBirthLocation_North Dakota',
#        'onehotencoder__SubjectsBirthLocation_Ohio',
#        'onehotencoder__SubjectsBirthLocation_Oklahoma',
#        'onehotencoder__SubjectsBirthLocation_Oregon',
#        'onehotencoder__SubjectsBirthLocation_Panama',
#        'onehotencoder__SubjectsBirthLocation_Paraguay',
#        'onehotencoder__SubjectsBirthLocation_Pennsylvania',
#        'onehotencoder__SubjectsBirthLocation_Peru',
#        'onehotencoder__SubjectsBirthLocation_Philippines',
#        'onehotencoder__SubjectsBirthLocation_Poland',
#        'onehotencoder__SubjectsBirthLocation_Portugal',
#        'onehotencoder__SubjectsBirthLocation_Puerto Rico',
#        'onehotencoder__SubjectsBirthLocation_Rhode Island',
#        'onehotencoder__SubjectsBirthLocation_Romania',
#        'onehotencoder__SubjectsBirthLocation_Russia',
#        'onehotencoder__SubjectsBirthLocation_Saint Lucia',
#        'onehotencoder__SubjectsBirthLocation_Senegal',
#        'onehotencoder__SubjectsBirthLocation_Serbia',
#        'onehotencoder__SubjectsBirthLocation_South Africa',
#        'onehotencoder__SubjectsBirthLocation_South America',
#        'onehotencoder__SubjectsBirthLocation_South Carolina',
#        'onehotencoder__SubjectsBirthLocation_South Dakota',
#        'onehotencoder__SubjectsBirthLocation_South Korea',
#        'onehotencoder__SubjectsBirthLocation_Sri Lanka',
#        'onehotencoder__SubjectsBirthLocation_Sudan',
#        'onehotencoder__SubjectsBirthLocation_Tennessee',
#        'onehotencoder__SubjectsBirthLocation_Texas',
#        'onehotencoder__SubjectsBirthLocation_Togo',
#        'onehotencoder__SubjectsBirthLocation_Trinidad and Tobago',
#        'onehotencoder__SubjectsBirthLocation_Turkey',
#        'onehotencoder__SubjectsBirthLocation_US Virgin Islands',
#        'onehotencoder__SubjectsBirthLocation_Ukraine',
#        'onehotencoder__SubjectsBirthLocation_United Kingdom',
#        'onehotencoder__SubjectsBirthLocation_United States',
#        'onehotencoder__SubjectsBirthLocation_Utah',
#        'onehotencoder__SubjectsBirthLocation_Venezuela',
#        'onehotencoder__SubjectsBirthLocation_Vermont',
#        'onehotencoder__SubjectsBirthLocation_Virginia',
#        'onehotencoder__SubjectsBirthLocation_Washington',
#        'onehotencoder__SubjectsBirthLocation_West Virginia',
#        'onehotencoder__SubjectsBirthLocation_Wisconsin',
#        'onehotencoder__SubjectsBirthLocation_Wyoming',
#        'onehotencoder__WritingPreference_Either hand (No preference)',
#        'onehotencoder__WritingPreference_Left hand',
#        'onehotencoder__WritingPreference_Right hand',
#        'remainder__abdominalextensiondepthsitting',
#        'remainder__acromialheight', 'remainder__acromionradialelength',
#        'remainder__anklecircumference', 'remainder__axillaheight',
#        'remainder__balloffootcircumference',
#        'remainder__balloffootlength', 'remainder__biacromialbreadth',
#        'remainder__bicepscircumferenceflexed',
#        'remainder__bicristalbreadth', 'remainder__bideltoidbreadth',
#        'remainder__bimalleolarbreadth', 'remainder__bitragionchinarc',
#        'remainder__bitragionsubmandibulararc',
#        'remainder__bizygomaticbreadth', 'remainder__buttockcircumference',
#        'remainder__buttockdepth', 'remainder__buttockheight',
#        'remainder__buttockkneelength',
#        'remainder__buttockpopliteallength',
#        'remainder__calfcircumference', 'remainder__cervicaleheight',
#        'remainder__chestbreadth', 'remainder__chestcircumference',
#        'remainder__chestdepth', 'remainder__chestheight',
#        'remainder__crotchheight', 'remainder__crotchlengthomphalion',
#        'remainder__crotchlengthposterioromphalion',
#        'remainder__earbreadth', 'remainder__earlength',
#        'remainder__earprotrusion', 'remainder__elbowrestheight',
#        'remainder__eyeheightsitting', 'remainder__footbreadthhorizontal',
#        'remainder__footlength', 'remainder__forearmcenterofgriplength',
#        'remainder__forearmcircumferenceflexed',
#        'remainder__forearmforearmbreadth', 'remainder__forearmhandlength',
#        'remainder__functionalleglength', 'remainder__handbreadth',
#        'remainder__handcircumference', 'remainder__handlength',
#        'remainder__headbreadth', 'remainder__headcircumference',
#        'remainder__headlength', 'remainder__heelanklecircumference',
#        'remainder__heelbreadth', 'remainder__hipbreadth',
#        'remainder__hipbreadthsitting', 'remainder__iliocristaleheight',
#        'remainder__interpupillarybreadth', 'remainder__interscyei',
#        'remainder__interscyeii', 'remainder__kneeheightmidpatella',
#        'remainder__kneeheightsitting',
#        'remainder__lateralfemoralepicondyleheight',
#        'remainder__lateralmalleolusheight',
#        'remainder__lowerthighcircumference',
#        'remainder__mentonsellionlength', 'remainder__neckcircumference',
#        'remainder__neckcircumferencebase',
#        'remainder__overheadfingertipreachsitting',
#        'remainder__palmlength', 'remainder__poplitealheight',
#        'remainder__radialestylionlength',
#        'remainder__shouldercircumference',
#        'remainder__shoulderelbowlength', 'remainder__shoulderlength',
#        'remainder__sittingheight', 'remainder__sleevelengthspinewrist',
#        'remainder__sleeveoutseam', 'remainder__span',
#        'remainder__stature', 'remainder__suprasternaleheight',
#        'remainder__tenthribheight', 'remainder__thighcircumference',
#        'remainder__thighclearance', 'remainder__thumbtipreach',
#        'remainder__tibialheight', 'remainder__tragiontopofhead',
#        'remainder__trochanterionheight',
#        'remainder__verticaltrunkcircumferenceusa',
#        'remainder__waistbacklength', 'remainder__waistbreadth',
#        'remainder__waistcircumference', 'remainder__waistdepth',
#        'remainder__waistfrontlengthsitting',
#        'remainder__waistheightomphalion', 'remainder__weightkg',
#        'remainder__wristcircumference', 'remainder__wristheight',
#        'remainder__Age'], dtype=object)

# %% [markdown]
# ## Shap values for all data

# %%
import shap

explainer = shap.LinearExplainer(model_shap, X_train_trans) #LinearExplainer

shap_values = explainer.shap_values(X_test_trans)

shap.summary_plot(shap_values, X_test_trans, max_display=300,feature_names = features, plot_type="bar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 import shap
# ----> 3 explainer = shap.LinearExplainer(model_shap, X_train_trans) #LinearExplainer
#       5 shap_values = explainer.shap_values(X_test_trans)
#       7 shap.summary_plot(shap_values, X_test_trans, max_display=300,feature_names = features, plot_type="bar")
#
# NameError: name 'model_shap' is not defined

# %% [markdown]
# ## SHAP for Feature Selection

# %%
explainer = shap.Explainer(model_shap, X_train_trans)

shap_values = explainer.shap_values(X_train_trans)

shap.summary_plot(shap_values, X_train_trans, max_display=300,feature_names = features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 explainer = shap.Explainer(model_shap, X_train_trans)
#       3 shap_values = explainer.shap_values(X_train_trans)
#       5 shap.summary_plot(shap_values, X_train_trans, max_display=300,feature_names = X_train_trans.columns)
#
# NameError: name 'model_shap' is not defined

# %%
hispanic = ["SubjectsBirthLocation",  'handlength',  'forearmcircumferenceflexed', "headlength", 'bitragionsubmandibulararc',
            'footbreadthhorizontal',  'bimalleolarbreadth', 'poplitealheight', 'waistdepth', 'WritingPreference', 'tragiontopofhead',
            'bideltoidbreadth', 'neckcircumferencebase', 'biacromialbreadth','buttockheight', 'buttockkneelength', 'earlength', 
            'axillaheight', "Age"]

# %%
X2 = X[hispanic]
X2.head()
# Out:
#   SubjectsBirthLocation  handlength  forearmcircumferenceflexed  headlength  bitragionsubmandibulararc  footbreadthhorizontal  bimalleolarbreadth  poplitealheight  waistdepth WritingPreference  tragiontopofhead  bideltoidbreadth  neckcircumferencebase  biacromialbreadth  buttockheight  buttockkneelength  earlength  axillaheight  Age
# 0          North Dakota         193                         299         206                        291                    101                  71              437         240        Right hand               140               493                    436                401            882                619         71          1347   41
# 1              New York         195                         289         201                        320                     98                  67              417         225         Left hand               120               479                    420                394            870                584         62          1293   35
# 2              New York         203                         357         202                        330                    103                  75              431         255         Left hand               125               544                    434                427            901                623         61          1327   42
# 3             Wisconsin         194                         318         199                        309                    106                  73              393         205        Right hand               127               518                    446                401            821                560         66          1239   31
# 4        North Carolina         218                         324         197                        310                    111                  80              523         214        Right hand               122               524                    430                435           1080                706         56          1478   21

# %%
X2 = X[hispanic]
y = data.DODRace

# %%
cat_new = X2.select_dtypes("object").columns
cat_new
# Out:
# Index(['SubjectsBirthLocation', 'WritingPreference'], dtype='object')

# %%
X2.shape
# Out:
# (5769, 19)

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y, test_size=0.2, random_state=101, stratify =y)

# %%
column_trans_shap = make_column_transformer((OneHotEncoder(handle_unknown="ignore", sparse=False), cat_new), 
                                       remainder=MinMaxScaler())

operations_shap = [("OneHotEncoder",column_trans_shap),("log", LogisticRegression(class_weight='balanced',max_iter=10000,
                                                            random_state=101, penalty="l1", solver='saga'))]

pipe_shap_model = Pipeline(steps=operations_shap)
pipe_shap_model.fit(X_train2, y_train2)
# Out:
# Pipeline(steps=[('OneHotEncoder',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   Index(['SubjectsBirthLocation', 'WritingPreference'], dtype='object'))])),
#                 ('log',
#                  LogisticRegression(class_weight='balanced', max_iter=10000,
#                                     penalty='l1', random_state=101,
#                                     solver='saga'))])

# %%
eval_metric(pipe_shap_model, X_train2, y_train2, X_test2, y_test2)
# Out:
# Test_Set
# [[215  15  30]
#  [  8 108  20]
#  [ 93 129 536]]
#               precision    recall  f1-score   support
#
#        Black       0.68      0.83      0.75       260
#     Hispanic       0.43      0.79      0.56       136
#        White       0.91      0.71      0.80       758
#
#     accuracy                           0.74      1154
#    macro avg       0.67      0.78      0.70      1154
# weighted avg       0.80      0.74      0.76      1154
#
#
# Train_Set
# [[ 878   47  113]
#  [  31  441   71]
#  [ 366  512 2156]]
#               precision    recall  f1-score   support
#
#        Black       0.69      0.85      0.76      1038
#     Hispanic       0.44      0.81      0.57       543
#        White       0.92      0.71      0.80      3034
#
#     accuracy                           0.75      4615
#    macro avg       0.68      0.79      0.71      4615
# weighted avg       0.81      0.75      0.77      4615

# %%
model = Pipeline(steps=operations_shap)

scores = cross_validate(model, X_train2, y_train2, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic           0.538005
# test_precision_Hispanic    0.417747
# test_recall_Hispanic       0.758519
# dtype: float64

# %%
from yellowbrick.classifier import PrecisionRecallCurve
model = Pipeline(steps=operations_shap)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train2, y_train2)
viz.score(X_test2, y_test2)
viz.show();

# %%
from scikitplot.metrics import plot_roc, precision_recall_curve
from scikitplot.metrics import plot_precision_recall


model = Pipeline(steps=operations_shap)

model.fit(X_train2, y_train2)

y_pred_proba = model.predict_proba(X_test2)
    
plot_precision_recall(y_test2, y_pred_proba)
plt.show()

# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
